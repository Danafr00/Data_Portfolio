# %% [markdown]
# ### Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd 
import numpy as np
import urllib.parse

# %% [markdown]
# ### HTTP Request

# %% [markdown]
# #### store website in variable

# %%
website = 'https://www.trulia.com/NY/New_York/'
headers = ({'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.5112.81 Safari/537.36 Edg/104.0.1293.54'})

# %% [markdown]
# #### Get Request

# %%
response = requests.get(website, headers=headers)

# %% [markdown]
# #### Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Soup Object

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <script>
#    window.trulia = window.trulia || {};
#           trulia.analytics = trulia.analytics || {};
#           trulia.analytics.automaticTrackState = false;
#   </script>
#   <style data-styled="" data-styled-version="5.1.1">
#    .eIkmHi{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g1[id="MediaBlock__MediaContainer-skmvlj-0"]{content:"eIkmHi,"}/*!sc*/
# .dwmuOU{margin:0 8px;}/*!sc*/
# .dwmuOU:last-child{margin-right:0;}/*!sc*/
# .dwmuOU:first-child{margin-left:0;}/*!sc*/
# .BVZzV{-webkit-flex:1 1 0px;-ms-flex:1 1 0px;flex:1 1 0px;width:100%;margin:0 8px;}/*!sc*/
# .BVZzV:last-child{margin-right:0;}/*!sc*/
# .BVZzV:first-child{margin-left:0;}/*!sc*/
# .gnreBg{margin:0 4px;}/*!sc*/
# .gnreBg:last-child{margin-right:0;}/*!sc*/
# .gnreBg:first-child{margin-left:0;}/*!sc*/
# .ccEFsg{margin:0;}/*!sc*/
# .ccEFsg:last-child{margin-right:0;}/*!sc*/
# .ccEFsg:first-child{margin-left:0;}/*!sc*/
# .edhurL{margin:0 8px;overflow:hidden;}/*!sc*/
# .edhurL:last-child{margin-right:0;}/*!sc*/
# .edhurL:first-child{margin-left:0;}/*!sc*/
# .jNJnVO{margin:0 2px;}/*!sc*/
# .jNJnVO:last-child{margin-right:0;}/*!sc*/
# .jNJnVO:first-child{margin-left:0;}/*!sc*/
# .qjlKt{margin:0 2px;overflow:hidden;}/*!sc*/
# .qjlKt:last-child{margin-right:0;}/*!sc*/
# .qjlKt:first-child{margin-left:0;}/*!sc*/
# .jamZmF{-webkit-flex:1 1 0px;-ms-flex:1 1 0px;flex:1 1 0px;width:100%;margin:0 4px;}/*!sc*/
# .jamZmF:last-child{margin-right:0;}/*!sc*/
# .jamZmF:first-child{margin-left:0;}/*!sc*/
# .chqnRx{-webkit-flex:1 1 0px;-ms-flex:1 1 0px;flex:1 1 0px;width:100%;margin:0;}/*!sc*/
# .chqnRx:last-child{margin-right:0;}/*!sc*/
# .chqnRx:first-child{margin-left:0;}/*!sc*/
# data-styled.g2[id="MediaBlock__MediaContent-skmvlj-1"]{content:"dwmuOU,BVZzV,gnreBg,ccEFsg,edhurL,jNJnVO,qjlKt,jamZmF,chqnRx,"}/*!sc*/
# .cAsKxs{width:16px !important;height:16px !important;display:inline-block;font-size:0;}/*!sc*/
# .cAsKxs .svg{width:16px;}/*!sc*/
# .cAsKxs .svg{height:16px;}/*!sc*/
# .cAsKxs path{fill:rgb(107,119,128);}/*!sc*/
# .hnYFju{width:24px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .hnYFju .svg{width:24px;}/*!sc*/
# .hnYFju .svg{height:24px;}/*!sc*/
# .hnYFju path{fill:rgb(255,255,255);}/*!sc*/
# .jlplot{width:24px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .jlplot .svg{width:24px;}/*!sc*/
# .jlplot .svg{height:24px;}/*!sc*/
# .jlplot path{fill:rgb(0,120,130);}/*!sc*/
# .bXOPul{width:24px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .bXOPul .svg{width:24px;}/*!sc*/
# .bXOPul .svg{height:24px;}/*!sc*/
# .bXOPul path{fill:rgb(59,65,68);}/*!sc*/
# .dStlHx{width:20px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .dStlHx .svg{width:20px;}/*!sc*/
# .dStlHx .svg{height:24px;}/*!sc*/
# .dStlHx path{fill:rgb(0,120,130);}/*!sc*/
# .kZNIEt{width:16px !important;height:22px !important;display:inline-block;font-size:0;}/*!sc*/
# .kZNIEt .svg{width:16px;}/*!sc*/
# .kZNIEt .svg{height:22px;}/*!sc*/
# .kZNIEt path{fill:rgb(59,65,68);}/*!sc*/
# .iemARF{width:16px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .iemARF .svg{width:16px;}/*!sc*/
# .iemARF .svg{height:24px;}/*!sc*/
# .iemARF path{fill:rgb(0,120,130);}/*!sc*/
# .ijNWVp{width:20px !important;height:20px !important;display:inline-block;font-size:0;}/*!sc*/
# .ijNWVp .svg{width:20px;}/*!sc*/
# .ijNWVp .svg{height:20px;}/*!sc*/
# .ijNWVp path{fill:rgb(0,120,130);}/*!sc*/
# .ckNPAJ{width:16px !important;height:16px !important;display:inline-block;font-size:0;}/*!sc*/
# .ckNPAJ .svg{width:16px;}/*!sc*/
# .ckNPAJ .svg{height:16px;}/*!sc*/
# .ckNPAJ path{fill:rgb(0,120,130);}/*!sc*/
# .jfYGaR{width:20px !important;height:20px !important;display:inline-block;font-size:0;}/*!sc*/
# .jfYGaR .svg{width:20px;}/*!sc*/
# .jfYGaR .svg{height:20px;}/*!sc*/
# .jfYGaR path{fill:rgb(59,65,68);}/*!sc*/
# data-styled.g3[id="getUiSvgContainer__SvgContainer-sc-1cdn1ln-0"]{content:"cAsKxs,hnYFju,jlplot,bXOPul,dStlHx,kZNIEt,iemARF,ijNWVp,ckNPAJ,jfYGaR,"}/*!sc*/
# .jlkWrz{display:none;}/*!sc*/
# @media (min-width:376px){.jlkWrz{display:none;}}/*!sc*/
# @media (min-width:570px){.jlkWrz{display:none;}}/*!sc*/
# @media (min-width:768px){.jlkWrz{display:block;}}/*!sc*/
# @media (min-width:993px){.jlkWrz{display:block;}}/*!sc*/
# .bhkWRs{display:block;}/*!sc*/
# @media (min-width:376px){.bhkWRs{display:block;}}/*!sc*/
# @media (min-width:570px){.bhkWRs{display:block;}}/*!sc*/
# @media (min-width:768px){.bhkWRs{display:none;}}/*!sc*/
# @media (min-width:993px){.bhkWRs{display:none;}}/*!sc*/
# .bsjsJO{display:block;}/*!sc*/
# .jqAYVe{display:block;border-style:solid !important;border-color:rgb(205,209,212);border-width:0 0 1px 0;}/*!sc*/
# .dROcJl{display:none;}/*!sc*/
# .fchmFc{display:none;}/*!sc*/
# @media (min-width:376px){.fchmFc{display:none;}}/*!sc*/
# @media (min-width:570px){.fchmFc{display:none;}}/*!sc*/
# @media (min-width:768px){.fchmFc{display:block;}}/*!sc*/
# @media (min-width:993px){.fchmFc{display:none;}}/*!sc*/
# .khumPA{display:none;}/*!sc*/
# @media (min-width:376px){.khumPA{display:none;}}/*!sc*/
# @media (min-width:570px){.khumPA{display:none;}}/*!sc*/
# @media (min-width:768px){.khumPA{display:none;}}/*!sc*/
# @media (min-width:993px){.khumPA{display:block;}}/*!sc*/
# .QoeRP{width:100%;display:block;}/*!sc*/
# @media (min-width:376px){.QoeRP{display:block;}}/*!sc*/
# @media (min-width:570px){.QoeRP{display:block;}}/*!sc*/
# @media (min-width:768px){.QoeRP{display:none;}}/*!sc*/
# .cPZGSD{display:inline-block;display:inline-block;}/*!sc*/
# .crxgdI{display:inline-block;width:100%;display:inline-block;}/*!sc*/
# data-styled.g4[id="Box__BoxElement-sc-1f5rw0h-0"]{content:"jlkWrz,bhkWRs,bsjsJO,jqAYVe,dROcJl,fchmFc,khumPA,QoeRP,cPZGSD,crxgdI,"}/*!sc*/
# .fAXlbl{cursor:pointer;display:inline;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;}/*!sc*/
# .fAXlbl[role='button']:active{outline:none;box-shadow:0 0 0 1px rgb(107,119,128);}/*!sc*/
# .fAXlbl:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .erxzVp{cursor:pointer;display:inline-block;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;}/*!sc*/
# .erxzVp[role='button']:active{outline:none;box-shadow:0 0 0 1px rgb(107,119,128);}/*!sc*/
# .erxzVp:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g5[id="BoxButton-sc-12vrxun-0"]{content:"fAXlbl,erxzVp,"}/*!sc*/
# .gCjLgA{font-weight:bold;}/*!sc*/
# .kRmhGt{color:rgb(0,120,130);}/*!sc*/
# .bxzLaH{font-size:14px;line-height:1.43;}/*!sc*/
# .bxzLaH .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;width:20.02px;}/*!sc*/
# data-styled.g7[id="Text__TextBase-sc-1cait9d-0"]{content:"gCjLgA,dujbAG,kRmhGt,bxzLaH,"}/*!sc*/
# .dFamyw{font-size:14px;line-height:1.43;text-align:center;}/*!sc*/
# .dFamyw .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;width:20.02px;}/*!sc*/
# .gsLPTE{color:rgb(0,120,130);font-weight:bold;}/*!sc*/
# .kZRvWC{font-weight:bold;font-size:14px;line-height:1.43;text-align:center;}/*!sc*/
# .kZRvWC .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;width:20.02px;}/*!sc*/
# .ilVROc{font-weight:bold;font-size:20px;line-height:1.2;}/*!sc*/
# .ilVROc .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .RBSGf{color:rgb(107,119,128);font-size:12px;line-height:1.33;}/*!sc*/
# .RBSGf .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:15.96px;width:15.96px;}/*!sc*/
# .faLGMa{color:rgb(59,65,68);}/*!sc*/
# .uyZVK{font-weight:bold;font-size:14px;line-height:1.43;}/*!sc*/
# .uyZVK .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;width:20.02px;}/*!sc*/
# .keMYfJ{font-weight:bold;font-size:20px;line-height:1.2;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .keMYfJ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .bjqKkI{font-size:16px;line-height:1.5;}/*!sc*/
# .bjqKkI .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .dZyoXR{font-size:16px;line-height:1.5;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .dZyoXR .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .ccZuZv{color:rgb(107,119,128);font-size:10px;line-height:1.6;}/*!sc*/
# .ccZuZv .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:16px;width:16px;}/*!sc*/
# .fkSzsq{color:rgb(0,120,130);}/*!sc*/
# .kgxmNH{color:rgb(107,119,128);}/*!sc*/
# .gA-DbwZ{font-weight:bold;font-size:14px;line-height:1.43;}/*!sc*/
# @media (min-width:376px){.gA-DbwZ{font-size:14px;}}/*!sc*/
# @media (min-width:570px){.gA-DbwZ{font-size:14px;}}/*!sc*/
# @media (min-width:768px){.gA-DbwZ{font-size:16px;}}/*!sc*/
# @media (min-width:376px){.gA-DbwZ{line-height:1.43;}}/*!sc*/
# @media (min-width:570px){.gA-DbwZ{line-height:1.43;}}/*!sc*/
# @media (min-width:768px){.gA-DbwZ{line-height:1.5;}}/*!sc*/
# .gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;width:20.02px;}/*!sc*/
# @media (min-width:376px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;}}/*!sc*/
# @media (min-width:570px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;}}/*!sc*/
# @media (min-width:768px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;}}/*!sc*/
# @media (min-width:376px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{width:20.02px;}}/*!sc*/
# @media (min-width:570px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{width:20.02px;}}/*!sc*/
# @media (min-width:768px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{width:24px;}}/*!sc*/
# .cTGlQX{font-weight:bold;}/*!sc*/
# data-styled.g9[id="Text__TextContainerBase-sc-1cait9d-1"]{content:"dFamyw,gsLPTE,kZRvWC,ilVROc,RBSGf,faLGMa,uyZVK,keMYfJ,bjqKkI,dZyoXR,ccZuZv,oVGDp,fkSzsq,kgxmNH,gA-DbwZ,cTGlQX,"}/*!sc*/
# .gijRfk{padding:8px 16px 8px 16px;}/*!sc*/
# .kGavLk{padding:0 8px 0 0;}/*!sc*/
# .grfUIW{padding:16px 0 32px 0;}/*!sc*/
# .gOaeFu{padding:8px 0 24px 0;}/*!sc*/
# .eHmMNv{padding:0 0 16px 0;}/*!sc*/
# .kgdlpc{padding:4px 16px 4px 16px;}/*!sc*/
# .kRVDgw{padding:8px 0 0 0;}/*!sc*/
# .kGaqTU{padding:0 4px 0 0;}/*!sc*/
# .gokgj{padding:0 16px 0 0;}/*!sc*/
# .jJlWQw{padding:0 8px 0 8px;}/*!sc*/
# .kftGdI{padding:16px 0 16px 0;}/*!sc*/
# .hMDWQm{padding:0 0 0 2px;}/*!sc*/
# .dZDbka{padding:4px 2px 0 0;}/*!sc*/
# .fcYWAF{padding:0 0 32px 0;}/*!sc*/
# .dtoUNs{padding:0 0 0 0;}/*!sc*/
# data-styled.g10[id="Padding-sc-1tki7vp-0"]{content:"gijRfk,kGavLk,grfUIW,gOaeFu,eHmMNv,kgdlpc,kRVDgw,kGaqTU,gokgj,jJlWQw,kftGdI,hMDWQm,dZDbka,fcYWAF,dtoUNs,"}/*!sc*/
# .dpULLt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:53px;overflow:auto;-webkit-overflow-scrolling:touch;}/*!sc*/
# .giAiEJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:auto;-webkit-overflow-scrolling:touch;}/*!sc*/
# .bPNugb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:auto;-webkit-overflow-scrolling:touch;}/*!sc*/
# @media (max-width:47.9375em){.bPNugb{display:block;}}/*!sc*/
# data-styled.g12[id="FlexContainers__Rows-zvngfq-0"]{content:"dpULLt,giAiEJ,bPNugb,"}/*!sc*/
# .eCjeDf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# data-styled.g14[id="FlexContainers__Columns-zvngfq-2"]{content:"eCjeDf,"}/*!sc*/
# .kRfxNx{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;-webkit-text-decoration:none;text-decoration:none;font-size:16px;line-height:1.5;padding:8px 16px;outline:none;}/*!sc*/
# .kRfxNx path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .kRfxNx .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .kRfxNx::-moz-focus-inner{border:0;}/*!sc*/
# .kRfxNx[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .kRfxNx:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g22[id="ButtonBase-sc-14ooajz-0"]{content:"kRfxNx,"}/*!sc*/
# .iSYPov{line-height:1;color:inherit;}/*!sc*/
# .iSYPov:hover,.iSYPov:focus{color:rgb(0,120,130);}/*!sc*/
# .iSYPov:hover path,.iSYPov:focus path{fill:rgb(0,120,130);}/*!sc*/
# .jPioDE{line-height:1;color:inherit;}/*!sc*/
# data-styled.g30[id="UiButton-r41csk-0"]{content:"iSYPov,jPioDE,"}/*!sc*/
# .iLsXMy{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;-webkit-text-decoration:none;text-decoration:none;font-size:16px;line-height:1.5;padding:8px 16px;outline:none;color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:rgb(205,209,212);}/*!sc*/
# .iLsXMy path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .iLsXMy .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .iLsXMy::-moz-focus-inner{border:0;}/*!sc*/
# .iLsXMy[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .iLsXMy:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .iLsXMy:hover,.iLsXMy[class~='hover']{color:rgb(59,65,68);background-color:rgb(232,233,234);border-color:transparent;}/*!sc*/
# .iLsXMy[class~='focus'],.iLsXMy:focus{color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:rgb(107,119,128);outline:none;}/*!sc*/
# .iLsXMy[class~='focus']:focus-visible,.iLsXMy:focus:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .iLsXMy[class~='active'],.iLsXMy:active{color:rgb(255,255,255);background-color:rgb(107,119,128);border-color:transparent;}/*!sc*/
# .iLsXMy[class~='active'] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path,.iLsXMy:active .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(255,255,255);}/*!sc*/
# .iLsXMy[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);}/*!sc*/
# .iLsXMy[disabled] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(205,209,212);}/*!sc*/
# data-styled.g34[id="Button-sc-1ea9wz-0"]{content:"iLsXMy,"}/*!sc*/
# .eoSlgA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:0;margin-right:0;margin-top:-4px;-webkit-flex-wrap:nowrap;-ms-flex-wrap:nowrap;flex-wrap:nowrap;overflow-x:auto;-webkit-overflow-scrolling:touch;}/*!sc*/
# @media (min-width:376px){.eoSlgA{margin-left:-2px;}}/*!sc*/
# @media (min-width:570px){.eoSlgA{margin-left:-2px;}}/*!sc*/
# @media (min-width:376px){.eoSlgA{margin-right:-2px;}}/*!sc*/
# @media (min-width:570px){.eoSlgA{margin-right:-2px;}}/*!sc*/
# .eoSlgA > .Grid__CellBox-sc-144isrp-0{border-style:solid;border-color:transparent;border-width:4px 2px 0px 2px;}/*!sc*/
# .iqgnOs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:-8px;margin-right:-8px;margin-top:-16px;-webkit-flex-wrap:nowrap;-ms-flex-wrap:nowrap;flex-wrap:nowrap;overflow-x:auto;-webkit-overflow-scrolling:touch;}/*!sc*/
# .iqgnOs > .Grid__CellBox-sc-144isrp-0{border-style:solid;border-color:transparent;border-width:16px 8px 0px 8px;}/*!sc*/
# .bQSVOQ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:-8px;margin-right:-8px;margin-top:-16px;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# .bQSVOQ > .Grid__CellBox-sc-144isrp-0{border-style:solid;border-color:transparent;border-width:16px 8px 0px 8px;}/*!sc*/
# data-styled.g54[id="Grid__GridContainer-sc-144isrp-1"]{content:"eoSlgA,iqgnOs,bQSVOQ,"}/*!sc*/
# .hPjFaC{object-fit:cover;width:100%;height:100%;}/*!sc*/
# .cOExqt{width:20px;height:20px;}/*!sc*/
# .emFnwq{width:auto;height:100%;}/*!sc*/
# data-styled.g56[id="Image__ImageContainer-sc-1motiir-0"]{content:"hPjFaC,cOExqt,emFnwq,"}/*!sc*/
# .blYRoh{width:70px;height:32px;display:inline-block;line-height:0;}/*!sc*/
# .blYRoh .svg{width:70px;}/*!sc*/
# .blYRoh .svg{height:32px;}/*!sc*/
# .eWkDYx{width:70px;height:24px;display:inline-block;line-height:0;}/*!sc*/
# .eWkDYx .svg{width:70px;}/*!sc*/
# .eWkDYx .svg{height:24px;}/*!sc*/
# data-styled.g58[id="getSvgContainer__SvgContainer-sc-9w90nz-0"]{content:"blYRoh,eWkDYx,"}/*!sc*/
# .cKFaMj{height:20px;}/*!sc*/
# .cKFaMj .svg{height:20px;}/*!sc*/
# data-styled.g59[id="getSvgContainer__StyledImage-sc-9w90nz-1"]{content:"cKFaMj,"}/*!sc*/
# .gSLuwD{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .gSLuwD:hover{-webkit-text-decoration:underline;text-decoration:underline;color:rgb(0,69,75);}/*!sc*/
# data-styled.g60[id="Anchor__StyledText-sc-5lya7g-0"]{content:"gSLuwD,"}/*!sc*/
# .euBOac{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .euBOac:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .gLFHbk{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .gLFHbk:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g61[id="Anchor__StyledAnchor-sc-5lya7g-1"]{content:"euBOac,gLFHbk,"}/*!sc*/
# .eAlroL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;height:64px;margin:0;padding:0 16px 0 16px;padding:0 calc(16px + env(safe-area-inset-right)) 0 calc(16px + env(safe-area-inset-left));background-color:rgb(255,255,255);position:relative;z-index:100;font-size:15px;border-bottom:1px solid rgb(232,233,234);}/*!sc*/
# @media (max-width:62em){.eAlroL{padding:0 12px;}}/*!sc*/
# data-styled.g65[id="Navbar__Nav-sky7mr-0"]{content:"eAlroL,"}/*!sc*/
# .ZwySm{margin-left:16px;padding:0 4px;background-color:rgb(255,255,255);}/*!sc*/
# @media (max-width:62em){.ZwySm{margin-right:-10px;margin-left:2px;}}/*!sc*/
# data-styled.g66[id="Navbar__NavbarMobileMenuToggle-sky7mr-1"]{content:"ZwySm,"}/*!sc*/
# .lmeUPp{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;padding:16px 24px 16px 0;}/*!sc*/
# @media (max-width:62em){.lmeUPp{padding:12px 12px 12px 6px;}}/*!sc*/
# data-styled.g67[id="Navbar__LogoContainer-sky7mr-2"]{content:"lmeUPp,"}/*!sc*/
# .kbckwe{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justift-content:center;-ms-flex-pack:center;justift-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;height:100%;}/*!sc*/
# data-styled.g69[id="Navbar__IconContainer-sky7mr-4"]{content:"kbckwe,"}/*!sc*/
# .iMHbRw{color:rgb(59,65,68);-webkit-transition:background 0.15s ease-in-out;transition:background 0.15s ease-in-out;position:relative;}/*!sc*/
# .iMHbRw > a,.iMHbRw > span,.iMHbRw > button:not(.Button-sc-1ea9wz-0){cursor:pointer;padding:8px 16px 8px 16px;color:rgb(59,65,68);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:8px;background-color:transparent;}/*!sc*/
# .iMHbRw > a:focus svg path,.iMHbRw > span:focus svg path,.iMHbRw > button:not(.Button-sc-1ea9wz-0):focus svg path{fill:rgb(59,65,68);}/*!sc*/
# .iMHbRw svg{margin-top:-1px;}/*!sc*/
# .iMHbRw > span{cursor:default;}/*!sc*/
# .iMHbRw:hover > a,.iMHbRw:hover > span,.iMHbRw:hover > button:not(.Button-sc-1ea9wz-0){color:rgb(255,255,255);background-color:rgb(0,120,130);}/*!sc*/
# .iMHbRw:hover > a svg path,.iMHbRw:hover > span svg path,.iMHbRw:hover > button:not(.Button-sc-1ea9wz-0) svg path{fill:rgb(255,255,255);}/*!sc*/
# .iMHbRw:hover > ul{display:block;}/*!sc*/
# .iMHbRw ul{display:none;position:absolute;top:45px;background:rgb(255,255,255);border-radius:4px;box-shadow:0 2px 4px 0 rgba(59,65,68,0.5);padding:4px 0;}/*!sc*/
# .iMHbRw ul a,.iMHbRw ul button{color:rgb(59,65,68);white-space:nowrap;display:block;}/*!sc*/
# .iMHbRw ul a:hover,.iMHbRw ul button:hover{color:rgb(59,65,68);background-color:rgb(232,233,234);}/*!sc*/
# .iMHbRw ul::before{display:block;position:absolute;content:'';width:100%;height:15px;top:-15px;}/*!sc*/
# @media (max-width:62em){.iMHbRw{display:none;}}/*!sc*/
# data-styled.g75[id="NavbarItem__StyledNavbarItem-sc-1kjsgse-0"]{content:"iMHbRw,"}/*!sc*/
# .jvZEPV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-left:4px;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;}/*!sc*/
# @media (min-width:1060px){}/*!sc*/
# @media (min-width:1240px){}/*!sc*/
# data-styled.g77[id="NavbarSection-gp9p9l-0"]{content:"jvZEPV,"}/*!sc*/
# .hPToJy{position:absolute;left:-10000px;-webkit-clip:rect(1px 1px 1px 1px);clip:rect(1px 1px 1px 1px);-webkit-clip:rect(1px,1px,1px,1px);clip:rect(1px,1px,1px,1px);padding:0;border:0;height:1px;width:1px;overflow:hidden;}/*!sc*/
# data-styled.g78[id="ScreenReaderContent-sc-1y1ua5d-0"]{content:"hPToJy,"}/*!sc*/
# .fgHPbp{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;-webkit-text-decoration:none;text-decoration:none;font-size:16px;line-height:1.5;padding:8px 16px;outline:none;color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:transparent;}/*!sc*/
# .fgHPbp path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .fgHPbp .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .fgHPbp::-moz-focus-inner{border:0;}/*!sc*/
# .fgHPbp[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .fgHPbp:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .fgHPbp .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(59,65,68);}/*!sc*/
# .fgHPbp[class~='hover'],.fgHPbp:hover{color:rgb(255,255,255);background-color:rgb(0,120,130);border-color:transprant;}/*!sc*/
# .fgHPbp[class~='hover'] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path,.fgHPbp:hover .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(255,255,255);}/*!sc*/
# .fgHPbp[class~='focus'],.fgHPbp:focus{color:rgb(0,120,130);border-color:rgb(0,120,130);}/*!sc*/
# .fgHPbp[class~='focus'] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path,.fgHPbp:focus .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(0,120,130);}/*!sc*/
# .fgHPbp[class~='active'],.fgHPbp:active{color:rgb(59,65,68);background-color:rgb(232,233,234);border-color:transparent;box-shadow:none;}/*!sc*/
# .fgHPbp[class~='active'] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path,.fgHPbp:active .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(59,65,68);}/*!sc*/
# .fgHPbp[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);box-shadow:none;}/*!sc*/
# .fgHPbp[disabled] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(205,209,212);}/*!sc*/
# data-styled.g82[id="GlobalNavigationButton-x0gdrd-0"]{content:"fgHPbp,"}/*!sc*/
# .gQGHnr li{display:inline-block;border-style:none;margin-right:8px;}/*!sc*/
# .gQGHnr li:last-child{margin:0;}/*!sc*/
# .ctIOhZ li{display:inline-block;}/*!sc*/
# .ctIOhZ li:before{content:"";display:inline-block;vertical-align:middle;width:4px;height:4px;border-radius:50%;background-color:currentcolor;margin:0px 4px 2px;}/*!sc*/
# .ctIOhZ li:first-child:before{content:'';width:0;height:0;margin:0;}/*!sc*/
# data-styled.g83[id="List__ListContainer-sc-8uj508-0"]{content:"ljHPkT,gQGHnr,ctIOhZ,"}/*!sc*/
# .dwoxWy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-left:0;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;-webkit-flex:0 1 420px;-ms-flex:0 1 420px;flex:0 1 420px;}/*!sc*/
# @media (min-width:1060px){}/*!sc*/
# @media (min-width:1240px){}/*!sc*/
# @media (max-width:62em){.dwoxWy{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;width:100%;}}/*!sc*/
# data-styled.g89[id="NavbarContainer__SearchBarSection-sc-15svuwa-5"]{content:"dwoxWy,"}/*!sc*/
# @media (max-width:1240px){.pFuxB{display:none;}}/*!sc*/
# @media (max-width:1060px){.pFuxB{display:none;}}/*!sc*/
# data-styled.g90[id="NavbarContainer__NavLinkItem-sc-15svuwa-6"]{content:"pFuxB,"}/*!sc*/
# .cHCUKt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;}/*!sc*/
# @media (max-width:62em){.cHCUKt{display:none;}}/*!sc*/
# data-styled.g91[id="NavbarContainer__UserButtonsItem-sc-15svuwa-7"]{content:"cHCUKt,"}/*!sc*/
# .fZJkX{border:1px solid rgb(245,246,247);border-radius:8px;background-color:rgb(245,246,247);padding:8px 64px 8px 16px;color:rgb(59,65,68);font-size:16px;line-height:1.5;width:100%;height:42px;-webkit-transition:width 0.35s ease;transition:width 0.35s ease;display:inline-block;-webkit-appearance:none;-moz-appearance:none;appearance:none;}/*!sc*/
# .fZJkX.react-autosuggest__input--open{border:1px solid rgb(245,246,247);border-radius:8px;border-bottom-left-radius:0px;border-bottom-right-radius:0px;border-bottom:none;}/*!sc*/
# .fZJkX .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .fZJkX::-webkit-input-placeholder{color:#606F76;}/*!sc*/
# .fZJkX::-moz-placeholder{color:#606F76;}/*!sc*/
# .fZJkX:-ms-input-placeholder{color:#606F76;}/*!sc*/
# .fZJkX::placeholder{color:#606F76;}/*!sc*/
# .fZJkX[placeholder]{text-overflow:ellipsis;}/*!sc*/
# .fZJkX::-ms-clear{display:none;}/*!sc*/
# .fZJkX:focus{border-color:rgb(205,209,212);background-color:rgb(255,255,255);outline:none;}/*!sc*/
# .fZJkX::-webkit-search-cancel-button{display:none;}/*!sc*/
# .fZJkX:focus{padding-right:80px;}/*!sc*/
# data-styled.g95[id="LocationAutosuggestInput__Input-sc-789ttj-0"]{content:"fZJkX,"}/*!sc*/
# .cFovxO{position:relative;}/*!sc*/
# data-styled.g96[id="LocationAutosuggestInput__InputContainer-sc-789ttj-1"]{content:"cFovxO,"}/*!sc*/
# .gNheLz{cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:absolute;right:48px;top:0;height:100%;padding:12px;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;}/*!sc*/
# input:not(:focus) + .gNheLz{pointer-events:none;opacity:0;}/*!sc*/
# input:not(:focus) + .gNheLz:focus{pointer-events:all;opacity:1;}/*!sc*/
# .gNheLz:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g97[id="LocationAutosuggestInput__RightInnerIcon-sc-789ttj-2"]{content:"gNheLz,"}/*!sc*/
# .kIJIQK{cursor:pointer;display:block;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;position:absolute;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;right:0;top:0;height:100%;min-width:42px;cursor:pointer;background-color:rgb(217,60,35);padding:9px 12px;border-bottom-right-radius:8px;border-top-right-radius:8px;-webkit-transition:background-color 0.15s ease;transition:background-color 0.15s ease;}/*!sc*/
# .kIJIQK[role='button']:active{outline:none;box-shadow:0 0 0 1px rgb(107,119,128);}/*!sc*/
# .kIJIQK:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .react-autosuggest__input--open ~ .kIJIQK{border-bottom-right-radius:0;}/*!sc*/
# .kIJIQK:hover{background-color:rgb(156,17,20);}/*!sc*/
# .kIJIQK.focus-visible:not(:focus-visible){box-shadow:none;}/*!sc*/
# data-styled.g98[id="LocationAutosuggestInput__RightIcon-sc-789ttj-3"]{content:"kIJIQK,"}/*!sc*/
# .lcWvKj{border:1px solid rgb(205,209,212);border-bottom-right-radius:8px;border-bottom-left-radius:8px;position:absolute;width:100%;background:white;-webkit-transition:width 0.35s ease;transition:width 0.35s ease;max-height:50vh;overflow:auto;-webkit-overflow-scrolling:touch;opacity:0;}/*!sc*/
# data-styled.g99[id="LocationAutosuggestDrodown__LocationAutosuggestDropdown-sc-22jd4l-0"]{content:"lcWvKj,"}/*!sc*/
# .kIXuPW{position:relative;width:100%;-webkit-transition:width 0.35s ease;transition:width 0.35s ease;}/*!sc*/
# .kIXuPW .react-autosuggest__suggestion--first .LocationAutosuggestDrodown__ItemContainer-sc-22jd4l-2{border:none;}/*!sc*/
# .kIXuPW .react-autosuggest__section-title + .react-autosuggest__suggestions-list > .react-autosuggest__suggestion--first .LocationAutosuggestDrodown__ItemContainer-sc-22jd4l-2{border-top:none;}/*!sc*/
# data-styled.g102[id="LocationAutosuggestDrodown__LocationAutosuggestBoxContainer-sc-22jd4l-3"]{content:"kIXuPW,"}/*!sc*/
# .liYvlm{color:rgb(59,65,68);}/*!sc*/
# .liYvlm:hover{color:rgb(0,120,130);}/*!sc*/
# @media (max-width:23.4375em){.liYvlm{line-height:25px;}}/*!sc*/
# data-styled.g109[id="FooterAnchor-sc-1qyjqke-0"]{content:"liYvlm,"}/*!sc*/
# .eDgeeY{padding:16px env(safe-area-inset-right) env(safe-area-inset-bottom) env(safe-area-inset-left);font-size:10px;line-height:1.6;}/*!sc*/
# .eDgeeY .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:16px;width:16px;}/*!sc*/
# data-styled.g110[id="Copyright__Container-r29r4j-0"]{content:"eDgeeY,"}/*!sc*/
# .dCpGms{padding:16px env(safe-area-inset-right) 16px env(safe-area-inset-left);font-size:12px;line-height:1.33;}/*!sc*/
# .dCpGms .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:15.96px;width:15.96px;}/*!sc*/
# @media (max-width:23.4375em){.dCpGms{line-height:22px;}}/*!sc*/
# data-styled.g111[id="Accessibility__Container-vmfiy3-0"]{content:"dCpGms,"}/*!sc*/
# .ivICeq{padding:0;font-size:12px;line-height:1.33;}/*!sc*/
# .ivICeq .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:15.96px;width:15.96px;}/*!sc*/
# data-styled.g112[id="Footer__FooterContainer-h25adx-0"]{content:"ivICeq,"}/*!sc*/
# @media (max-width:47.9375em){.fLjkrG{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.fLjkrG::after{content:'';width:4px;height:4px;border-radius:50%;background-color:currentColor;margin:0 4px 0;}.fLjkrG:last-child:after{display:none;}}/*!sc*/
# @media (max-width:47.9375em){.iXDUHN{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.iXDUHN::after{content:'';width:4px;height:4px;border-radius:50%;background-color:currentColor;margin:0 4px 0;}.iXDUHN:last-child:after{display:none;}}/*!sc*/
# .iXDUHN:after{display:none;}/*!sc*/
# .etPKim{display:none;}/*!sc*/
# data-styled.g113[id="LinkColumn__ListItem-sc-18qnqbg-0"]{content:"fLjkrG,iXDUHN,etPKim,"}/*!sc*/
# .chUtxH{color:rgb(59,65,68);-webkit-text-decoration:none;text-decoration:none;padding:2px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .chUtxH:hover{color:rgb(0,120,130);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .chUtxH div{padding-right:24px;}/*!sc*/
# @media (max-width:23.4375em){.chUtxH{line-height:25px;}}/*!sc*/
# data-styled.g114[id="LinkColumn__Link-sc-18qnqbg-1"]{content:"chUtxH,"}/*!sc*/
# .eiMzua{padding:32px 0 8px 0;}/*!sc*/
# @media (min-width:48em){.eiMzua{padding:2px 0;}}/*!sc*/
# .eiMzua a{color:rgb(59,65,68);-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .eiMzua a:hover{color:rgb(0,120,130);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g115[id="LinkColumn__LinkColumnHeading-sc-18qnqbg-2"]{content:"eiMzua,"}/*!sc*/
# .fGQGPu{position:relative;color:rgb(0,173,187);font-size:12px;line-height:1.33;padding:0;}/*!sc*/
# .fGQGPu .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:15.96px;width:15.96px;}/*!sc*/
# data-styled.g116[id="LinkColumn__ToggleMenuButton-sc-18qnqbg-3"]{content:"fGQGPu,"}/*!sc*/
# .gfYCGU{-webkit-flex:1 1 0px;-ms-flex:1 1 0px;flex:1 1 0px;margin-left:8px;}/*!sc*/
# .gfYCGU:first-child{margin-left:0;}/*!sc*/
# @media (max-width:47.9375em){.gfYCGU{-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;margin-left:0;}}/*!sc*/
# data-styled.g117[id="LinkColumn__Column-sc-18qnqbg-4"]{content:"gfYCGU,"}/*!sc*/
# .dyUsOb{padding:0 env(safe-area-inset-right) 0 env(safe-area-inset-left);}/*!sc*/
# data-styled.g118[id="NavigationSecondary__Container-sc-59f6ac-0"]{content:"dyUsOb,"}/*!sc*/
# .iagBDf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;padding:0 0 24px;}/*!sc*/
# @media (max-width:47.9375em){.iagBDf{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}/*!sc*/
# data-styled.g119[id="NavigationSecondary__Inner-sc-59f6ac-1"]{content:"iagBDf,"}/*!sc*/
# .bmseOe{padding:0 env(safe-area-inset-right) 0 env(safe-area-inset-left);}/*!sc*/
# data-styled.g120[id="FooterLinkList__Container-yuht23-0"]{content:"bmseOe,"}/*!sc*/
# .fRcNIL{color:rgb(59,65,68);-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .fRcNIL:hover{color:rgb(0,120,130);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g121[id="FooterLinkList__CookiePreferenceLink-yuht23-1"]{content:"fRcNIL,"}/*!sc*/
# .gledEB{list-style:none;display:inline-block;margin:0;padding:16px 0 16px;}/*!sc*/
# .gledEB li{display:inline;}/*!sc*/
# .gledEB li + li::before{content:'';display:inline-block;vertical-align:middle;width:4px;height:4px;border-radius:50%;background-color:currentColor;margin:0 4px 2px;}/*!sc*/
# data-styled.g122[id="FooterLinkList__LinkList-yuht23-2"]{content:"gledEB,"}/*!sc*/
# .BqcCM{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g123[id="TrademarkDisclaimer__StyedSpan-sc-1pdq8xi-0"]{content:"BqcCM,"}/*!sc*/
# .gGbtyJ{width:100%;height:64px;}/*!sc*/
# .gGbtyJ nav{border-bottom:none;}/*!sc*/
# @media (max-width:47.9375em){.gGbtyJ nav{border-bottom:1px solid rgb(232,233,234);}}/*!sc*/
# .gGbtyJ > *{z-index:100;position:fixed;}/*!sc*/
# @media (max-height:319px){.gGbtyJ > *{position:relative;}}/*!sc*/
# data-styled.g135[id="SearchResultsHeader__HeaderContainer-j4zvtf-0"]{content:"gGbtyJ,"}/*!sc*/
# .eDdhet{position:absolute;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;height:100%;}/*!sc*/
# data-styled.g140[id="Tiles__TileBackground-fk0fs3-0"]{content:"eDdhet,"}/*!sc*/
# .irebmk{background-color:rgb(232,233,234);position:relative;border-radius:8px;overflow:hidden;cursor:pointer;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;width:100%;height:100%;outline:none;}/*!sc*/
# @media (hover:hover){.irebmk{-webkit-mask-image:-webkit-radial-gradient(white,black);}.irebmk > .Tiles__TileBackground-fk0fs3-0{-webkit-transition:-webkit-transform 0.45s cubic-bezier(0.645,0.045,0.355,1);-webkit-transition:transform 0.45s cubic-bezier(0.645,0.045,0.355,1);transition:transform 0.45s cubic-bezier(0.645,0.045,0.355,1);}.irebmk:hover > .Tiles__TileBackground-fk0fs3-0{-webkit-transform:scale(1.1);-ms-transform:scale(1.1);transform:scale(1.1);}.irebmk:focus-visible{-webkit-mask-image:none;}}/*!sc*/
# .irebmk:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g141[id="Tiles__TileContainer-fk0fs3-1"]{content:"irebmk,"}/*!sc*/
# .bcrqWm{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;padding:2px 8px;border-radius:4px;background-color:rgb(232,233,234);cursor:default;}/*!sc*/
# .bcrqWm:focus{outline:none;box-shadow:0 0 1px 1px rgb(107,119,128);}/*!sc*/
# .kpWlaH{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;padding:2px 8px;border-radius:4px;background-color:rgb(232,233,234);cursor:default;font-size:14px;,,line-height:1.43;line-height:initial;}/*!sc*/
# .kpWlaH,.kpWlaH,.kpWlaH,.kpWlaH .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0,{,height:20.02px;,width:20.02px;}/*!sc*/
# .kpWlaH:focus{outline:none;box-shadow:0 0 1px 1px rgb(107,119,128);}/*!sc*/
# data-styled.g149[id="Tag__TagBase-sc-1rp6fz0-1"]{content:"bcrqWm,kpWlaH,"}/*!sc*/
# .cyuFDE{width:100%;display:inline-block;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;font-weight:bold;width:unset;border-radius:8px;background-color:rgb(255,255,255);-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;padding:8px;}/*!sc*/
# .cyuFDE:focus-within{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g157[id="Select__SelectContainer-sc-1l7enz0-0"]{content:"cyuFDE,"}/*!sc*/
# .hltsmt{position:absolute;opacity:0;width:100%;height:100%;top:0;left:0;right:0;bottom:0;cursor:pointer;-webkit-appearance:none;font-size:16px;line-height:1.5;}/*!sc*/
# .hltsmt .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# data-styled.g158[id="Select__NativeSelect-sc-1l7enz0-1"]{content:"hltsmt,"}/*!sc*/
# .hawBvf{display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# .hawBvf:first-child{margin-left:4px;}/*!sc*/
# .iBLWLK{width:284px;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# .iBLWLK:first-child{margin-left:4px;}/*!sc*/
# data-styled.g160[id="ContentSlider__StyledCell-kss2hn-0"]{content:"hawBvf,iBLWLK,"}/*!sc*/
# .btbFUe{position:relative;overflow:hidden;}/*!sc*/
# @media (max-width:35.5625em){.btbFUe .sliderControl{display:none;}}/*!sc*/
# @media (pointer:fine){.btbFUe .sliderControl{display:block;}}/*!sc*/
# data-styled.g161[id="ContentSlider__ContentSliderContainer-kss2hn-1"]{content:"btbFUe,"}/*!sc*/
# .bkUrBZ{overflow:hidden;margin:-4px;padding:4px;}/*!sc*/
# data-styled.g162[id="ContentSlider__OverflowContainer-kss2hn-2"]{content:"bkUrBZ,"}/*!sc*/
# .gGpjsg{margin-bottom:-18px;padding-bottom:18px;}/*!sc*/
# .gGpjsg::-webkit-scrollbar{display:none;}/*!sc*/
# .hNRexv{margin-bottom:-18px;padding-bottom:18px;-webkit-scroll-snap-type:proximity;-moz-scroll-snap-type:proximity;-ms-scroll-snap-type:proximity;scroll-snap-type:proximity;-webkit-scroll-snap-type:x proximity;-moz-scroll-snap-type:x proximity;-ms-scroll-snap-type:x proximity;scroll-snap-type:x proximity;-webkit-scroll-snap-points-x:repeat(284px8px});-moz-scroll-snap-points-x:repeat(284px8px});-ms-scroll-snap-points-x:repeat(284px8px});scroll-snap-points-x:repeat(284px8px});}/*!sc*/
# .hNRexv::-webkit-scrollbar{display:none;}/*!sc*/
# data-styled.g163[id="ContentSlider__ScrollContainer-kss2hn-3"]{content:"gGpjsg,hNRexv,"}/*!sc*/
# .dYxtzw{overflow:hidden;height:24px;}/*!sc*/
# data-styled.g172[id="PropertyCardFacts__FactTagContainer-k5it2k-0"]{content:"dYxtzw,"}/*!sc*/
# .jIGwyC{margin-right:4px;text-transform:uppercase;font-size:12px;line-height:1.33;}/*!sc*/
# .jIGwyC .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:15.96px;width:15.96px;}/*!sc*/
# data-styled.g173[id="PropertyCardFacts__FactTag-k5it2k-1"]{content:"jIGwyC,"}/*!sc*/
# .jDqIDV{-webkit-animation:dWTQWq linear 0.3s !important;animation:dWTQWq linear 0.3s !important;overflow:hidden;display:none;}/*!sc*/
# data-styled.g175[id="PropertyCardFacts__FactContainer-k5it2k-3"]{content:"jDqIDV,"}/*!sc*/
# .cyMyhd{margin:4px 0;border-top:1px solid rgb(205,209,212);padding-top:8px;}/*!sc*/
# data-styled.g176[id="PropertyCard__PropertyCardExtendedContentContainer-m1ur0x-0"]{content:"cyMyhd,"}/*!sc*/
# .kehSAX{text-transform:uppercase;line-height:13px;padding-bottom:4px;}/*!sc*/
# data-styled.g177[id="PropertyCard__CapitalizedText-m1ur0x-1"]{content:"kehSAX,"}/*!sc*/
# .CEYnN{width:100%;border-radius:8px;}/*!sc*/
# .CEYnN:hover{cursor:pointer;}/*!sc*/
# data-styled.g178[id="PropertyCard__InteractivePropertyCardContainer-m1ur0x-2"]{content:"CEYnN,"}/*!sc*/
# .dgzfOv{display:block;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# data-styled.g179[id="PropertyCard__StyledLink-m1ur0x-3"]{content:"dgzfOv,"}/*!sc*/
# .faCQjz{min-width:224px;width:224px;width:100%;height:100%;}/*!sc*/
# .faCQjz a,.faCQjz a:hover{color:inherit;}/*!sc*/
# data-styled.g180[id="PropertyCard__PropertyCardContainer-m1ur0x-4"]{content:"faCQjz,"}/*!sc*/
# .ZXEpq{min-width:44px;min-height:44px;width:44px;height:44px;overflow:visible;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# data-styled.g184[id="IconButton-sc-1hr6tt4-0"]{content:"ZXEpq,"}/*!sc*/
# .jVMCHF{margin-right:4px;text-transform:uppercase;background-color:rgb(255,255,255);color:rgb(5,34,134);font-size:12px;line-height:1.33;padding:2px 4px;}/*!sc*/
# .jVMCHF .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:15.96px;width:15.96px;}/*!sc*/
# .lanJOM{margin-right:4px;text-transform:uppercase;background-color:rgb(255,255,255);color:rgb(59,65,68);font-size:12px;line-height:1.33;padding:2px 4px;}/*!sc*/
# .lanJOM .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:15.96px;width:15.96px;}/*!sc*/
# data-styled.g185[id="PropertyTag-sc-5t90lx-0"]{content:"jVMCHF,lanJOM,"}/*!sc*/
# .glSOUh{position:relative;z-index:0;height:calc(100% - 104px);}/*!sc*/
# @media (max-width:35.5625em){.glSOUh{height:190px;}}/*!sc*/
# .hNiIWY{position:relative;z-index:0;height:calc(100% - 104px);}/*!sc*/
# @media (max-width:35.5625em){.hNiIWY{height:30vh;}}/*!sc*/
# data-styled.g196[id="PropertyCardMedia__PropertyCardMediaContainer-qb9jxv-0"]{content:"glSOUh,hNiIWY,"}/*!sc*/
# .kNXJNq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:80%;height:19px;overflow:hidden;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;position:absolute;top:8px;left:8px;}/*!sc*/
# data-styled.g197[id="PropertyCardMedia__PropertyTagsContainer-qb9jxv-1"]{content:"kNXJNq,"}/*!sc*/
# .kryVdE{width:50px;height:18px;position:absolute;bottom:8px;right:8px;padding:2px;border:1px solid rgb(255,255,255);background-color:rgb(255,255,255);background-image:url(https://photos.zillowstatic.com/fp/8220cbcfb33612826eba63c564991450-trulia_inf_40.jpeg);border-radius:2px;background-repeat:no-repeat;background-attachment:inherit;background-position:center;background-size:contain;}/*!sc*/
# data-styled.g198[id="PropertyCardMedia__PropertyAttributeLogoContainer-qb9jxv-2"]{content:"kryVdE,"}/*!sc*/
# .jJFkQV{position:absolute;top:0;right:0;z-index:1;}/*!sc*/
# data-styled.g200[id="PropertyCardMedia__SaveHomeButtonContainer-qb9jxv-4"]{content:"jJFkQV,"}/*!sc*/
# .hmgeux{min-height:160px;}/*!sc*/
# data-styled.g201[id="PropertyCardMedia__PhotoTileContainer-qb9jxv-5"]{content:"hmgeux,"}/*!sc*/
# .jIgnrG{position:absolute;bottom:0;left:0;padding:2px;background-color:rgba(0,0,0,0.8);color:#c5b7bc;font-size:10px;line-height:1.6;border-radius:0 0 0 8px;}/*!sc*/
# .jIgnrG .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:16px;width:16px;}/*!sc*/
# data-styled.g202[id="PropertyCardMedia__StreetViewFlagContainer-qb9jxv-6"]{content:"jIgnrG,"}/*!sc*/
# .fdsGMZ{font-size:16px;color:rgb(107,119,128);font-weight:normal;margin:0;padding-bottom:8px;}/*!sc*/
# data-styled.g207[id="SearchResultsHeadings__ResultCountText-sc-1cad3tj-1"]{content:"fdsGMZ,"}/*!sc*/
# .fexrDT{margin-left:8px;color:rgb(107,119,128);white-space:nowrap;}/*!sc*/
# data-styled.g208[id="SearchResultsHeadings__CountText-sc-1cad3tj-2"]{content:"fexrDT,"}/*!sc*/
# .icoUQD{display:inline;font-size:20px;line-height:1.2;margin-bottom:4px;}/*!sc*/
# .icoUQD .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# data-styled.g209[id="SearchResultsHeadings__StyledHeading-sc-1cad3tj-3"]{content:"icoUQD,"}/*!sc*/
# .eNbNAV{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;min-width:auto;}/*!sc*/
# .eNbNAV > button:focus,.eNbNAV a:focus{z-index:1;}/*!sc*/
# .eNbNAV > .ButtonBase-sc-14ooajz-0{margin:0;}/*!sc*/
# .eNbNAV > .ButtonBase-sc-14ooajz-0:not(:first-child){border-top-left-radius:0;border-bottom-left-radius:0;}/*!sc*/
# .eNbNAV > .ButtonBase-sc-14ooajz-0:not(:last-child){border-top-right-radius:0;border-bottom-right-radius:0;border-right:0;}/*!sc*/
# .eNbNAV > .ButtonBase-sc-14ooajz-0:focus{border-right:1px solid;}/*!sc*/
# .eNbNAV > .ButtonBase-sc-14ooajz-0:focus + .ButtonBase-sc-14ooajz-0{border-left:0;}/*!sc*/
# .eNbNAV > .PrimaryButton-sc-16zopmz-0:focus{border-right:1px solid;}/*!sc*/
# .eNbNAV > .PrimaryButton-sc-16zopmz-0:focus + .ButtonBase-sc-14ooajz-0{border-left:0;}/*!sc*/
# .eNbNAV > .PrimaryButton-sc-16zopmz-0:hover{border-right:1px solid;color:rgb(255,255,255);background-color:rgb(0,120,130);}/*!sc*/
# .eNbNAV > .PrimaryButton-sc-16zopmz-0:hover + .ButtonBase-sc-14ooajz-0{border-left:0;}/*!sc*/
# .eNbNAV > .PrimaryButton-sc-16zopmz-0:hover .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(255,255,255);}/*!sc*/
# .eNbNAV > .TertiaryButton-sc-1ve5gq4-0:focus{border-right:1px solid;}/*!sc*/
# .eNbNAV > .TertiaryButton-sc-1ve5gq4-0:focus + .ButtonBase-sc-14ooajz-0{border-left:0;}/*!sc*/
# .eNbNAV > .TertiaryButton-sc-1ve5gq4-0:hover{border-right:1px solid;color:rgb(255,255,255);background-color:rgb(217,60,35);}/*!sc*/
# .eNbNAV > .TertiaryButton-sc-1ve5gq4-0:hover + .ButtonBase-sc-14ooajz-0{border-left:0;}/*!sc*/
# .eNbNAV > .TertiaryButton-sc-1ve5gq4-0:hover .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(255,255,255);}/*!sc*/
# .eNbNAV > .PrimaryButton-sc-16zopmz-0 + .ButtonBase-sc-14ooajz-0,.eNbNAV > .TertiaryButton-sc-1ve5gq4-0 + .ButtonBase-sc-14ooajz-0,.eNbNAV > [enabled='1'] + .ButtonBase-sc-14ooajz-0{border-left-color:transparent;}/*!sc*/
# data-styled.g210[id="ButtonGroup-g55gjt-0"]{content:"eNbNAV,"}/*!sc*/
# .jKLoTy{position:relative;background-color:rgb(245,246,247);border-radius:8px;}/*!sc*/
# data-styled.g211[id="ButtonToggle__ButtonToggleContainer-xkit6c-0"]{content:"jKLoTy,"}/*!sc*/
# .xSdQe{position:relative;z-index:1;}/*!sc*/
# data-styled.g212[id="ButtonToggle__ButtonToggles-xkit6c-1"]{content:"xSdQe,"}/*!sc*/
# ...
#             Information about brokerage services
#            </a>
#            ,
#            <a class="Anchor__StyledAnchor-sc-5lya7g-1 gLFHbk" href="https://www.trec.texas.gov/sites/default/files/pdf-forms/CN%201-3.pdf" rel="noreferrer noopener nofollow" target="_blank">
#             Consumer protection notice
#            </a>
#            <br/>
#            California DRE #1522444
#           </div>
#           <div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 cTGlQX">
#            <a class="Anchor__StyledAnchor-sc-5lya7g-1 gLFHbk" href="https://www.trulia.com/info/contact-us/" rel="noreferrer noopener" target="_blank">
#             Contact Zillow, Inc Brokerage
#            </a>
#           </div>
#          </div>
#          <div class="FooterLinkList__Container-yuht23-0 bmseOe">
#           <ul class="FooterLinkList__LinkList-yuht23-2 gledEB">
#            <li>
#             Trulia Corporate
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-5lya7g-1 euBOac FooterAnchor-sc-1qyjqke-0 liYvlm" href="//www.zillowgroup.com/about-zillow-group/" rel="nofollow">
#              About Zillow Group
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-5lya7g-1 euBOac FooterAnchor-sc-1qyjqke-0 liYvlm" href="//www.zillow.com/rental-manager/resources/fair-housing-guide/" rel="nofollow">
#              Fair Housing Guide
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-5lya7g-1 euBOac FooterAnchor-sc-1qyjqke-0 liYvlm" href="//www.zillow.com/careers/" rel="nofollow">
#              Careers
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-5lya7g-1 euBOac FooterAnchor-sc-1qyjqke-0 liYvlm" href="//www.trulia.com/newsroom/" rel="nofollow">
#              Newsroom
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-5lya7g-1 euBOac FooterAnchor-sc-1qyjqke-0 liYvlm" href="https://investors.zillowgroup.com/" rel="nofollow">
#              Investor Relations
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-5lya7g-1 euBOac FooterAnchor-sc-1qyjqke-0 liYvlm" href="//www.trulia.com/terms/advertisers/" rel="nofollow">
#              Advertising Terms
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-5lya7g-1 euBOac FooterAnchor-sc-1qyjqke-0 liYvlm" href="//www.zillow.com/corp/Privacy.htm" rel="nofollow">
#              Privacy
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-5lya7g-1 euBOac FooterAnchor-sc-1qyjqke-0 liYvlm" href="//www.trulia.com/info/terms/" rel="nofollow">
#              Terms of Use
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-5lya7g-1 euBOac FooterAnchor-sc-1qyjqke-0 liYvlm" href="//www.trulia.com/info/listings-quality-policy/" rel="nofollow">
#              Listings Quality Policy
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-5lya7g-1 euBOac FooterAnchor-sc-1qyjqke-0 liYvlm" href="https://www.zillow.com/corp/SATerms.htm" rel="nofollow">
#              Subscription Terms
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-5lya7g-1 euBOac FooterAnchor-sc-1qyjqke-0 liYvlm" href="https://support.trulia.com/hc/en-us">
#              Help
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-5lya7g-1 euBOac FooterAnchor-sc-1qyjqke-0 liYvlm" href="https://privacy.zillowgroup.com/" rel="nofollow">
#              Privacy Portal
#             </a>
#            </li>
#            <li>
#             <div aria-label="Cookie Preference" class="Box__BoxElement-sc-1f5rw0h-0 bsjsJO BoxButton-sc-12vrxun-0 fAXlbl UiButton-r41csk-0 iSYPov FooterLinkList__CookiePreferenceLink-yuht23-1 fRcNIL optanon-toggle-display" role="button" tabindex="0">
#              Cookie Preference
#             </div>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-5lya7g-1 euBOac" href="https://privacy.zillowgroup.com/cookie" rel="nofollow" style="display:inline-block;vertical-align:middle" target="_blank">
#              <div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 cTGlQX">
#               <div class="MediaBlock__MediaContainer-skmvlj-0 eIkmHi">
#                <div class="MediaBlock__MediaContent-skmvlj-1 gnreBg">
#                 Do Not Sell My Personal Information
#                </div>
#                <div class="getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 ckNPAJ">
#                 <svg aria-hidden="true" aria-label="" class="svg" role="img" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
#                  <path d="M22.756 14.71l-5.11-5.775 1.993-1.762 7.725 8.73-7.693 9.005-2.022-1.728 4.963-5.81H5.56v-2.66h17.195z" fill="#869099">
#                  </path>
#                 </svg>
#                </div>
#               </div>
#              </div>
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="Accessibility__Container-vmfiy3-0 dCpGms">
#           Zillow Group is committed to ensuring digital accessibility for individuals with disabilities.  We are continuously working to improve the accessibility of our web experience for everyone,  and we welcome feedback and accommodation requests. If you wish to report an issue or seek an  accommodation, please
#           <a class="Anchor__StyledAnchor-sc-5lya7g-1 gLFHbk" href="https://support.trulia.com/hc/en-us/requests/new?ticket_form_id=360000050828" rel="nofollow">
#            let us know
#           </a>
#           .
#          </div>
#          <div class="Copyright__Container-r29r4j-0 eDgeeY">
#           Copyright ©
#           <!-- -->
#           2022
#           <!-- -->
#           Trulia, LLC. All rights reserved.
#           <a class="Anchor__StyledAnchor-sc-5lya7g-1 gLFHbk FooterAnchor-sc-1qyjqke-0 liYvlm" href="https://www.hud.gov/program_offices/fair_housing_equal_opp" rel="nofollow">
#            Equal Housing Opportunity.
#           </a>
#           <span>
#            Have a Question? Visit our
#           </span>
#           <a class="Anchor__StyledAnchor-sc-5lya7g-1 gLFHbk FooterAnchor-sc-1qyjqke-0 liYvlm" href="https://www.trulia.com/help/" rel="nofollow">
#            Help Center
#           </a>
#           to find the answer.
#          </div>
#         </footer>
#        </div>
#       </div>
#       <section aria-label="Interactive Google Map showing listings in New York, NY. Details about each listing, including address and price, can be found in the search results under the h2 heading." class="SearchResultsContentLayout__MapColumn-sc-4wj1i6-3 eHppcE" role="region">
#       </section>
#       <div class="FlexContainers__Rows-zvngfq-0 bPNugb Card-qyhhuy-0 iVrQNM FloatingCard-sc-18omfhv-0 SearchResultsFloatingNavigation__Container-sc-13e9tt7-0 jSwHWl" id="floating-navigation" spacing="none">
#        <div class="ButtonGroup-g55gjt-0 eNbNAV">
#         <button class="ButtonBase-sc-14ooajz-0 Button-sc-1ea9wz-0 SearchResultsFloatingNavigation__StyledButton-sc-13e9tt7-1 eGpOkm" data-testid="floating-nav-save-search-button" style="color:rgb(59, 65, 68)" type="button">
#          <div class="MediaBlock__MediaContainer-skmvlj-0 eIkmHi">
#           <div class="getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 jfYGaR">
#            <svg aria-hidden="true" aria-label="" class="svg" role="img" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
#             <path d="M22.083 17.453a2.66 2.66 0 0 1-.304-1.235V12.92c0-3.281-2.668-5.605-5.82-5.605-3.15 0-5.813 2.322-5.813 5.606l-.002 3.3c0 .43-.104.853-.304 1.234l-.785 1.496 13.813.001-.785-1.5zm2.356-4.533v3.298l2.826 5.395-22.61-.003 2.83-5.39v-3.3c0-5.278 4.434-8.265 8.474-8.265 4.042 0 8.48 2.988 8.48 8.265zm-8.5 14.345a3.768 3.768 0 0 1-3.769-3.768h7.537a3.768 3.768 0 0 1-3.768 3.768z" fill="#869099">
#             </path>
#            </svg>
#           </div>
#           <div class="MediaBlock__MediaContent-skmvlj-1 dwmuOU">
#            Save Search
#           </div>
#          </div>
#         </button>
#         <button class="ButtonBase-sc-14ooajz-0 Button-sc-1ea9wz-0 SearchResultsFloatingNavigation__StyledButton-sc-13e9tt7-1 eGpOkm" data-testid="floating-nav-map" type="button">
#          <div class="MediaBlock__MediaContainer-skmvlj-0 eIkmHi">
#           <div class="getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 jfYGaR">
#            <svg aria-hidden="true" aria-label="" class="svg" role="img" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
#             <path d="M13.66 12.233V22.39l4.517-3.01V9.221l-4.517 3.011zm-2.66-.11l-3.02-2.014v10.157L11 22.28V12.122zm9.837-2.9v10.156l3.103 2.07V11.29l-3.103-2.069zm-.06-3.238h.06v.04L26.6 9.867v16.551l-7.093-4.728-7.094 4.728L5.32 21.69V5.138l7.093 4.73 5.764-3.843v-.04h.06l1.27-.847 1.27.847z" fill="#869099">
#             </path>
#            </svg>
#           </div>
#           <div class="MediaBlock__MediaContent-skmvlj-1 dwmuOU">
#            Map
#           </div>
#          </div>
#         </button>
#        </div>
#       </div>
#       <span aria-live="assertive" class="ScreenReaderContent-sc-1y1ua5d-0 hPToJy">
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"abExperiments":{"1274":"a","1297":"a","1316":"b","1317":"control","1328":"b","1329":"control","1332":"b","1334":"b","1337":"b","1338":"control","1341":"b","1342":"b","1343":"b","1353":"b","1357":"b","1360":"b","1365":"b","1366":"a","1369":"a","1371":"b","1375":"b","1377":"b","1379":"b"},"abTracking":"1274a;1297a;1316b;1317_control;1328b;1329_control;1332b;1334b;1337b;1338_control;1341b;1342b;1343b;1353b;1357b;1360b;1365b;1366a;1369a;1371b;1375b;1377b;1379b","session":{"isBot":false,"userLifetimeId":"220830rhewghc6m2a2iyl6fd8evlm891","transactionId":"a0917a74-6f97-4d35-b4ef-b5e0a8c9207c","supportedMediaTypes":[],"isVisitFromSearchEngine":false,"isNonPersonalized":false,"navigatedFrom":false,"isAndroidUa":false},"_page":{"title":"New York, NY Homes For Sale \u0026 New York, NY Real Estate | Trulia","description":"23,443 Homes For Sale in New York, NY. Browse photos, see new properties, get open house info, and research neighborhoods on Trulia.","metaTags":{"robots":{"name":"robots","content":"INDEX, FOLLOW"},"ogUrl":{"property":"og:url","content":"https://www.trulia.com/NY/New_York/"},"ogDescription":{"property":"og:description","content":"23,443 Homes For Sale in New York, NY. Browse photos, see new properties, get open house info, and research neighborhoods on Trulia."},"ogTitle":{"property":"og:title","content":"New York, NY Homes For Sale \u0026 New York, NY Real Estate | Trulia"},"ogImage":{"property":"og:image","content":"https://www.trulia.com/images/logos/standardized/v4/logo-with-icon-200x200.png"},"ogImageWidth":{"property":"og:image:width","content":"200"},"ogImageHeight":{"property":"og:image:height","content":"200"}},"linkTags":{"heroImgPreload":{"rel":"preload","as":"image","href":"https://maps.googleapis.com/maps/api/streetview?size=320x240\u0026location=1120%20Brightn%20Be%20Ave%20%20%232F%20Brooklyn%20NY%2011235\u0026key=AIzaSyCzWKDOMLGYlR3C9dltAR7sbLvcQEWNcvc\u0026signature=61FTdR896_BEQi4zXqQck-9w3Wo%3D"},"mapBgImgPreload":{"rel":"preload","as":"image","href":"https://www.trulia.com/images/backgrounds/map-gray-background.png"},"androidDeeplink":{"rel":"alternate","href":"android-app://com.trulia.android/https/www.trulia.com/NY/New_York/"},"iosDeeplink":{"rel":"alternate","href":"ios-app://288487321/https/www.trulia.com/NY/New_York/"},"canonicalUrl":{"rel":"canonical","href":"https://www.trulia.com/NY/New_York/"}},"branchBanner":{"config":{"shouldDisableBanner":false,"apiKey":"key_live_pkrocc5yGCN4njTWV2CmGlapwtfdRBt8"},"bannerOptions":{"disable_entry_animation":true,"metadata":{"banner":true,"page":"srp","pageType":"for-sale-srp"},"isDirectVisit":"1"},"bannerViewData":{"data":{"city":"New York","state":"NY"}},"anonymousId":"220830rhewghc6m2a2iyl6fd8evlm891"},"ads":{"isIEAdsEnabled":true,"isPrebidAdsEnabled":true,"pageType":"trulia_srp"},"viewer":{"userStatus":null,"userType":null,"userId":null,"loggedIn":false,"name":null,"email":null,"profileImage":null,"permissions":[],"userNavigation":null,"optedOutOfSale":false,"__typename":"USER_Viewer"}},"asPath":"/NY/New_York/","searchData":{"currentUrl":"/NY/New_York/","canonicalUrl":"/NY/New_York/","adTargetings":"{\"keyVals\":{\"hybrid\":\"srpmapright\",\"city\":\"new_york\",\"state\":\"ny\",\"cnty\":\"kings\",\"dma\":\"43\",\"env\":\"prod\",\"listtp\":\"Buy_General\",\"user\":\"ojl\",\"guid\":\"220830rhewghc6m2a2iyl6fd8evlm891\",\"uid\":null,\"ppid\":\"220830rhewghc6m2a2iyl6fd8evlm891\",\"zip\":[\"11203\",\"11230\",\"10065\",\"11229\",\"11378\",\"11238\",\"11221\",\"11214\",\"10301\",\"10027\",\"11379\",\"11355\",\"11235\",\"11413\",\"10038\",\"10011\",\"11204\",\"10031\",\"10461\",\"10303\",\"10305\",\"11226\",\"10033\",\"10022\",\"10304\",\"11224\",\"10463\",\"11228\",\"10021\",\"10012\",\"11201\",\"10306\",\"11213\",\"10467\"],\"filtered\":\"false\",\"vers\":[\"class2\"]}}","location":{"city":"New York","state":"NY","__typename":"SEARCH_ResultLocationCity","boundingBox":{"minCoordinates":{"latitude":40.495865,"longitude":-74.255641,"__typename":"SEA ...
#   </script>
#   <script async="" src="https://assets.adobedtm.com/launch-EN6a2a075351da41849d53019821066484.min.js">
#   </script>
#   <script>
#    function initTracking(pageviewPayload) {
#     let count = 0;
#     const MAX_COUNT = 100;
#     window.s = window.s || {};
#     window.trulia = window.trulia || {};
#     window.trulia.dataLayer = window.trulia.dataLayer || {};
#     window.trulia.dataLayer.referrer = document.referrer;
#
#     function listenersDefined() {
#       const listeners = window.trulia.dataLayer.listeners;
#       return typeof listeners !== 'undefined' && listeners.length !== 0;
#     }
#
#     const queue = [];
#
#     const track = function (event, data, isInitialPageView) {
#       if (processQueue()) {
#         handleEvent(event, data, isInitialPageView);
#       } else {
#         queue.push({
#           event: event,
#           data: data,
#           isInitialPageView: isInitialPageView
#         });
#       }
#     };
#
#     const handleEvent = function (event, data, isInitialPageView) {
#       if (isInitialPageView) {
#         window.s.referrer = window.trulia.dataLayer.referrer;
#       }
#
#       trulia.dataLayer.listeners.forEach(function (listener) {
#         listener(event, data);
#       });
#     };
#
#     const processQueue = function () {
#       if (listenersDefined()) {
#         if (queue.length) {
#           let queuedData;
#
#           while (queuedData = queue.shift()) {
#             handleEvent(queuedData.event, queuedData.data, queuedData.isInitialPageView);
#           }
#         }
#
#         return true;
#       }
#
#       if (count <= MAX_COUNT) {
#         setTimeout(processQueue, 300);
#         count += 1;
#       }
#
#       return false;
#     };
#
#     if (pageviewPayload) {
#       track('trackState', pageviewPayload, true);
#     }
#
#     window.trulia.dataLayer.track = track;
#   }
#           initTracking(null);
#   </script>
#   <script>
#    (function() {
#                 window._pxAppId = 'PXYO6YjwLb';
#                 // Custom parameters
#                 // window._pxParam1 = "<param1>";
#                 var p = document.getElementsByTagName('script')[0],
#                     s = document.createElement('script');
#                 s.async = 1;
#                 s.src = '//client.px-cloud.net/PXYO6YjwLb/main.min.js';
#                 p.parentNode.insertBefore(s, p);
#             }());
#   </script>
#   <noscript>
#    <div height="1" style="position:fixed;top:0;left:0;display:none" width="1">
#     <img alt="px pixel" src="//collector-PXYO6YjwLb.px-cloud.net/api/v1/collector/noScript.gif?appId=PXYO6YjwLb"/>
#    </div>
#   </noscript>
#  </body>
# </html>

# %% [markdown]
# ### Results

# %%
result = soup.find_all('li', {'class' : 'Grid__CellBox-sc-144isrp-0 SearchResultsList__WideCell-b7y9ki-2 jiZmPM'})

# %%
len(result)
# Out:
# 42

# %% [markdown]
# ### Get Only the RIght Result

# %%
result_update = [i for i in result if i.has_attr('data-testid')]

# %%
len(result_update)
# Out:
# 40

# %% [markdown]
# ### Get the Attribute

# %%
address = [result.find('div', {'data-testid':'property-address'}).get_text() for result in result_update]
beds = [result.find('div', {'data-testid':'property-beds'}).get_text() for result in result_update]
baths = [result.find('div', {'data-testid':'property-baths'}).get_text() for result in result_update]
prices = [result.find('div', {'data-testid':'property-price'}).get_text() for result in result_update]

# %% [markdown]
# ### Make a DataFrame

# %%
real_estate = pd.DataFrame(columns=['Address', 'Beds', 'Baths', 'Price'])

for i in range (len(address)):
    real_estate=real_estate.append({'Address':address[i], 'Beds':beds[i], 'Baths':baths[i], 'Price':prices[i]}, ignore_index=True)

# %%
real_estate
# Out:
#                                               Address    Beds Baths  \
# 0             469 E  49th St   #6, Brooklyn, NY 11203    10bd   6ba
# 1                    715 Avenue L, Brooklyn, NY 11230     8bd   6ba
# 2                  223 E  62nd St, New York, NY 10065     5bd   6ba
# 3           1824 E  17th St   #B2, Brooklyn, NY 11229     2bd   2ba
# 4                 52-15 65th Pl #3D, Queens, NY 11378     2bd   1ba
# 5                 432 Carlton Ave, Brooklyn, NY 11238     7bd   4ba
# 6          1143 Lafayette Ave #3B, Brooklyn, NY 11221     1bd   1ba
# 7                  43 Bay 25th St, Brooklyn, NY 11214     6bd   4ba
# 8             155 Bay St #5B, Staten Island, NY 10301     2bd   2ba
# 9             18 W  127th St   #1, New York, NY 10027     7bd   5ba
# 10             6204 77th Pl, Middle Village, NY 11379     4bd   2ba
# 11        133-07 41st Ave UNIT 4B, Flushing, NY 11355     1bd   1ba
# 12       1120 Brightn Be Ave  #2F, Brooklyn, NY 11235     1bd   1ba
# 13  131-11 Francis Lewis Blvd, Springfield Gardens...     3bd   3ba
# 14               33 Park Row  #7A, New York, NY 10038     1bd   2ba
# 15           46 Lefferts Pl   #2R, Brooklyn, NY 11238  Studio   1ba
# 16            137 W  12th St #5-1, New York, NY 10011     1bd   1ba
# 17                   2102 65th St, Brooklyn, NY 11204     6bd   3ba
# 18            441 Convent Ave #1C, New York, NY 10031     1bd   1ba
# 19            441 Convent Ave #3M, New York, NY 10031     1bd   1ba
# 20                1464 William Place, Bronx, NY 10461     5bd   4ba
# 21       269 Maple Pkwy #128, Staten Island, NY 10303     2bd   1ba
# 22           59 Vera St   #C, Staten Island, NY 10305     1bd   1ba
# 23             145 Erasmus Street, Brooklyn, NY 11226     4bd   3ba
# 24            120 Bennett Ave #2A, New York, NY 10033     1bd   1ba
# 25            418 E  59th St #30A, New York, NY 10022     2bd   3ba
# 26             199 Mosel Ave, Staten Island, NY 10304     2bd   2ba
# 27          3734 Oceanic Ave  #A2, Brooklyn, NY 11224     3bd   3ba
# 28           124 Van Cortlandt Ave W, Bronx, NY 10463     4bd   3ba
# 29                   1572 85th St, Brooklyn, NY 11228     7bd   5ba
# 30             315 E  72nd St #4M, New York, NY 10021     1bd   1ba
# 31          214 Mulberry St   #3D, New York, NY 10012  Studio   1ba
# 32                 51 Jay St   #B, Brooklyn, NY 11201     4bd   5ba
# 33             18 Taunton St, Staten Island, NY 10306     4bd   3ba
# 34            1065 Sterling Place, Brooklyn, NY 11213     6bd   4ba
# 35             750 Park Ave  #4BC, New York, NY 10021     4bd   4ba
# 36           601 Pelham Pkwy N  #516, Bronx, NY 10467     1bd   1ba
# 37               750 Park Ave #4C, New York, NY 10021     2bd   2ba
# 38              750 Park Ave #4-B, New York, NY 10021     1bd   2ba
# 39                4704 Burling St, Flushing, NY 11355     5bd   3ba
#
#          Price
# 0   $1,250,000
# 1   $1,690,000
# 2   $7,995,000
# 3     $579,000
# 4     $469,000
# 5   $2,450,000
# 6     $650,000
# 7   $2,299,000
# 8     $599,000
# 9   $3,500,000
# 10    $860,000
# 11    $525,000
# 12    $325,000
# 13    $750,000
# 14  $2,175,000
# 15    $550,000
# 16    $675,000
# 17  $1,480,000
# 18    $463,000
# 19    $535,000
# 20    $829,999
# 21    $299,000
# 22    $235,000
# 23    $995,000
# 24    $399,000
# 25  $1,560,000
# 26    $568,000
# 27    $549,000
# 28    $910,000
# 29  $2,280,000
# 30    $795,000
# 31    $750,000
# 32  $7,000,000
# 33  $1,150,000
# 34  $2,100,000
# 35  $3,800,000
# 36    $230,000
# 37  $1,500,000
# 38  $1,900,000
# 39  $1,499,000

# %% [markdown]
# ### Get 5 Pages

# %%
real_estate_new=pd.DataFrame(columns=['Address', 'Beds', 'Baths', 'Area', 'Price'])

address=[]
beds=[]
baths=[]
areas=[]
prices=[]

web = ['https://www.trulia.com/NY/New_York/',
      'https://www.trulia.com/CA/Los_Angeles/',
      'https://www.trulia.com/IL/Chicago/',
      'https://www.trulia.com/AZ/Phoenix/',
      'https://www.trulia.com/NV/Las_Vegas/']

for h in web:
    for i in range (1,21):
        website = requests.get(h + str(i) + '_p/', headers=headers)

        soup = BeautifulSoup(website.content, 'html.parser')

        result = soup.find_all('li', {'class' : 'Grid__CellBox-sc-144isrp-0 SearchResultsList__WideCell-b7y9ki-2 jiZmPM'})

        result_update = [k for k in result if k.has_attr('data-testid')]

        for result in result_update:

            try:
                address.append(result.find('div', {'data-testid':'property-address'}).get_text())
            except:
                address.append('n/a')

            try:
                beds.append(result.find('div', {'data-testid':'property-beds'}).get_text())
            except:
                beds.append('n/a')

            try:
                baths.append(result.find('div', {'data-testid':'property-baths'}).get_text())
            except:
                baths.append('n/a')    

            try:
                areas.append(result.find('div', {'data-testid':'property-floorSpace'}).get_text())
            except:
                areas.append('n/a')  

            try:
                prices.append(result.find('div', {'data-testid':'property-price'}).get_text())
            except:
                prices.append('n/a')      

        for j in range (len(address)):
            real_estate_new=real_estate_new.append({'Address':address[j], 'Beds':beds[j], 'Baths':baths[j], 'Area':areas[j], 'Price':prices[j]}, ignore_index=True)

# %%
real_estate_new
# Out:
#                                                   Address  Beds Baths  \
# 0          4-74 48th Ave  #9K, Long Island City, NY 11109   1bd   1ba
# 1                 469 E  49th St   #6, Brooklyn, NY 11203  10bd   6ba
# 2                        715 Avenue L, Brooklyn, NY 11230   8bd   6ba
# 3                      223 E  62nd St, New York, NY 10065   5bd   6ba
# 4               1824 E  17th St   #B2, Brooklyn, NY 11229   2bd   2ba
# ...                                                   ...   ...   ...
# 208145  Crimson Plan 524 in Watercolor, North Las Vega...   3bd   3ba
# 208146  Crimson Plan 523 in Watercolor, North Las Vega...   3bd   3ba
# 208147  Sienna Plan 512 in Watercolor, North Las Vegas...   3bd   2ba
# 208148  Indigo Plan 544 in Watercolor, North Las Vegas...   3bd   3ba
# 208149  Crimson Plan 522 in Watercolor, North Las Vega...   3bd   3ba
#
#               Area       Price
# 0         700 sqft    $555,000
# 1              n/a  $1,250,000
# 2       2,015 sqft  $1,690,000
# 3       3,750 sqft  $7,995,000
# 4         888 sqft    $579,000
# ...            ...         ...
# 208145  1,366 sqft   $327,990+
# 208146  1,352 sqft   $327,990+
# 208147  1,347 sqft   $311,990+
# 208148  2,023 sqft   $426,990+
# 208149  1,372 sqft   $342,990+
#
# [208150 rows x 5 columns]

# %%
# dataframe info
real_estate_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208150 entries, 0 to 208149
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Address  208150 non-null  object
#  1   Beds     208150 non-null  object
#  2   Baths    208150 non-null  object
#  3   Area     208150 non-null  object
#  4   Price    208150 non-null  object
# dtypes: object(5)
# memory usage: 7.9+ MB

# %%
#first 5 results
real_estate_new.head()
# Out:
#                                           Address  Beds Baths        Area  \
# 0  4-74 48th Ave  #9K, Long Island City, NY 11109   1bd   1ba    700 sqft
# 1         469 E  49th St   #6, Brooklyn, NY 11203  10bd   6ba         n/a
# 2                715 Avenue L, Brooklyn, NY 11230   8bd   6ba  2,015 sqft
# 3              223 E  62nd St, New York, NY 10065   5bd   6ba  3,750 sqft
# 4       1824 E  17th St   #B2, Brooklyn, NY 11229   2bd   2ba    888 sqft
#
#         Price
# 0    $555,000
# 1  $1,250,000
# 2  $1,690,000
# 3  $7,995,000
# 4    $579,000

# %% [markdown]
# ### Data Cleaning

# %%
real_estate_new['Beds'] = real_estate_new['Beds'].apply(lambda x: x.strip('bd'))
real_estate_new['Baths'] = real_estate_new['Baths'].apply(lambda x: x.strip('ba'))
real_estate_new['Price'] = real_estate_new['Price'].apply(lambda x: x.strip('$'))
real_estate_new['Price'] = real_estate_new['Price'].apply(lambda x: x.replace(",",""))
real_estate_new['Price'] = real_estate_new['Price'].apply(lambda x: x.replace("+",""))
real_estate_new['Area'] = real_estate_new['Area'].apply(lambda x: x.replace(" sqft",""))

real_estate_new['Street']=real_estate_new['Address'].apply(lambda x: x.split(',')[0])
real_estate_new['District']=real_estate_new['Address'].apply(lambda x: x.split(',')[1])
real_estate_new['City']=real_estate_new['Address'].apply(lambda x: x.split(',')[2].split(' ')[1])
real_estate_new['Zip Code']=real_estate_new['Address'].apply(lambda x: x.split(',')[2].split(' ')[2])

# %%
real_estate_new.describe()
# Out:
#                                     Address    Beds   Baths    Area   Price  \
# count                                208150  208150  208150  208150  208150
# unique                                 4080      25      19    1919    1466
# top     1170 Ocean Pkwy, Brooklyn, NY 11230       3       2     n/a  799000
# freq                                    188   57838   70888   39019    2932
#
#                        Street  District    City Zip Code
# count                  208150    208150  208150   208150
# unique                   4060       164       7      477
# top     Address Not Disclosed   Chicago      NY    85339
# freq                      899     38193   73534     2250

# %%
real_estate_new
# Out:
#                                                   Address Beds Baths   Area  \
# 0          4-74 48th Ave  #9K, Long Island City, NY 11109    1     1    700
# 1                 469 E  49th St   #6, Brooklyn, NY 11203   10     6    n/a
# 2                        715 Avenue L, Brooklyn, NY 11230    8     6  2,015
# 3                      223 E  62nd St, New York, NY 10065    5     6  3,750
# 4               1824 E  17th St   #B2, Brooklyn, NY 11229    2     2    888
# ...                                                   ...  ...   ...    ...
# 208145  Crimson Plan 524 in Watercolor, North Las Vega...    3     3  1,366
# 208146  Crimson Plan 523 in Watercolor, North Las Vega...    3     3  1,352
# 208147  Sienna Plan 512 in Watercolor, North Las Vegas...    3     2  1,347
# 208148  Indigo Plan 544 in Watercolor, North Las Vegas...    3     3  2,023
# 208149  Crimson Plan 522 in Watercolor, North Las Vega...    3     3  1,372
#
#           Price                          Street           District City  \
# 0        555000              4-74 48th Ave  #9K   Long Island City   NY
# 1       1250000             469 E  49th St   #6           Brooklyn   NY
# 2       1690000                    715 Avenue L           Brooklyn   NY
# 3       7995000                  223 E  62nd St           New York   NY
# 4        579000           1824 E  17th St   #B2           Brooklyn   NY
# ...         ...                             ...                ...  ...
# 208145   327990  Crimson Plan 524 in Watercolor    North Las Vegas   NV
# 208146   327990  Crimson Plan 523 in Watercolor    North Las Vegas   NV
# 208147   311990   Sienna Plan 512 in Watercolor    North Las Vegas   NV
# 208148   426990   Indigo Plan 544 in Watercolor    North Las Vegas   NV
# 208149   342990  Crimson Plan 522 in Watercolor    North Las Vegas   NV
#
#        Zip Code
# 0         11109
# 1         11203
# 2         11230
# 3         10065
# 4         11229
# ...         ...
# 208145    89086
# 208146    89086
# 208147    89086
# 208148    89086
# 208149    89086
#
# [208150 rows x 9 columns]

# %%
real_estate_new.to_csv('Dataset Real Estate.csv')
