# %% [markdown]
# ### Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd 
import urllib.parse

# %% [markdown]
# ### Put all together

# %%
# create dataframe (in the beginning it is empty)
df_restaurant = pd.DataFrame(columns=['Restaurant Name', 'Address', 'Phone', 'Email', 'Homepage', 'Info'])

# sequence of numbers - 1 to 3 (4 is not included)
for i in range(1,4):

    # varibale for pages withing website
    website = 'https://www.yellowpages.com/search?search_terms=restaurant&geo_location_terms=San Francisco, CA&page=' + str(i)

    # request
    response = requests.get(website)
    
    # create soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # result container
    result_container = soup.find_all('div', {'class':'result'})
    
    # URL Part 1
    url_part_1 = 'https://www.yellowpages.com/'
    
    url_part_2 = []

    # loop through results
    for item in result_container:
        
    # loop through links
        for link in item.find_all('a', {'class': 'business-name'}):
            url_part_2.append(link.get('href'))
    
    # Join URL 1 and URL 2 in order to get the abosolute URL
    url_joined = []

    for link_2 in url_part_2:
        url_joined.append(urllib.parse.urljoin(url_part_1, link_2))
        
        
    # loop through all joined links
    for link in url_joined:
        response = requests.get(link)

        # create soup object
        soup = BeautifulSoup(response.content, 'html.parser')

        # name
        try:
            name = soup.find('h1').get_text()
        except:
            name = 'n/a'

        # address 
        try:
            address = soup.find('h2', {'class': 'address'}).get_text()
        except:
            address = 'n/a'

        # phone
        try:
            phone = soup.find('p', {'class':'phone'}).get_text()
        except:
            phone = 'n/a'

        # email
        try:
            email = soup.find('a', {'class': 'email-business'}).get('href').split('mailto:')[1]
        except:
            email = 'n/a'

        # website
        try:
            website = soup.find('a', {'class': 'website-link'}).get('href')
        except:
            website = 'n/a'

        # general info
        try:
            info = soup.find('dd', {'class': 'general-info'}).get_text()
        except:
            info = 'n/a'
            
        # Pandas Dataframe
        df_restaurant = df_restaurant.append({'Restaurant Name': name, 'Address':address, 'Phone': phone,
                                             'Email':email, 'Homepage': website, 'Info': info}, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# ~\Anaconda3\envs\tensorflow_env\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     751     addrlist = []
# --> 752     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     753         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\connection.py in connect(self)
#     308         # Add certificate verification
# --> 309         conn = self._new_conn()
#     310         hostname = self.host
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     171             raise NewConnectionError(
# --> 172                 self, "Failed to establish a new connection: %s" % e
#     173             )
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x00000257348E7688>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     726             retries = retries.increment(
# --> 727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     728             )
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     445         if new_retry.is_exhausted():
# --> 446             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     447
#
# MaxRetryError: HTTPSConnectionPool(host='www.yellowpages.com', port=443): Max retries exceeded with url: /search?search_terms=restaurant&geo_location_terms=San%20Francisco,%20CA&page=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000257348E7688>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-4-1e436dde2f61> in <module>
#       9
#      10     # request
# ---> 11     response = requests.get(website)
#      12
#      13     # create soup object
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.yellowpages.com', port=443): Max retries exceeded with url: /search?search_terms=restaurant&geo_location_terms=San%20Francisco,%20CA&page=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000257348E7688>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %% [markdown]
# ### Output Pandas Dataframe

# %%
df_restaurant
# Out:
#                          Restaurant Name  \
# 0                                Mr. K's
# 1   Potjanee Thai Restaurant of New York
# 2              Spoonfed New York Country
# 3               Da Noi Midtown Manhattan
# 4                  Seven's Turkish Grill
# ..                                   ...
# 85                            Indian Taj
# 86                   Rocco's Pizza Joint
# 87                               Juniors
# 88            Moonstruck East Restaurant
# 89                      Steamers Landing
#
#                                               Address           Phone  \
# 0                 570 Lexington AveNew York, NY 10022  (212) 583-1668
# 1                     48 Carmine StNew York, NY 10014  (212) 558-9071
# 2                     331 W 51st StNew York, NY 10019  (718) 789-3048
# 3                     214 E 49th StNew York, NY 10017  (347) 955-0067
# 4                     158 W 72nd StNew York, NY 10023  (212) 724-4700
# ..                                                ...             ...
# 85                  181 Bleecker StNew York, NY 10012  (212) 982-0810
# 86                      162 7th AveNew York, NY 10011  (212) 633-9555
# 87                    1515 BroadwayNew York, NY 10036  (212) 302-2000
# 88                      449 3rd AveNew York, NY 10016  (212) 213-1100
# 89  Between Liberty & Albany On The The Hudson Riv...  (212) 432-1451
#
#                     Email                                           Homepage  \
# 0   info@movingmaninc.com                              http://www.mrksny.com
# 1   mthitna2011@gmail.com                                http://potjanee.net
# 2   randy@spoonfednyc.com            http://www.spoonfed.nyc/contact-us.html
# 3       info@danoinyc.com         http://danoinyc.com/midtown-manhattan.html
# 4                     n/a                                                n/a
# ..                    ...                                                ...
# 85   info@indiantajny.com                             http://indiantajny.com
# 86        Cola148@aol.com                 http://www.roccospizzajointnyc.com
# 87                    n/a  https://www.juniorscheesecake.com/blog/restaur...
# 88                    n/a        http://moonstruck.nyc/locations/449-3rd-ave
# 89                    n/a                     http://www.steamerslanding.com
#
#                                                  Info
# 0   We offer exclusive seating to you and your par...
# 1   If you're looking for authentic Thai food in N...
# 2                                                 n/a
# 3   High quality dining, elegant private parties a...
# 4   Here at Seven's Mediterranean Turkish Grill we...
# ..                                                ...
# 85                                                n/a
# 86   NYC's Best Pizza. Specialty Coffee, Chelsea, NYC
# 87                                                n/a
# 88                                                n/a
# 89                                                n/a
#
# [90 rows x 6 columns]

# %% [markdown]
# ### Store in Excel

# %%
df_restaurant.to_excel('results_multiple_pages.xlsx', index=False)
