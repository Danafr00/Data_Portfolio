# %% [markdown]
# ### Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd 
import urllib.parse

# %% [markdown]
# ### HTTP Request

# %% [markdown]
# #### store website in variable

# %%
website = 'https://www.yellowpages.com/search?search_terms=restaurant&geo_location_terms=New+York%2C+NY'

# %% [markdown]
# #### Get Request

# %%
response = requests.get(website)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# ~\Anaconda3\envs\tensorflow_env\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     751     addrlist = []
# --> 752     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     753         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\connection.py in connect(self)
#     308         # Add certificate verification
# --> 309         conn = self._new_conn()
#     310         hostname = self.host
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     171             raise NewConnectionError(
# --> 172                 self, "Failed to establish a new connection: %s" % e
#     173             )
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x000001D5F6158848>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     726             retries = retries.increment(
# --> 727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     728             )
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     445         if new_retry.is_exhausted():
# --> 446             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     447
#
# MaxRetryError: HTTPSConnectionPool(host='www.yellowpages.com', port=443): Max retries exceeded with url: /search?search_terms=restaurant&geo_location_terms=New+York%2C+NY (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D5F6158848>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-3-3a060f508d8c> in <module>
# ----> 1 response = requests.get(website)
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.yellowpages.com', port=443): Max retries exceeded with url: /search?search_terms=restaurant&geo_location_terms=New+York%2C+NY (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D5F6158848>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %% [markdown]
# #### Status Code

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ### Soup Object

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta content="utf-8" name="charset"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width" name="viewport"/><title>Best 30 Restaurant in New York, NY with Reviews - YP.com</title><meta content="Popular &amp; reviewed Restaurant in New York, NY. Find reviews, menus, or even order online - THE REAL YELLOW PAGES®" name="description"/><meta content="noindex, follow" name="robots"/><meta content="app-id=284806204, app-argument=ypmobile://srp?search_category=restaurant&amp;latitude=40.7142691&amp;longitude=-74.0059729" name="apple-itunes-app"/><meta content="website" property="og:type"/><meta content="Best 30 Restaurant in New York, NY with Reviews - YP.com" property="og:title"/><meta content="Popular &amp; reviewed Restaurant in New York, NY. Find reviews, menus, or even order online - THE REAL YELLOW PAGES®" property="og:description"/><meta content="//i1.ypcdn.com/ypu/images/logo-yp.png?546cbad" property="og:image"/><meta content="600" property="og:image:width"/><meta content="315" property="og:image:height"/><meta content="https://www.yellowpages.com/new-york-ny/restaurant" property="og:url"/><meta content="https://www.yellowpages.com/new-york-ny/restaurant" property="twitter:url"/><meta content="summary" property="twitter:card"/><meta content="www.yellowpages.com" property="twitter:domain"/><meta content="@YP" property="twitter:site"/><meta content="//i1.ypcdn.com/ypu/images/logo-yp.png?546cbad" property="twitter:image"/><meta content="Best 30 Restaurant in New York, NY with Reviews - YP.com" property="twitter:title"/><meta content="Popular &amp; reviewed Restaurant in New York, NY. Find reviews, menus, or even order online - THE REAL YELLOW PAGES®" property="twitter:description"/><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam-cell.nr-data.net","errorBeacon":"bam-cell.nr-data.net","licenseKey":"a7bc01046c","applicationID":"7805046,7804101","applicationTime":1281.98828,"transactionName":"MgRSZBMFXkMHVhZdWgtOc0USEF9dSUYQRA==","queueTime":0,"ttGuid":"eae5516d7917e8","agentToken":null}; (window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:false}};(window.NREUM||(NREUM={})).loader_config={xpid:"XAAAVUVUAAMFVFVU",licenseKey:"a7bc01046c",applicationID:"7805046"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var i,o=t("ee"),a=t(25),s={};try{i=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,i.indexOf("dev")!==-1&&(s.dev=!0),i.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&o.on("internal-error",function(t){r(t.stack)}),s.dev&&o.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{p?p-=1:i(s||new UncaughtException(t,e,n),!0)}catch(f){try{o("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function i(t,e){var n=e?null:c.now();o("err",[t,n])}var o=t("handle"),a=t(26),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError";if(!c.disabled){var p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(9),t(8),"addEventListener"in window&&t(5),c.xhrWrappable&&t(10),d=!0)}s.on("fn-start",function(t,e,n){d&&(p+=1)}),s.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,i(n))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){o("ierr",[t,c. ...
# UserLoggedIn   = false;
# source         = "";
# Tracking       = {"lwes":{"rid":"webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7","ptid":"www.yellowpages.com","aid":"webyp","eaid":"YPU","enc":1,"version":"10844","vrid":"e1ab5c58-dcc7-47ab-adaf-d6aa98aa0165","v":1,"referrer":"","ua":"python-requests/2.24.0","uip":"91.8.122.184","url":"https://www.yellowpages.com/search?search_terms=restaurant&geo_location_terms=New+York%2C+NY","eid":"7de72471-8afa-4b46-9a41-bea9cf2aa25c","ypcst_base_url":"https://c.ypcdn.com"},"yext":{"PID":"4Diy12y2qo","TRACK_URL":"https://pl.yext.com/plpixel"},"supermedia":{"SUPERMEDIA_HOST":"api.superpages.com"},"dexmedia":{"SUPERMEDIA_HOST":"api.superpages.com"},"citysearch":{"CITYSEARCH_IMP_TRACKER":"https://api.citygridmedia.com/ads/tracker/imp"},"tripadvisor":{"TRIPADVISOR_HOST":"https://www.tripadvisor.com/img/cdsi/partner/transparent_pixel-32908-3-en_US.gif"},"dex":{"DEX_REDIRECTOR_HOST":"http://www.dexknows.com/rd/index.asp","TRACK_URL":"https://api.superpages.com/xml/search","SRC":"ypintfeed"},"host":"www.yellowpages.com","page_id":1,"pageName":"search_results","pageNumber":1,"app_id":"webyp","vrid":"e1ab5c58-dcc7-47ab-adaf-d6aa98aa0165","rid":"webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7","request_id":"webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7","ip":"91.8.122.184","search_terms":"restaurant","env":"prod","location":{"geo_term":"New York, NY","lat":40.7142691,"lng":-74.0059729,"city":"New York","state":"NY","display_geo":"New York, NY","slug":"new-york-ny","display_header":"New York","display_title":"New York, New York"},"dks":"fc794596-a3fc-40bd-ad61-b9808ab6763a","user_agent":"python-requests/2.24.0","botData":{"isMobile":false,"isTablet":false,"isiPad":false,"isiPod":false,"isiPhone":false,"isAndroid":false,"isBlackberry":false,"isOpera":false,"isIE":false,"isIECompatibilityMode":false,"isSafari":false,"isFirefox":false,"isWebkit":false,"isChrome":false,"isKonqueror":false,"isOmniWeb":false,"isSeaMonkey":false,"isFlock":false,"isAmaya":false,"isEpiphany":false,"isDesktop":false,"isWindows":false,"isLinux":false,"isLinux64":false,"isMac":false,"isChromeOS":false,"isBada":false,"isSamsung":false,"isRaspberry":false,"isBot":false,"isCurl":false,"isAndroidTablet":false,"isWinJs":false,"isKindleFire":false,"isSilk":false,"silkAccelerated":false,"browser":"unknown","os":"unknown","platform":"unknown","geoIp":{},"source":"python-requests/2.24.0","isiOS":false},"referrer":"","remote_ip":"","dex_dks":"","dex_dkdt":"","dex_click_img":"","current_geo_terms":"","ipf_click_host":"","visitor_month":"","visitor_week":"","trafficSegment":"","user_type":"","omnitureServer":"yellowpagesglobal","orig_src":false,"currentBucket":"ypu:ypu:header-a","bucket":"ypu:ypu:header-a","sgt":"ypu:ypu:header-a","url":"https://www.yellowpages.com/search?search_terms=restaurant&geo_location_terms=New+York%2C+NY","mybook":{},"platform":"Web","platformExperience":"desktop","deviceType":"desktop web browser device type","searchforce":{"SEARCH_FORCE_HOST":"sftrack.searchforce.net/SFConversionTracking/img.jpg"},"ptid":"www.yellowpages.com"};
# YPFB           = {"appId":"150853628282807"};
# YPGoogle       = {"adsense":{},"maps":{},"plus":{"clientId":"257161415943-pb2742i46njs5kdta4p1jco0cnq7ss66.apps.googleusercontent.com"}};
# YPU            = {"googleJsApi":"https://maps.googleapis.com/maps/api/js?channel=web&callback=YPU.initializeGoogleMaps&v=3.38&key=AIzaSyAFLfj_UY3XBrQzlSRf_QbnUJRnLvxKh5Q","ASSET_HOST":"i2.ypcdn.com","MEDIA_ASSET_HOST":"i1.ypcdn.com","REVISION":"546cbad","geoLocation":{"formattedAddress":"New York, NY","address":"","city":"New York","state":"NY","stateName":"New York","latitude":40.7142691,"longitude":-74.0059729,"geoType":"city","zips":[],"neighborhood":"","radius":5000,"directories":["NRKNY","YBURMZ","NYCMZ","NYST","NATL"]},"srpSortTerm":"relevance","isMapView":false,"pageTracking":{"geo_term":"New York, NY","feature_impression":"tripadvisor,menu,RLP,bbb,open-now,open-24hr,preferred,orderonline-spm,orderonline-spv,website,custom-link,phone-no,address,ga_106,ga_31,article,Helpful","total_catExp":0,"total_center_listings":30,"total_top_listings":1,"total_center_ads":6,"total_right_listings":10,"total_center_free":24,"search_terms":"restaurant","vertical":"RESTAURANT","search_type":"category","heading_code":"8009371","page_number":1,"feature_impression_view":["filter_close"],"refinement_type":"default","products":";407372;;;event67=1|event68=0|event69=1|event70=0;eVar76=1:1:1|eVar77=ad|eVar78=8004222|eVar79=1001117676060,;475254262;;;event67=1|event68=0|event69=1|event70=0;eVar76=1:2:1|eVar77=ad|eVar78=8004279|eVar79=1001874845727,;482175847;;;event67=1|event68=0|event69=1|event70=0;eVar76=1:3:1|eVar77=ad|eVar78=8009371|eVar79=1000647207573,;533587405;;;event67=1|event68=0|event69=1|event70=0;eVar76=1:4:1|eVar77=ad|eVar78=8004287|eVar79=1001682503857,;460080517;;;event67=1|event68=0|event69=1|event70=0;eVar76=1:5:1|eVar77=ad|eVar78=8004266|eVar79=1000439722148,;5642814;;;event67=1|event68=0|event69=1|event70=0;eVar76=1:6:1|eVar77=ad|eVar78=8004225|eVar79=1001105931107,;28771538;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:7:1|eVar77=free|eVar78=8004199|eVar79=28771538,;458844388;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:8:1|eVar77=free|eVar78=8016124|eVar79=458844388,;285698;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:9:1|eVar77=free|eVar78=8004225|eVar79=285698,;15362553;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:10:1|eVar77=free|eVar78=8004282|eVar79=15362553,;6255318;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:11:1|eVar77=free|eVar78=8005357|eVar79=6255318,;8526127;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:12:1|eVar77=free|eVar78=8004199|eVar79=8526127,;1275150;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:13:1|eVar77=free|eVar78=8004282|eVar79=1275150,;462462383;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:14:1|eVar77=free|eVar78=8004285|eVar79=462462383,;3030157;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:15:1|eVar77=free|eVar78=8004161|eVar79=3030157,;3306782;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:16:1|eVar77=free|eVar78=8004225|eVar79=3306782,;8889637;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:17:1|eVar77=free|eVar78=8004199|eVar79=8889637,;2388948;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:18:1|eVar77=free|eVar78=8004225|eVar79=2388948,;11139387;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:19:1|eVar77=free|eVar78=8004282|eVar79=11139387,;16097243;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:20:1|eVar77=free|eVar78=8002304|eVar79=16097243,;10705734;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:21:1|eVar77=free|eVar78=8004199|eVar79=10705734,;459052000;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:22:1|eVar77=free|eVar78=8004199|eVar79=459052000,;2659878;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:23:1|eVar77=free|eVar78=8016124|eVar79=2659878,;12325724;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:24:1|eVar77=free|eVar78=8004222|eVar79=12325724,;450845415;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:25:1|eVar77=free|eVar78=8004287|eVar79=450845415,;3465042;;;event67=0|event68=1|event69=1|event70=0;eVar76=1:26:1|eVar77=free|eVar78=8004199|eVar79=3465042,;10889409;;;event67=0|event68=1|event69= ...
# </script><script src="//i1.ypcdn.com/ypu/vendor/VisitorAPI.js?546cbad"></script><script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script><script type="text/javascript">var gptadslots = [];
# var googletag = googletag || {};
#
# googletag.cmd = googletag.cmd || [];
# </script><script type="text/javascript">googletag.cmd.push(function() {
#     if (document.cookie.indexOf('optOut')!== -1) {
#         googletag.pubads().setPrivacySettings({'restrictDataProcessing': true });
#     }
#     //Adslot 1 declaration
#     gptadslots.push(googletag.defineSlot('/53532708/ca-pub-3200418779552017-tag/YP-Serp-300', [[300, 250]], 'div-gpt-ad-1553116728289-0')
#                            .addService(googletag.pubads()).setTargeting('us_privacy', '%%PATTERN:pubs_custom_key_for_us_privacy%%'));
#     //Adslot 2 declaration
#     gptadslots.push(googletag.defineSlot('/53532708/ca-pub-3200418779552017-tag/YP-Serp-300-BTF', [[300, 250]], 'div-gpt-ad-1555631981784-0')
#                            .addService(googletag.pubads()).setTargeting('us_privacy', '%%PATTERN:pubs_custom_key_for_us_privacy%%'));
#     //Adslot 3 declaration
#     gptadslots.push(googletag.defineSlot('/53532708/ca-pub-3200418779552017-tag/YP-SERP-728', [[728, 90]], 'div-gpt-ad-1555630445292-0')
#                .addService(googletag.pubads()).setTargeting('us_privacy', '%%PATTERN:pubs_custom_key_for_us_privacy%%'));
#     googletag.pubads().setTargeting('YP_category', ['8009371']);
#     googletag.pubads().enableSingleRequest();
#     googletag.pubads().setTargeting('pubs_custom_key_for_us_privacy', '138315278567');
#     googletag.enableServices();
# });
# </script><link href="//i4.ypcdn.com/ypu/images/favicon.ico?546cbad" rel="icon shortcut"/><link href="//i3.ypcdn.com/ypu/images/apple-touch-icon-precomposed.png?546cbad" rel="apple-touch-icon-precomposed" type="image/x-icon"/><link href="//i3.ypcdn.com/ypu/css/common.min.css?546cbad" rel="stylesheet" type="text/css"/><script src="//i2.ypcdn.com/ypu/vendor/essentials.bundle.js?546cbad"></script><script async="async" src="https://www.google.com/adsense/search/ads.js"></script><script charset="utf-8" type="text/javascript">(function(g,o){g[o]=g[o]||function(){(g[o]['q']=g[o]['q']||[]).push(
# arguments)},g[o]['t']=1*new Date})(window,'_googCsa');</script><script src="//i3.ypcdn.com/ypu/js/compiled/srp_adsense.js?546cbad"></script><link href="https://www.yellowpages.com/new-york-ny/restaurant?page=2" rel="next"><link href="//i1.ypcdn.com/ypu/css/csrp.min.css?546cbad" rel="stylesheet" type="text/css"/><noscript><link href="//i1.ypcdn.com/uitl/web/itl_widget.css?546cbad" rel="stylesheet" type="text/css"/></noscript><script>(function() {
#     function loadDeferredCss() {
#         var lazyStyleElm = document.createElement('link');
#         lazyStyleElm.rel = 'stylesheet';
#         lazyStyleElm.href = '//i1.ypcdn.com/uitl/web/itl_widget.css?546cbad';
#         lazyStyleElm.type = 'text/css';
#         var deferCss = document.getElementsByTagName('link')[0];
#         deferCss.parentNode.insertBefore(lazyStyleElm, deferCss);
#     }
#
#     if (window.addEventListener) {
#         window.addEventListener('load', loadDeferredCss, false);
#     } else if (window.attachEvent) {
#         window.attachEvent('onload', loadDeferredCss);
#     } else {
#         window.onload = loadDeferredCss;
#     }
# })();</script><link href="//i3.ypcdn.com/ypu/css/csrp/food_search.min.css?546cbad" rel="stylesheet" type="text/css"/><!--[if IE]><link type='text/css' rel='stylesheet' href="//i3.ypcdn.com/ypu/css/ie.min.css?546cbad"/><![endif]--><script>ValidationJSON = {};
# </script><script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function()
# { (i[r].q=i[r].q||[]).push(arguments)}
# ,i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# var optOut;
# if (document.cookie.indexOf('optOut') !== -1) {
#     optOut = document.cookie.split('optOut=')[1].split(';')[0];
# }
#
# ga('create', 'UA-9709876-1', 'auto');
# ga('require', 'displayfeatures');
# if (optOut) {
#     ga('set', 'allowAdPersonalizationSignals', false);
#     ga('set', 'dimension1', 'true' );
# } else {
#     ga('set', 'allowAdPersonalizationSignals', true);
#     ga('set', 'dimension1', 'false' );
# }
# ga('send', 'pageview');</script><script>!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '886701991493531');
# fbq('track', 'PageView');</script><noscript><img alt="" height="1" src="https://www.facebook.com/tr?id=886701991493531&amp;ev=PageView&amp;noscript=1" width="1"/></noscript><script>TripAdvisor = {};
# if (typeof newrelic !== 'undefined') {
#     newrelic.setPageViewName('/srp');
# }
# </script></link></head><body><svg class="hide" height="0" viewbox="0 0 0 0" width="0" xmlns="http://www.w3.org/2000/svg"
/roadside-assistance">Roadside Assistance</a><a href="https://www.yellowpages.com/new-york-ny/tire-shops">Tire Shops</a><a href="https://www.yellowpages.com/new-york-ny/towing">Towing</a><a href="https://www.yellowpages.com/new-york-ny/window-tinting">Window Tinting</a></div></div><div class="browse-cat" id="beauty"><div class="category-name"><img alt="Browse beauty" src="//i2.ypcdn.com/ypu/images/svgs/beauty.svg?546cbad">beauty</img></div><div class="category-links"><a href="https://www.yellowpages.com/new-york-ny/barber-shops">Barber Shops</a><a href="https://www.yellowpages.com/new-york-ny/beauty-salons">Beauty Salons</a><a href="https://www.yellowpages.com/new-york-ny/beauty-supplies">Beauty Supplies</a><a href="https://www.yellowpages.com/new-york-ny/day-spas">Day Spas</a><a href="https://www.yellowpages.com/new-york-ny/facial-salons">Facial Salons</a><a href="https://www.yellowpages.com/new-york-ny/hair-removal">Hair Removal</a><a href="https://www.yellowpages.com/new-york-ny/hair-supplies">Hair Supplies</a><a href="https://www.yellowpages.com/new-york-ny/hair-stylists">Hair Stylists</a><a href="https://www.yellowpages.com/new-york-ny/massage">Massage</a><a href="https://www.yellowpages.com/new-york-ny/nail-salons">Nail Salons</a></div></div><div class="browse-cat" id="home-services"><div class="category-name"><img alt="Brow ...
# <path d="M3-1c-3.9 0-7 3.1-7 7 0 5.2 7 13 7 13s7-7.8 7-13C10 2.1 6.9-1 3-1zM3 8.5C1.6 8.5 0.5 7.4 0.5 6S1.6 3.5 3 3.5 5.5 4.6 5.5 6 4.4 8.5 3 8.5z"></path>
# </svg><span>Where?</span><input autocomplete="off" data-onempty="menu-location" id="location" name="geo_location_terms" placeholder="Where?" type="text" value="New York, NY"/></label><ul class="search-dropdown menu-location" id="menu-location"><li class="current-location"><a href="#" id="menu-location-link">Use My Location</a></li></ul><ul class="search-dropdown autosuggest-location" id="autosuggest-location"></ul></div><button data-analytics='{"click_id":101,"searchbox":"Standard_Searchbox"}' type="submit" value="Find">Find</button></form></div><nav class="user-links"><div class="signed-out"><a data-analytics='{"click_id":164}' href="/login">Log In</a><span class="divider">•</span><a data-analytics='{"click_id":165}' href="/register">Sign Up</a></div></nav></div></header><div class="hide" id="privacy-policy-notice"><div id="pp-container"><p>Please note our privacy policy has changed. To view the policy, please go to <a href="https://corporate.thryv.com/privacy/" id="link-pp-notice" rel="nofollow noopener" target="_blank">https://corporate.thryv.com/privacy/</a></p><div id="close-pp-notice"><svg height="15" viewbox="0 0 15 15" width="15" xmlns="http://www.w3.org/2000/svg"><line x1="0" x2="15" y1="0" y2="15"></line><line x1="0" x2="15" y1="15" y2="0"></line></svg></div></div></div><div id="content-container"><!--------------------- CSRP Template === Restaurant Search ---------------><div class="srp list-view restaurant-search header-a has-related-articles has-helpful-reviews" id="content"><svg class="hide" height="0" viewbox="0 0 20 21" width="0" xmlns="http://www.w3.org/2000/svg"><symbol><path d="
# " height="100" src="https://i3.ypcdn.com/blob/c34e2901edfb966b565d36f5d8199a1b8b1a656f_100x100_crop.jpg?546cbad
# " width="100"/><noscript><img alt="Mr. K's" asset_type="blob_api" class="csrp" height="100" src="https://i3.ypcdn.com/blob/c34e2901edfb966b565d36f5d8199a1b8b1a656f_100x100_crop.jpg?546cbad
# " width="100"/></noscript></a></div><div class="info"><h2 class="n">1. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/mr-ks-407372?lid=1001117676060" rel=""><span>Mr. K's</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaurants">Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/chinese-restaurants">Chinese Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/banquet-halls-reception-facilities">Banquet Halls &amp; Reception Facilities</a></div><div class="ratings" data-israteable="true"><a class="rating" data-analytics='{"click_id":22,"listing_features":"ratings"}' href="/new-york-ny/mip/mr-ks-407372?lid=1001117676060#yp-rating"><div class="result-rating four"><span class="count">(27)</span></div></a></div><div class="badges"><div class="years-in-business"><div class="count"><div class="number">25</div></div><span>YEARS<br/>IN BUSINESS</span></div></div><div class="links"><a class="track-visit-website" data-analytics='{"click_id":6,"act":2,"dku":"http://www.mrksny.com","FL":"url","target":"website","LOC":"http://www.mrksny.com","adclick":true,"iid":"9db185cb-859f-4b3c-8cae-db27561f3d25"}' href="http://www.mrksny.com" rel="nofollow noopener" target="_blank">Website</a><a class="track-map-it directions" data-analytics='{"click_id":13,"target":"website","act":4,"adclick":true,"iid":"9db185cb-859f-4b3c-8cae-db27561f3d25"}' href="/listings/1001117676060/directions">Directions</a><a class="menu" data-analytics='{"click_id":1614,"target":"menus","listing_features":"menu-link"}' href="/listings/407372/menu?lid=1001117676060">Services</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(212) 583-1668</div><p class="adr"><div class="street-address">570 Lexington Ave</div><div class="locality">New York, NY 10022</div></p></div><div class="snippet"><figure class="color-4"><svg height="16" viewbox="0 0 22 22" width="16" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#default-avatar"></use></svg></figure><p class="body with-avatar">Great tasty food, good service, large portions, affordable per person. The staff is neat, the room is clean.</p></div><div class="listing-ctas"><a class="action order-online" data-analytics='{"adclick":true,"events":"event7,event5","category":"8004222","impression_id":"9db185cb-859f-4b3c-8cae-db27561f3d25","listing_id":"1001117676060","item_id":-1,"listing_type":"sub","ypid":"407372","content_provider":"IY","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-407372","item_type":"SPM","lhc":"8004222","ldir":"NRKNY","rate":4,"hasTripAdvisor":false,"pid":"800000001503987347","mip_claimed_status":"mip_unclaimed","mip_ypid":"407372","click_id":523,"listing_features":"orderonline"}' href="http://redirect.singleapi.com/?trackingId=sp-l1259836-t1-p17-rNVZC223TFUYTO===" rel="nofollow noopener" target="_blank"><svg xmlns="http://www.w3.org/2000/svg"><use xlink:href="#order-online"></use></svg>Order Online</a></div></div></div></div></div><div class="result" data-analytics='{"adclick":true,"events":"event7,event5","category":"8004279","impression_id":"bb68b1ba-680a-46b5-8ecf-05394c15c183","listing_id":"1001874845727","item_id":-1,"listing_type":"sub","ypid":"475254262","content_provider":"RD","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-475254262","item_type":"listing","lhc":"8004279","ldir":"NRKNY","rate":3.5,"hasTripAdvisor":true,"pid":"800000002288085821","mip_claimed_status":"mip_unclaimed","mip_ypid":"475254262","rating":"advertiser","listing_index":2,"tier":50,"poi":2,"rank":2,"act":1,"features":"website,reviews,menu,phone,tripadvisor" ...
# " height="100" src="https://i3.ypcdn.com/blob/6970e92017832f34f9a139d11051c9501af79592_100x100_crop.jpg?546cbad
# " width="100"/><noscript><img alt="Potjanee Thai Restaurant of New York" asset_type="blob_api" class="csrp" height="100" src="https://i3.ypcdn.com/blob/6970e92017832f34f9a139d11051c9501af79592_100x100_crop.jpg?546cbad
# " width="100"/></noscript></a></div><div class="info"><h2 class="n">2. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/potjanee-thai-restaurant-of-new-york-475254262?lid=1001874845727" rel=""><span>Potjanee Thai Restaurant of New York</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaurants">Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/asian-restaurants">Asian Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/thai-restaurants">Thai Restaurants</a></div><div class="ratings" data-israteable="true" data-tripadvisor='{"rating":"4.5","count":"24"}'><a class="rating hasExtraRating" data-analytics='{"click_id":22,"listing_features":"ratings"}' href="/new-york-ny/mip/potjanee-thai-restaurant-of-new-york-475254262?lid=1001874845727#yp-rating"><div class="result-rating three half"><span class="count">(5)</span></div></a></div><div class="badges"><div class="years-in-business"><div class="count"><div class="number">11</div></div><span>YEARS<br/>IN BUSINESS</span></div><div class="years-with-yp"><div class="count"><div class="number">3</div></div><span>YEARS <br/> WITH</span><img src="//i3.ypcdn.com/ypu/images/svgs/ypIcon.svg?546cbad"/></div></div><div class="links"><a class="track-visit-website" data-analytics='{"click_id":6,"act":2,"dku":"http://potjanee.net","FL":"url","target":"website","LOC":"http://potjanee.net","adclick":true,"iid":"bb68b1ba-680a-46b5-8ecf-05394c15c183"}' href="http://potjanee.net" rel="nofollow noopener" target="_blank">Website</a><a class="track-map-it directions" data-analytics='{"click_id":13,"target":"website","act":4,"adclick":true,"iid":"bb68b1ba-680a-46b5-8ecf-05394c15c183"}' href="/listings/1001874845727/directions">Directions</a><a class="menu" data-analytics='{"click_id":1614,"target":"menus","listing_features":"menu-link"}' href="/listings/475254262/menu?lid=1001874845727">View Menu</a><a class="track-more-info" data-analytics='{"click_id":7,"target":"moreInfo","act":1,"FL":"list","adclick":true,"iid":"bb68b1ba-680a-46b5-8ecf-05394c15c183"}' href="/new-york-ny/mip/potjanee-thai-restaurant-of-new-york-475254262?lid=1001874845727">More Info</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(212) 558-9071</div><p class="adr"><div class="street-address">48 Carmine St</div><div class="locality">New York, NY 10014</div></p></div><div class="snippet"><figure class="color-2"><svg height="16" viewbox="0 0 22 22" width="16" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#default-avatar"></use></svg></figure><p class="body with-avatar">This is a family owned restaurant, they took over what was known as Morakote restaurant back in 2007 and changed its name to Potjanee Thai…</p></div><div class="listing-ctas"></div></div></div></div></div><div class="result" data-analytics='{"adclick":true,"events":"event7,event5","category":"8009371","impression_id":"f9c94739-b927-429e-b116-109d0cc835f5","listing_id":"1000647207573","item_id":-1,"listing_type":"sub","ypid":"482175847","content_provider":"GUMP","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-482175847","item_type":"listing","lhc":"8009371","ldir":"NRKNY","rate":0,"hasTripAdvisor":false,"pid":"800000001027261646","mip_claimed_status":"mip_claimed","mip_ypid":"482175847","rating":"advertiser","listing_index":3,"tier":30,"poi":3,"rank":3,"act":1,"features":"website,menu,phone,preferred","impression":1,"content_partner_id":"GUMP"}' data-impressionid="f9c94739-b927-429e-b116-109d0cc835f5" data-ypid="482175847" id="lid-482175847"><div class="srp-listing clickable-area gump" data-anal ...
# " height="100" src="https://i3.ypcdn.com/blob/de4bae0c86f07cdd35db94b34a4e476c9e66ea01_100x100_crop.jpg?546cbad
# " width="100"/><noscript><img alt="Babbo" asset_type="blob_api" class="csrp" height="100" src="https://i3.ypcdn.com/blob/de4bae0c86f07cdd35db94b34a4e476c9e66ea01_100x100_crop.jpg?546cbad
# " width="100"/></noscript></a></div><div class="info"><h2 class="n">9. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/babbo-285698" rel=""><span>Babbo</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaurants">Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/italian-restaurants">Italian Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/mediterranean-restaurants">Mediterranean Restaurants</a></div><div class="ratings" data-israteable="true" data-tripadvisor='{"rating":"4.0","count":"1941"}'><a class="rating hasExtraRating" data-analytics='{"click_id":22,"listing_features":"ratings"}' href="/new-york-ny/mip/babbo-285698#yp-rating"><div class="result-rating four"><span class="count">(232)</span></div></a></div><div class="badges"><div class="years-in-business"><div class="count"><div class="number">23</div></div><span>YEARS<br/>IN BUSINESS</span></div></div><div class="links"><a class="track-visit-website" data-analytics='{"click_id":6,"act":2,"dku":"https://www.babbonyc.com","FL":"url","target":"website","LOC":"https://www.babbonyc.com","adclick":true,"iid":"fbdcf27a-23da-44d7-9956-7f5d794f09fa"}' href="https://www.babbonyc.com" rel="nofollow noopener" target="_blank">Website</a><a class="menu" data-analytics='{"click_id":1614,"target":"menus","listing_features":"menu-link"}' href="/listings/285698/menu?lid=285698">View Menu</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(212) 777-0303</div><p class="adr"><div class="street-address">110 Waverly Pl Frnt A</div><div class="locality">New York, NY 10011</div></p></div><div class="snippet"><figure class="color-2">VN</figure><p class="body with-avatar">Their food is good but I think they need to improve on waiting time. Ive waited for almost an hour before they serve my orders. I almost starve to…</p></div><div class="listing-ctas"></div></div></div></div></div><div class="result" data-analytics='{"adclick":true,"events":"event7,event6","category":"8004282","impression_id":"e2d502f0-d96f-4aac-9f03-5516a119bb50","listing_id":"15362553","item_id":-1,"listing_type":"free","ypid":"15362553","content_provider":"MDM","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-15362553","item_type":"listing","lhc":"8004282","ldir":"NRKNY","rate":4,"hasTripAdvisor":true,"mip_claimed_status":"mip_unclaimed","mip_ypid":"15362553","rating":"free","listing_index":10,"tier":999,"poi":10,"rank":10,"act":1,"features":"website,reviews,menu,phone,tripadvisor","impression":1,"content_partner_id":"MDM"}' data-impressionid="e2d502f0-d96f-4aac-9f03-5516a119bb50" data-ypid="15362553" id="lid-15362553"><div class="srp-listing clickable-area mdm" data-analytics='{"click_id":1600,"category":"8004282","tier":999}' data-bcnt="0"><div class="v-card"><div class="media-thumbnail"><a class="media-thumbnail-wrapper photo" data-analytics='{"click_id":1499,"features":"photo-gallery"}' href="/new-york-ny/mip/sparks-steak-house-15362553?lid=15362553#gallery"><img alt="Sparks Steak House" asset_type="blob_api" class="no-tracks lazy" data-original="https://i3.ypcdn.com/blob/b9fe661dc5be830385672a86f340e1c34b309464_100x100_crop.jpg?546cbad
# " height="100" src="https://i3.ypcdn.com/blob/b9fe661dc5be830385672a86f340e1c34b309464_100x100_crop.jpg?546cbad
# " width="100"/><noscript><img alt="Sparks Steak House" asset_type="blob_api" class="csrp" height="100" src="https://i3.ypcdn.com/blob/b9fe661dc5be830385672a86f340e1c34b309464_100x100_crop.jpg?546cbad
# " width="100"/></noscript></a></div><div class="info"><h2 class="n">10. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/sparks-steak-house-15362553" rel=""><span>Sparks Steak House</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaurants">Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/steak-houses">Steak Houses</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/barbecue-restaurants">Barbecue Restaurants</a></div><div class="ratings" data-israteable="true" data-tripadvisor='{"rating":"4.0","count":"1421"}'><a class="rating hasExtraRating" data-analytics='{"click_id":22,"listing_features":"ratings"}' href="/new-york-ny/mip/sparks-steak-house-15362553#yp-rating"><div class="result-rating four"><span class="count">(110)</span></div></a></div><div class="badges"><div class="years-in-business"><div class="count"><div class="number">26</div></div><span>YEARS<br/>IN BUSINESS</span></div></div><div class="links"><a class="track-visit-website" data-analytics='{"click_id":6,"act":2,"dku":"http://www.sparkssteakhouse.com","FL":"url","target":"website","LOC":"http://www.sparkssteakhouse.com","adclick":true,"iid":"e2d502f0-d96f-4aac-9f03-5516a119bb50"}' href="http://www.sparkssteakhouse.com" rel="nofollow noopener" target="_blank">Website</a><a class="menu" data-analytics='{"click_id":1614,"target":"menus","listing_features":"menu-link"}' href="/listings/15362553/menu?lid=15362553">View Menu</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(212) 687-4855</div><p class="adr"><div class="street-address">210 E 46th St</div><div class="locality">New York, NY 10017</div></p></div><div class="snippet"><img alt="User Avatar" class="lazy avatar" data-original="https://graph.facebook.com/314095142311670/picture?height=32&amp;width=32" height="32" width="32"/><p class="body with-avatar">I've been there and It's Awesome! The Staff we're so approachable, nice management, thank you for good catering. Very much appreciated.</p></div><div class="listing-ctas"></div></div></div></div></div><div class="result" data-analytics='{"adclick":true,"events":"event7,event6","category":"8005357","impression_id":"467f0984-3302-4897-87f5-e3f5260eebf1","listing_id":"6255318","item_id":-1,"listing_type":"free","ypid":"6255318","content_provider":"MDM","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-6255318","item_type":"listing","lhc":"8005357","ldir":"NRKNY","rate":4.5,"hasTripAdvisor":false,"mip_claimed_status":"mip_unclaimed","mip_ypid":"6255318","rating":"free","listing_index":11,"tier":999,"poi":11,"rank":11,"act":1,"features":"website,reviews,menu,phone","impression":1,"content_partner_id":"MDM"}' data-impressionid="467f0984-3302-4897-87f5-e3f5260eebf1" data-ypid="6255318" id="lid-6255318"><div class="srp-listing clickable-area mdm" data-analytics='{"click_id":1600,"category":"8005357","tier":999}' data-bcnt="0"><div class="v-card"><div class="media-thumbnail"><a class="media-thumbnail-wrapper default" data-analytics='{"click_id":509}' href="/new-york-ny/mip/bianca-6255318"><img alt="Bianca" height="100" src="//i3.ypcdn.com/ypu/images/default-thumbnails/thumbnail-3.svg?546cbad" width="100"/></a></div><div class="info"><h2 class="n">11. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/bianca-6255318" rel=""><span>Bianca</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaur ...
# " height="100" src="https://i3.ypcdn.com/blob/311bd4d42d003ccd0b77192a6866ad653489d7e9_100x100_crop.jpg?546cbad
# " width="100"/><noscript><img alt="Blind Pig" asset_type="blob_api" class="csrp" height="100" src="https://i3.ypcdn.com/blob/311bd4d42d003ccd0b77192a6866ad653489d7e9_100x100_crop.jpg?546cbad
# " width="100"/></noscript></a></div><div class="info"><h2 class="n">12. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/blind-pig-8526127" rel=""><span>Blind Pig</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaurants">Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/american-restaurants">American Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/bar-grills">Bar &amp; Grills</a></div><div class="ratings" data-israteable="true" data-tripadvisor='{"rating":"4.5","count":"26"}'><a class="rating hasExtraRating" data-analytics='{"click_id":22,"listing_features":"ratings"}' href="/new-york-ny/mip/blind-pig-8526127#yp-rating"><div class="result-rating four"><span class="count">(53)</span></div></a></div><div class="badges"><div class="years-in-business"><div class="count"><div class="number">21</div></div><span>YEARS<br/>IN BUSINESS</span></div></div><div class="links"><a class="track-visit-website" data-analytics='{"click_id":6,"act":2,"dku":"http://www.blindpigbar.com","FL":"url","target":"website","LOC":"http://www.blindpigbar.com","adclick":true,"iid":"102d8dd5-bfed-47eb-b218-f3ed5e1b0996"}' href="http://www.blindpigbar.com" rel="nofollow noopener" target="_blank">Website</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(212) 209-1573</div><p class="adr"><div class="street-address">233 E 14th St Frnt 1</div><div class="locality">New York, NY 10003</div></p></div><div class="snippet"><figure class="color-2"><svg height="16" viewbox="0 0 22 22" width="16" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#default-avatar"></use></svg></figure><p class="body with-avatar">Great bar food and pleasant bar staff. The drinks were fantastic also.</p></div><div class="listing-ctas"></div></div></div></div></div><div class="result" data-analytics='{"adclick":true,"events":"event7,event6","category":"8004282","impression_id":"ac2d0560-4e70-4754-b047-8b1799f3a673","listing_id":"1275150","item_id":-1,"listing_type":"free","ypid":"1275150","content_provider":"MDM","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-1275150","item_type":"listing","lhc":"8004282","ldir":"NRKNY","rate":4,"hasTripAdvisor":true,"mip_claimed_status":"mip_unclaimed","mip_ypid":"1275150","rating":"free","listing_index":13,"tier":999,"poi":13,"rank":13,"act":1,"features":"website,reviews,menu,phone,tripadvisor,orderonline-spm","impression":1,"content_partner_id":"MDM"}' data-impressionid="ac2d0560-4e70-4754-b047-8b1799f3a673" data-ypid="1275150" id="lid-1275150"><div class="srp-listing clickable-area mdm" data-analytics='{"click_id":1600,"category":"8004282","tier":999}' data-bcnt="0"><div class="v-card"><div class="media-thumbnail"><a class="media-thumbnail-wrapper photo" data-analytics='{"click_id":1499,"features":"photo-gallery"}' href="/new-york-ny/mip
wi">Milwaukee</a><a href="/new-york-ny">New York</a><a href="/oklahoma-city-ok">Oklahoma City</a><a href="/orlando-fl">Orlando</a><a href="/philadelphia-pa">Philadelphia</a><a href="/phoenix-az">Phoenix</a><a href="/saint-louis-mo">Saint Louis</a></div></section><section class="corporate-family"><header>YP<sup>SM</sup> Family</header><a href="https://corporate.thryv.com" rel="noopener" target="_blank" title="Corporate Site">Corporate Site</a><a data-analytics='{"click_id":458}' href="https://marketing.yellowpages.com/en/?from=advertise-with-us-YP" title="Marketing Solutions">Marketing Solutions</a><a href="https://www.anywho.com" rel="noopener" target="_blank" title="AnyWho">AnyWho</a></section></div><div class="social-links row"><a class="facebook" data-analytics='{"click_id":2363}' href="https://facebook.com/yp" rel="nofollow noopener" target="_blank" title="Like YP on Facebook">Like us on Facebook</a><a class="twitter" data-analytics='{"click_id":2364}' href="https://twitter.com/YP" rel="nofollow  ...
#     function loadDeferredScripts() {
#         var js = ["//i2.ypcdn.com/ypu/js/compiled/tripadvisor.js?546cbad"];
#         for (var i = 0; i < js.length; i++) {
#             var el = document.createElement('script');
#             el.src = js[i];
#             document.body.appendChild(el);
#         }
#     }
#     if (window.addEventListener) {
#         window.addEventListener('load', loadDeferredScripts, false);
#     } else if (window.attachEvent) {
#         window.attachEvent('onload', loadDeferredScripts);
#     } else {
#         window.onload = loadDeferredScripts;
#     }
# })();</script><script>/*! LAB.js (LABjs :: Loading And Blocking JavaScript)
#     v2.0.3 (c) Kyle Simpson
#     MIT License
# */
# (function(o){var K=o.$LAB,y="UseLocalXHR",z="AlwaysPreserveOrder",u="AllowDuplicates",A="CacheBust",B="BasePath",C=/^[^?#]*\//.exec(location.href)[0],D=/^\w+\:\/\/\/?[^\/]+/.exec(C)[0],i=document.head||document.getElementsByTagName("head"),L=(o.opera&&Object.prototype.toString.call(o.opera)=="[object Opera]")||("MozAppearance"in document.documentElement.style),q=document.createElement("script"),E=typeof q.preload=="boolean",r=E||(q.readyState&&q.readyState=="uninitialized"),F=!r&&q.async===true,M=!r&&!F&&!L;function G(a){return Object.prototype.toString.call(a)=="[object Function]"}function H(a){return Object.prototype.toString.call(a)=="[object Array]"}function N(a,c){var b=/^\w+\:\/\//;if(/^\/\/\/?/.test(a)){a=location.protocol+a}else if(!b.test(a)&&a.charAt(0)!="/"){a=(c||"")+a}return b.test(a)?a:((a.charAt(0)=="/"?D:C)+a)}function s(a,c){for(var b in a){if(a.hasOwnProperty(b)){c[b]=a[b]}}return c}function O(a){var c=false;for(var b=0;b<a.scripts.length;b++){if(a.scripts[b].ready&&a.scripts[b].exec_trigger){c=true;a.scripts[b].exec_trigger();a.scripts[b].exec_trigger=null}}return c}function t(a,c,b,d){a.onload=a.onreadystatechange=function(){if((a.readyState&&a.readyState!="complete"&&a.readyState!="loaded")||c[b])return;a.onload=a.onreadystatechange=null;d()}}function I(a){a.ready=a.finished=true;for(var c=0;c<a.finished_listeners.length;c++){a.finished_listeners[c]()}a.ready_listeners=[];a.finished_listeners=[]}function P(d,f,e,g,h){setTimeout(function(){var a,c=f.real_src,b;if("item"in i){if(!i[0]){setTimeout(arguments.callee,25);return}i=i[0]}a=document.createElement("script");if(f.type)a.type=f.type;if(f.charset)a.charset=f.charset;if(h){if(r){e.elem=a;if(E){a.preload=true;a.onpreload=g}else{a.onreadystatechange=function(){if(a.readyState=="loaded")g()}}a.src=c}else if(h&&c.indexOf(D)==0&&d[y]){b=new XMLHttpRequest();b.onreadystatechange=function(){if(b.readyState==4){b.onreadystatechange=function(){};e.text=b.responseText+"\n//@ sourceURL="+c;g()}};b.open("GET",c);b.send()}else{a.type="text/cache-script";t(a,e,"ready",function(){i.removeChild(a);g()});a.src=c;i.insertBefore(a,i.firstChild)}}else if(F){a.async=false;t(a,e,"finished",g);a.src=c;i.insertBefore(a,i.firstChild)}else{t(a,e,"finished",g);a.src=c;i.insertBefore(a,i.firstChild)}},0)}function J(){var l={},Q=r||M,n=[],p={},m;l[y]=true;l[z]=false;l[u]=false;l[A]=false;l[B]="";function R(a,c,b){var d;function f(){if(d!=null){d=null;I(b)}}if(p[c.src].finished)return;if(!a[u])p[c.src].finished=true;d=b.elem||document.createElement("script");if(c.type)d.type=c.type;if(c.charset)d.charset=c.charset;t(d,b,"finished",f);if(b.elem){b.elem=null}else if(b.text){d.onload=d.onreadystatechange=null;d.text=b.text}else{d.src=c.real_src}i.insertBefore(d,i.firstChild);if(b.text){f()}}function S(c,b,d,f){var e,g,h=function(){b.ready_cb(b,function(){R(c,b,e)})},j=function(){b.finished_cb(b,d)};b.src=N(b.src,c[B]);b.real_src=b.src+(c[A]?((/\?.*$/.test(b.src)?"&_":"?_")+~~(Math.random()*1E9)+"="):"");if(!p[b.src])p[b.src]={items:[],finished:false};g=p[b.src].items;if(c[u]||g.length==0){e=g[g.length]={ready:false,finished:false,ready_listeners:[h],finished_listeners:[j]};P(c,b,e,((f)?function(){e.ready=true;for(var a=0;a<e.ready_listeners.length;a++){e.ready_listeners[a]()}e.ready_listeners=[]}:function(){I(e)}),f)}else{e=g[0];if(e.finished){j()}else{e.finished_listeners.push(j)}}}function v(){var e,g=s(l,{}),h=[],j=0,w=false,k;function T(a,c){a.ready=true;a.exec_trigger=c;x()}function U(a,c){a.ready=a.finished=true;a.exec_trigger=null;for(var b=0;b<c.scripts.length;b++){if(!c.scripts[b].finished)return}c.finished=true;x()}function x(){while(j<h.length){if(G(h[j])){try{h[j++]()}catch(err){}continue}else if(!h[j].finished){if(O(h[j]))continue;break}j++}if(j==h.length){w=false;k=false}}function V(){if(!k||!k.scripts){h.push(k={scripts:[],finished:true})}}e={script:function(){for(var f=0;f<arguments.length;f++){(function(a,c){var b;if(!H(a)){c=[a]}for(var d=0;d<c.length;d++){V();a=c[d];i ...
#     function loadDeferredScripts() {
#         var js = ["//i2.ypcdn.com/ypu/js/compiled/srp.js?546cbad"];
#         for (var i = 0; i < js.length; i++) {
#             var el = document.createElement('script');
#             el.src = js[i];
#             document.body.appendChild(el);
#         }
#     }
#     if (window.addEventListener) {
#         window.addEventListener('load', loadDeferredScripts, false);
#     } else if (window.attachEvent) {
#         window.attachEvent('onload', loadDeferredScripts);
#     } else {
#         window.onload = loadDeferredScripts;
#     }
# })();</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"/","name":"Home"}},{"@type":"ListItem","position":2,"item":{"@id":"/new-york-ny","name":"New York, NY"}},{"@type":"ListItem","position":3,"item":{"@id":"/new-york-ny/restaurant","name":"Restaurant"}}]}</script><script type="application/ld+json">{"@context":"https://schema.org","@type":"CollectionPage","accessMode":"auditory, tactile, textual, visual, textOnVisual","publisher":"Yellow Pages","mainEntity":{"@type":"ItemList","itemListElement":[{"@type":"ItemPage","name":"Mr. K's","url":"https://www.yellowpages.com/new-york-ny/mip/mr-ks-407372?lid=1001117676060"},{"@type":"ItemPage","name":"Potjanee Thai Restaurant of New York","url":"https://www.yellowpages.com/new-york-ny/mip/potjanee-thai-restaurant-of-new-york-475254262?lid=1001874845
js?546cbad"];
#         for (var i = 0; i < js.length; i++) {
#             var el = document.createElement('script');
#             el.src = js[i];
#             document.body.appendChild(el);
#         }
#     }
#     if (window.addEventListener) {
#         window.addEventListener('load', loadDeferredScripts, false);
#     } else if (window.attachEvent) {
#         window.attachEvent('onload', loadDeferredScripts);
#     } else {
#         window.onload = loadDeferredScripts;
#     }
# })();</script><img alt="" class="beacon" height="1" src="https://c.ypcdn.com/ta1/e1ab5c58-dcc7-47ab-adaf-d6aa98aa0165" width="1"/><script>(function() {
#     function sendNewRelicPerformanceMetrics() {
#         // normalize the browsers
#         const performance = window.performance || window.webkitPerformance || window.msPerformance || window.mozPerformance;
#         const timing = performance.timing;
#         const metrics = {};
#         // IE bug https://gist.github.com/acdha/365f7bc0e10d2e7b7865
#         if (!timing.navigationStart) {
#             return;
#         }
#
#         // Timestamp for the request start
#         metrics.navigationStart = timing.navigationStart;
#         // Time To First Byte
#         metrics.timeToFirstByte = timing.responseStart - timing.navigationStart;
#
#         // Timestamp and duration of First Paint For Chrome
#         if (window.chrome && window.performance) {
#             let performanceEntries = performance.getEntriesByType('paint');
#
#             metrics.timeToFirstPaint = Math.round(performanceEntries[1].startTime);
#             metrics.firstPaint = metrics.timeToFirstPaint + metrics.navigationStart
#         }
#
#         // Timestamp and duration of First Paint For IE
#         else if (typeof timing.msFirstPaint === 'number') {
#             metrics.firstPaint = timing.msFirstPaint;
#             metrics.timeToFirstPaint = timing.msFirstPaint- timing.navigationStart;
#         }
#
#         // Time To Dom Interactive
#         if (timing.domInteractive) {
#             metrics.timeToDomInteractive = timing.domInteractive - timing.navigationStart;
#         }
#
#         if (typeof newrelic == 'object') {
#             newrelic.addPageAction('timings', metrics);
#         }
#     }
#     window.addEventListener('load', sendNewRelicPerformanceMetrics, false);
# })();</script></body>
# <!--
# version: 5.26.30-3389
# built_by: nextgen
# built_on: Thu Jul 22 21:36:56 UTC 2021
# build_host: consumer07-bamboo.prod.st1
# deployed_at: Fri Jul 23 17:37:35 UTC 2021
# deployed_by: root
# scm_rev: 546cbad
# ypu_parent: prod
# ypu_env: prod_ev1
# node_env: production
# hostname: ypu41.ev1
#
# --></html>

# %% [markdown]
# ### Results

# %%
result_container = soup.find_all('div', {'class':'result'})

# %%
result_container
# Out:
# [<div class="result" data-analytics='{"adclick":true,"events":"event7,event5","category":"8004222","impression_id":"9db185cb-859f-4b3c-8cae-db27561f3d25","listing_id":"1001117676060","item_id":-1,"listing_type":"sub","ypid":"407372","content_provider":"IY","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-407372","item_type":"listing","lhc":"8004222","ldir":"NRKNY","rate":4,"hasTripAdvisor":false,"pid":"800000001503987347","mip_claimed_status":"mip_unclaimed","mip_ypid":"407372","rating":"advertiser","listing_index":1,"tier":799,"poi":1,"rank":1,"act":1,"features":"website,reviews,menu,phone,orderonline-spm","impression":1,"content_partner_id":"IY"}' data-impressionid="9db185cb-859f-4b3c-8cae-db27561f3d25" data-ypid="407372" id="lid-407372"><div class="srp-listing clickable-area iy" data-analytics='{"click_id":1600,"category":"8004222","tier":799}' data-bcnt="0"><div class="v-card"><div class="media-thumbnail"><a class="media-thumbnail-wrapper photo" data-analytics='{"click_id":1499,"features":"photo-gallery"}' href="/new-york-ny/mip/mr-ks-407372?lid=1001117676060#gallery"><img alt="Mr. K's" asset_type="blob_api" class="no-tracks lazy" data-original="https://i3.ypcdn.com/blob/c34e2901edfb966b565d36f5d8199a1b8b1a656f_100x100_crop.jpg?546cbad
#  " height="100" src="https://i3.ypcdn.com/blob/c34e2901edfb966b565d36f5d8199a1b8b1a656f_100x100_crop.jpg?546cbad
#  " width="100"/><noscript><img alt="Mr. K's" asset_type="blob_api" class="csrp" height="100" src="https://i3.ypcdn.com/blob/c34e2901edfb966b565d36f5d8199a1b8b1a656f_100x100_crop.jpg?546cbad
#  " width="100"/></noscript></a></div><div class="info"><h2 class="n">1. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/mr-ks-407372?lid=1001117676060" rel=""><span>Mr. K's</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaurants">Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/chinese-restaurants">Chinese Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/banquet-halls-reception-facilities">Banquet Halls &amp; Reception Facilities</a></div><div class="ratings" data-israteable="true"><a class="rating" data-analytics='{"click_id":22,"listing_features":"ratings"}' href="/new-york-ny/mip/mr-ks-407372?lid=1001117676060#yp-rating"><div class="result-rating four"><span class="count">(27)</span></div></a></div><div class="badges"><div class="years-in-business"><div class="count"><div class="number">25</div></div><span>YEARS<br/>IN BUSINESS</span></div></div><div class="links"><a class="track-visit-website" data-analytics='{"click_id":6,"act":2,"dku":"http://www.mrksny.com","FL":"url","target":"website","LOC":"http://www.mrksny.com","adclick":true,"iid":"9db185cb-859f-4b3c-8cae-db27561f3d25"}' href="http://www.mrksny.com" rel="nofollow noopener" target="_blank">Website</a><a class="track-map-it directions" data-analytics='{"click_id":13,"target":"website","act":4,"adclick":true,"iid":"9db185cb-859f-4b3c-8cae-db27561f3d25"}' href="/listings/1001117676060/directions">Directions</a><a class="menu" data-analytics='{"click_id":1614,"target":"menus","listing_features":"menu-link"}' href="/listings/407372/menu?lid=1001117676060">Services</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(212) 583-1668</div><p class="adr"><div class="street-address">570 Lexington Ave</div><div class="locality">New York, NY 10022</div></p></div><div class="snippet"><figure class="color-4"><svg height="16" viewbox="0 0 22 22" width="16" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#default-avatar"></use></svg></figure><p class="body with-avatar">Great tasty food, good service, large portions, affordable per person. The staff is neat, the room is clean.</p></div><div class="listing-ctas"><a class="action order-online" data-analytics='{"adclick":true,"events":"event7,event5","category":"8004222","impression_id":"9db185cb-859f-4b3c-8cae-db27561f3d25","listing_id":"1001117676060","item_id":-1,"listing_type":"sub","ypid":"407372","content_provider":"IY","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-407372","item_type":"SPM","lhc":"8004222","ldir":"NRKNY","rate":4,"hasTripAdvisor":false,"pid":"800000001503987347","mip_claimed_status":"mip_unclaimed","mip_ypid":"407372","click_id":523,"listing_features":"orderonline"}' href="http://redirect.singleapi.com/?trackingId=sp-l1259836-t1-p17-rNVZC223TFUYTO===" rel="nofollow noopener" target="_blank"><svg xmlns="http://www.w3.org/2000/svg"><use xlink:href="#order-online"></use></svg>Order Online</a></div></div></div></div></div>,
#  <div class="result" data-analytics='{"adclick":true,"events":"event7,event5","category":"8004279","impression_id":"bb68b1ba-680a-46b5-8ecf-05394c15c183","listing_id":"1001874845727","item_id":-1,"listing_type":"sub","ypid":"475254262","content_provider":"RD","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-475254262","item_type":"listing","lhc":"8004279","ldir":"NRKNY","rate":3.5,"hasTripAdvisor":true,"pid":"800000002288085821","mip_claimed_status":"mip_unclaimed","mip_ypid":"475254262","rating":"advertiser","listing_index":2,"tier":50,"poi":2,"rank":2,"act":1,"features":"website,reviews,menu,phone,tripadvisor","impression":1,"content_partner_id":"RD"}' data-impressionid="bb68b1ba-680a-46b5-8ecf-05394c15c183" data-ypid="475254262" id="lid-475254262"><div class="srp-listing clickable-area rd" data-analytics='{"click_id":1600,"category":"8004279","tier":50}' data-bcnt="0"><div class="v-card"><div class="media-thumbnail"><a class="media-thumbnail-wrapper photo" data-analytics='{"click_id":1499,"features":"photo-gallery"}' href="/new-york-ny/mip/potjanee-thai-restaurant-of-new-york-475254262?lid=1001874845727#gallery"><img alt="Potjanee Thai Restaurant of New York" asset_type="blob_api" class="no-tracks lazy" data-original="https://i3.ypcdn.com/blob/6970e92017832f34f9a139d11051c9501af79592_100x100_crop.jpg?546cbad
#  " height="100" src="https://i3.ypcdn.com/blob/6970e92017832f34f9a139d11051c9501af79592_100x100_crop.jpg?546cbad
#  " width="100"/><noscript><img alt="Potjanee Thai Restaurant of New York" asset_type="blob_api" class="csrp" height="100" src="https://i3.ypcdn.com/blob/6970e92017832f34f9a139d11051c9501af79592_100x100_crop.jpg?546cbad
#  " width="100"/></noscript></a></div><div class="info"><h2 class="n">2. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/potjanee-thai-restaurant-of-new-york-475254262?lid=1001874845727" rel=""><span>Potjanee Thai Restaurant of New York</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaurants">Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/asian-restaurants">Asian Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/thai-restaurants">Thai Restaurants</a></div><div class="ratings" data-israteable="true" data-tripadvisor='{"rating":"4.5","count":"24"}'><a class="rating hasExtraRating" data-analytics='{"click_id":22,"listing_features":"ratings"}' href="/new-york-ny/mip/potjanee-thai-restaurant-of-new-york-475254262?lid=1001874845727#yp-rating"><div class="result-rating three half"><span class="count">(5)</span></div></a></div><div class="badges"><div class="years-in-business"><div class="count"><div class="number">11</div></div><span>YEARS<br/>IN BUSINESS</span></div><div class="years-with-yp"><div class="count"><div class="number">3</div></div><span>YEARS <br/> WITH</span><img src="//i3.ypcdn.com/ypu/images/svgs/ypIcon.svg?546cbad"/></div></div><div class="links"><a class="track-visit-website" data-analytics='{"click_id":6,"act":2,"dku":"http://potjanee.net","FL":"url","target":"website","LOC":"http://potjanee.net","adclick":true,"iid":"bb68b1ba-680a-46b5-8ecf-05394c15c183"}' href="http://potjanee.net" rel="nofollow noopener" target="_blank">Website</a><a class="track-map-it directions" data-analytics='{"click_id":13,"target":"website","act":4,"adclick":true,"iid":"bb68b1ba-680a-46b5-8ecf-05394c15c183"}' href="/listings/1001874845727/directions">Directions</a><a class="menu" data-analytics='{"click_id":1614,"target":"menus","listing_features":"menu-link"}' href="/listings/475254262/menu?lid=1001874845727">View Menu</a><a class="track-more-info" data-analytics='{"click_id":7,"target":"moreInfo","act":1,"FL":"list","adclick":true,"iid":"bb68b1ba-680a-46b5-8ecf-05394c15c183"}' href="/new-york-ny/mip/potjanee-thai-restaurant-of-new-york-475254262?lid=1001874845727">More Info</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(212) 558-9071</div><p class="adr"><div class="street-address">48 Carmine St</div><div class="locality">New York, NY 10014</div></p></div><div class="snippet"><figure class="color-2"><svg height="16" viewbox="0 0 22 22" width="16" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#default-avatar"></use></svg></figure><p class="body with-avatar">This is a family owned restaurant, they took over what was known as Morakote restaurant back in 2007 and changed its name to Potjanee Thai…</p></div><div class="listing-ctas"></div></div></div></div></div>,
#  <div class="result" data-analytics='{"adclick":true,"events":"event7,event5","category":"8009371","impression_id":"f9c94739-b927-429e-b116-109d0cc835f5","listing_id":"1000647207573","item_id":-1,"listing_type":"sub","ypid":"482175847","content_provider":"GUMP","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7
div></div><div class="links"><a class="track-visit-website" data-analytics='{"click_id":6,"act":2,"dku":"http://danoinyc.com/midtown-manhattan.html","FL":"url","target":"website","LOC":"http://danoinyc.com/midtown-manhattan.html","adclick":true,"iid":"f51c91bd-6716-40d9-b0bd-cbd557139d45"}' href="http://danoinyc.com/midtown-manhattan.html" rel="nofollow noopener" target="_blank">Website</a><a class="track-map-it directions" data-analytics='{"click_id":13,"target":"website","act":4,"adclick":true,"iid":"f51c91bd-6716-40d9-b0bd-cbd557139d45"}' href="/listings/1001682503857/directions">Directions</a><a class="menu" data-analytics='{"click_id":1614,"target":"menus","listing_features":"menu-link"}' href="/listings/533587405/menu?lid=1001682503857">View Menu</a><a class="track-more-info" data-analytics='{"click_id":7,"target":"moreInfo","act":1,"FL":"list","adclick":true,"iid":"f51c91bd-6716-40d9-b0bd-cbd557139d45"}' href="/new-york-ny/mip/da-noi-midtown-manhattan-533587405?lid=1001682503857">More Info</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(347) 955-0067</div><p class="adr"><div class="street-address">214 E 49th St</div><div class="locality">New York, NY 10017</div></p></div><div class="snippet"><p class="body"><span>From Business: High quality dining, elegant private parties and five star service are waiting for you at Da Noi in Mid-town Manhattan. We're located in the heart of the capital…</span></p></div><div class="listing-ctas"><a c ...
#  <div class="result" data-analytics='{"adclick":true,"events":"event7,event5","category":"8004266","impression_id":"62f42305-69c6-4655-b481-37a9a6dc9600","listing_id":"1000439722148","item_id":-1,"listing_type":"sub","ypid":"460080517","content_provider":"GUMP","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-460080517","item_type":"listing","lhc":"8004266","ldir":"NRKNY","rate":4.5,"hasTripAdvisor":false,"pid":"800000000812207619","mip_claimed_status":"mip_unclaimed","mip_ypid":"460080517","rating":"advertiser","listing_index":5,"tier":799,"poi":5,"rank":5,"act":1,"features":"reviews,menu,phone","impression":1,"content_partner_id":"GUMP"}' data-impressionid="62f42305-69c6-4655-b481-37a9a6dc9600" data-ypid="460080517" id="lid-460080517"><div class="srp-listing clickable-area gump" data-analytics='{"click_id":1600,"category":"8004266","tier":799}' data-bcnt="0"><div class="v-card"><div class="media-thumbnail"><a class="media-thumbnail-wrapper default" data-analytics='{"click_id":509}' href="/new-york-ny/mip/sevens-turkish-grill-460080517?lid=1000439722148"><img alt="Seven's Turkish Grill" height="100" src="//i4.ypcdn.com/ypu/images/default-thumbnails/thumbnail-1.svg?546cbad" width="100"/></a></div><div class="info"><h2 class="n">5. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/sevens-turkish-grill-460080517?lid=1000439722148" rel=""><span>Seven's Turkish Grill</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaurants">Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/mediterranean-restaurants">Mediterranean Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/caterers">Caterers</a></div><div class="ratings" data-israteable="true"><a class="rating" data-analytics='{"click_id":22,"listing_features":"ratings"}' href="/new-york-ny/mip/sevens-turkish-grill-460080517?lid=1000439722148#yp-rating"><div class="result-rating four half"><span class="count">(9)</span></div></a></div><div class="badges"><div class="years-in-business"><div class="count"><div class="number">15</div></div><span>YEARS<br/>IN BUSINESS</span></div></div><div class="links"><a class="track-map-it directions" data-analytics='{"click_id":13,"target":"website","act":4,"adclick":true,"iid":"62f42305-69c6-4655-b481-37a9a6dc9600"}' href="/listings/1000439722148/directions">Directions</a><a class="menu" data-analytics='{"click_id":1614,"target":"menus","listing_features":"menu-link"}' href="/listings/460080517/menu?lid=1000439722148">View Menu</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(212) 724-4700</div><p class="adr"><div class="street-address">158 W 72nd St</div><div class="locality">New York, NY 10023</div></p></div><div class="snippet"><img alt="User Avatar" class="lazy avatar" data-original="https://i1.ypcdn.com/blob/8e1da21ede474d1cb4d8df95c08d5897d234f811_32x32_crop.jpg" height="32" width="32"/><p class="body with-avatar">Great food, really enjoyed the experience. I've been to this place several times and I'll be back, telling all my friends about it.</p></div><div class="listing-ctas"></div></div></div></div></div>,
#  <div class="result" data-analytics='{"adclick":true,"events":"event7,event5","category":"8004225","impression_id":"844ef87a-8bba-4ce3-b50b-f95c4272848a","listing_id":"1001105931107","item_id":-1,"listing_type":"sub","ypid":"5642814","content_provider":"IY","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-5642814","item_type":"listing","lhc":"8004225","ldir":"NRKNY","rate":4.5,"hasTripAdvisor":true,"pid":"800000001492083394","mip_claimed_status":"mip_claimed","mip_ypid":"5642814","rating":"advertiser","listing_index":6,"tier":799,"poi":6,"rank":6,"act":1,"features":"website,reviews,menu,phone,tripadvisor,orderonline-spm","impression":1,"content_partner_id":"IY"}' data-impressionid="844ef87a-8bba-4ce3-b50b-f95c4272848a" data-ypid="5642814" id="lid-5642814"><div class="srp-listing clickable-area iy" data-analytics='{"click_id":1600,"category":"8004225","tier":799}' data-bcnt="0"><div class="v-card"><div class="media-thumbnail"><a class="media-thumbnail-wrapper default" data-analytics='{"click_id":509}' href="/new-york-ny/mip/todaro-brothers-5642814?lid=1001105931107"><img alt="Todaro Brothers" height="100" src="//i1.ypcdn.com/ypu/images/default-thumbnails/thumbnail-4.svg?546cbad" width="100"/></a></div><div class="info"><h2 class="n">6. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/todaro-brothers-5642814?lid=1001105931107" rel=""><span>Todaro Brothers</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaurants">Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/italian-restaurants">Italian Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/caterers">Caterers</a></div><div class="ratings" data-israteable="true" data-tripadvisor='{"rating":"4.0","count":"16"}'><a class="rating hasExtraRating" data-analytics='{"click_id":22,"listing_features":"ratings"}' href="/new-york-ny/mip/todaro-brothers-5642814?lid=1001105931107#yp-rating"><div class="result-rating four half"><span class="count">(5)</span></div></a></div><div class="badges"><div class="years-in-business"><div class="count"><div class="number">17</div></div><span>YEARS<br/>IN BUSINESS</span></div></div><div class="links"><a class="track-visit-website" data-analytics='{"click_id":6,"act":2,"dku":"http://www.todarobros.com","FL":"url","target":"website","LOC":"http://www.todarobros.com","adclick":true,"iid":"844ef87a-8bba-4ce3-b50b-f95c4272848a"}' href="http://www.todarobros.com" rel="nofollow noopener" target="_blank">Website</a><a class="track-map-it directions" data-analytics='{"click_id":13,"target":"website","act":4,"adclick":true,"iid":"844ef87a-8bba-4ce3-b50b-f95c4272848a"}' href="/listings/1001105931107/directions">Directions</a><a class="menu" data-analytics='{"click_id":1614,"target":"menus","listing_features":"menu-link"}' href="/listings/5642814/menu?lid=1001105931107">View Menu</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(212) 532-0633</div><p class="adr"><div class="street-address">555 2nd Ave</div><div class="locality">New York, NY 10016</div></p></div><div class="snippet"><img alt="User Avatar" class="lazy avatar" data-original="https://graph.facebook.com/725895725/picture?height=32&amp;width=32" height="32" width="32"/><p class="body with-avatar">ES SUPER RICO LO RECOMIENDO TIENE QUE IR A CONOCERLO, ES SUPER FRESCO TODO FRESCO TODO FRESCO TODO FRESCO TODO</p></div><div class="listing-ctas"><a class="action order-online" data-analytics='{"adclick":true,"events":"event7,event5","category":"8004225","impression_id":"844ef87a-8bba-4ce3-b50b-f95c4272848a","listing_id":"1001105931107"," ...
#  <div class="result" data-analytics='{"adclick":true,"events":"event7,event6","category":"8004199","impression_id":"e3b917bd-6251-4c77-a911-f2e22f242c1c","listing_id":"28771538","item_id":-1,"listing_type":"free","ypid":"28771538","content_provider":"MDM","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-28771538","item_type":"listing","lhc":"8004199","ldir":"NRKNY","rate":4,"hasTripAdvisor":true,"mip_claimed_status":"mip_unclaimed","mip_ypid":"28771538","rating":"free","listing_index":7,"tier":999,"poi":7,"rank":7,"act":1,"features":"website,reviews,menu,phone,tripadvisor","impression":1,"content_partner_id":"MDM"}' data-impressionid="e3b917bd-6251-4c77-a911-f2e22f242c1c" data-ypid="28771538" id="lid-28771538"><div class="srp-listing clickable-area mdm" data-analytics='{"click_id":1600,"category":"8004199","tier":999}' data-bcnt="0"><div class="v-card"><div class="media-thumbnail"><a class="media-thumbnail-wrapper default" data-analytics='{"click_id":509}' href="/new-york-ny/mip/punch-28771538"><img alt="Punch" height="100" src="//i4.ypcdn.com/ypu/images/default-thumbnails/thumbnail-5.svg?546cbad" width="100"/></a></div><div class="info"><h2 class="n">7. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/punch-28771538" rel=""><span>Punch</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaurants">Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/american-restaurants">American Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/bars">Bars</a></div><div class="ratings" data-israteable="true" data-tripadvisor='{"rating":"4.0","count":"89"}'><a class="rating hasExtraRating" data-analytics='{"click_id":22,"listing_features":"ratings"}' href="/new-york-ny/mip/punch-28771538#yp-rating"><div class="result-rating four"><span class="count">(53)</span></div></a></div><div class="badges"><div class="years-in-business"><div class="count"><div class="number">22</div></div><span>YEARS<br/>IN BUSINESS</span></div></div><div class="links"><a class="track-visit-website" data-analytics='{"click_id":6,"act":2,"dku":"http://www.punchrestaurant.com","FL":"url","target":"website","LOC":"http://www.punchrestaurant.com","adclick":true,"iid":"e3b917bd-6251-4c77-a911-f2e22f242c1c"}' href="http://www.punchrestaurant.com" rel="nofollow noopener" target="_blank">Website</a><a class="menu" data-analytics='{"click_id":1614,"target":"menus","listing_features":"menu-link"}' href="/listings/28771538/menu?lid=28771538">View Menu</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(212) 673-6333</div><p class="adr"><div class="street-address">913 Broadway</div><div class="locality">New York, NY 10010</div></p></div><div class="snippet"><figure class="color-5">KF</figure><p class="body with-avatar">great variety of foods and their steak is awesome.</p></div><div class="listing-ctas"></div></div></div></div></div>,
#  <div class="result" data-analytics='{"adclick":true,"events":"event7,event6","category":"8016124","impression_id":"d3737406-c461-4acd-8d80-23b520d6a965","listing_id":"458844388","item_id":-1,"listing_type":"free","ypid":"458844388","content_provider":"MDM","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-458844388","item_type":"listing","lhc":"8016124","ldir":"NRKNY","rate":5,"hasTripAdvisor":false,"mip_claimed_status":"mip_unclaimed","mip_ypid":"458844388","rating":"free","listing_index":8,"tier":999,"poi":8,"rank":8,"act":1,"features":"website,reviews,menu,phone","impression":1,"content_partner_id":"MDM"}' data-impressionid="d3737406-c461-4acd-8d80-23b520d6a965" data-ypid="458844388" id="lid-458844388"><div class="srp-listing clickable-area mdm" data-analytics='{"click_id":1600,"category":"8016124","tier":999}' data-bcnt="0"><div class="v-card"><div class="media-thumbnail"><a class="media-thumbnail-wrapper default" data-analytics='{"click_id":509}' href="/new-york-ny/mip/alpha-fusion-458844388"><img alt="Alpha Fusion" height="100" src="//i1.ypcdn.com/ypu/images/default-thumbnails/thumbnail-4.svg?546cbad" width="100"/></a></div><div class="info"><h2 class="n">8. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/alpha-fusion-458844388" rel=""><span>Alpha Fusion</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaurants">Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/asian-restaurants">Asian Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/take-out-restaurants">Take Out Restaurants</a></div><div class="ratings" data-israteable="true"><a class="rating" data-analytics='{"click_id":22,"listing_features":"ratings"}' href="/new-york-ny/mip/alpha-fusion-458844388#yp-rating"><div class="result-rating five"><span class="count">(25)</span></div></a></div><div class="badges"><div class="years-in-business"><div class="count"><div class="number">13</div></div><span>YEARS<br/>IN BUSINESS</span></div></div><div class="links"><a class="track-visit-website" data-analytics='{"click_id":6,"act":2,"dku":"http://www.alpha34.com","FL":"url","target":"website","LOC":"http://www.alpha34.com","adclick":true,"iid":"d3737406-c461-4acd-8d80-23b520d6a965"}' href="http://www.alpha34.com" rel="nofollow noopener" target="_blank">Website</a><a class="menu" data-analytics='{"click_id":1614,"target":"menus","listing_features":"menu-link"}' href="/listings/458844388/menu?lid=458844388">View Menu</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(212) 279-8887</div><p class="adr"><div class="street-address">365 W 34th St</div><div class="locality">New York, NY 10001</div></p></div><div class="snippet"><figure class="color-5">SB</figure><p class="body with-avatar">Crispy duck with pineapple fried rice is a great cuisine. I enjoyed it in Alpha Fusion. Last month I visited this restaurant with my friend. The…</p></div><div class="listing-ctas"></div></div></div></div></div>,
#  <div class="result" data-analytics='{"adclick":true,"events":"event7,event6","category":"8004225","impression_id":"fbdcf27a-23da-44d7-9956-7f5d794f09fa","listing_id":"285698","item_id":-1,"listing_type":"free","ypid":"285698","content_provider":"MDM","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-285698","item_type":"listing","lhc":"8004225","ldir":"NRKNY","rate":4,"hasTripAdvisor":true,"mip_claimed_status":"mip_unclaimed","mip_ypid":"285698","rating":"free","listing_index":9,"tier":999,"poi":9,"rank":9,"act":1,"features":"website,reviews,menu,phone,tripadvisor","impression":1,"content_partner_id":"MDM"}' data-impressionid="fbdcf27a-23da-44d7-9956-7f5d794f09fa" data-ypid="285698" id="lid-285698"><div class="srp-listing clickable-area mdm" data-analytics='{"click_id":1600,"category":"8004225","tier":999}' data-bcnt="0"><div class="v-card"><div class="media-thumbnail"><a class="media-thumbnail-wrapper photo" data-analytics='{"click_id":1499,"features":"photo-gallery"}' href="/new-york-ny/mip/babbo-285698?lid=285698#gallery"><img alt="Babbo" asset_type="blob_api" class="no-tracks lazy" data-original="https://i3.ypcdn.com/blob/de4bae0c86f07cdd35db94b34a4e476c9e66ea01_100x100_crop.jpg?546cbad
#  " height="100" src="https://i3.ypcdn.com/blob/de4bae0c86f07cdd35db94b34a4e476c9e66ea01_100x100_crop.jpg?546cbad
#  " width="100"/><noscript><img alt="Babbo" asset_type="blob_api" class="csrp" height="100" src="https://i3.ypcdn.com/blob/de4bae0c86f07cdd35db94b34a4e476c9e66ea01_100x100_crop.jpg?546cbad
#  " width="100"/></noscript></a></div><div class="info"><h2 class="n">9. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/babbo-285698" rel=""><span>Babbo</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaurants">Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/italian-restaurants">Italian Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/mediterranean-restaurants">Mediterranean Restaurants</a></div><div class="ratings" data-israteable="true" data-tripadvisor='{"rating":"4.0","count":"1941"}'><a class="rating hasExtraRating" data-analytics='{"click_id":22,"listing_features":"ratings"}' href="/new-york-ny/mip/babbo-285698#yp-rating"><div class="result-rating four"><span class="count">(232)</span></div></a></div><div class="badges"><div class="years-in-business"><div class="count"><div class="number">23</div></div><span>YEARS<br/>IN BUSINESS</span></div></div><div class="links"><a class="track-visit-website" data-analytics='{"click_id":6,"act":2,"dku":"https://www.babbonyc.com","FL":"url","target":"website","LOC":"https://www.babbonyc.com","adclick":true,"iid":"fbdcf27a-23da-44d7-9956-7f5d794f09fa"}' href="https://www.babbonyc.com" rel="nofollow noopener" target="_blank">Website</a><a class="menu" data-analytics='{"click_id":1614,"target":"menus","listing_features":"menu-link"}' href="/listings/285698/menu?lid=285698">View Menu</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(212) 777-0303</div><p class="adr"><div class="street-address">110 Waverly Pl Frnt A</div><div class="locality">New York, NY 10011</div></p></div><div class="snippet"><figure class="color-2">VN</figure><p class="body with-avatar">Their food is good but I think they need to improve on waiting time. Ive waited for almost an hour before they serve my orders. I almost starve to…</p></div><div class="listing-ctas"></div></div></div></div></div>,
#  <div class="result" data-analytics='{"adclick":true,"events":"event7,event6","category":"8004282","impression_id":"e2d502f0-d96f-4aac-9f03-5516a119bb50","listing_id":"15362553","item_id":-1,"listing_type":"free","ypid":"15362553","content_provider":"MDM","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-15362553","item_type":"listing","lhc":"8004282","ldir":"NRKNY","rate":4,"hasTripAdvisor":true,"mip_claimed_status":"mip_unclaimed","mip_ypid":"15362553","rating":"free","listing_index":10,"tier":999,"poi":10,"rank":10,"act":1,"features":"website,reviews,menu,phone,tripadvisor","impression":1,"content_partner_id":"MDM"}' data-impressionid="e2d502f0-d96f-4aac-9f03-5516a119bb50" data-ypid="15362553" id="lid-15362553"><div class="srp-listing clickable-area mdm" data-analytics='{"click_id":1600,"category":"8004282","tier":999}' data-bcnt="0"><div class="v-card"><div class="media-thumbnail"><a class="media-thumbnail-wrapper photo" data-analytics='{"click_id":1499,"features":"photo-gallery"}' href="/new-york-ny/mip/sparks-steak-house-15362553?lid=15362553#gallery"><img alt="Sparks Steak House" asset_type="blob_api" class="no-tracks lazy" data-original="https://i3.ypcdn.com/blob
asset_type="blob_api" class="csrp" height="100" src="https://i3.ypcdn.com/blob/311bd4d42d003ccd0b77192a6866ad653489d7e9_100x100_crop.jpg?546cbad
#  " width="100"/></noscript></a></div><div class="info"><h2 class="n">12. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/blind-pig-8526127" rel=""><span>Blind Pig</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaurants">Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/american-restaurants">American Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/bar-grills">Bar &amp; Grills</a></div><div class="ratings" data-israteable="true" data-tripadvisor='{"rating":"4.5","count":"26"}'><a class="rating hasExtraRating" data-analytics='{"click_id":22,"listing_features":"ratings"}' href="/new-york-ny/mip/blind-pig-8526127#yp-rating"><div class="result-rating four"><span class="count">(53)</span></div></a></div><div class="badges"><div class="years-in-business"><div class="count"><div class="number">21</div></div><span>YEARS<br/>IN BUSINESS</span></div></div><div class="links"><a class="track-visit-website" data-analytics='{"click_id":6,"act":2,"dku":"http://www.blindpigbar.com","FL":"url","target":"website","LOC":"http://www.blindpigbar.com","adclick":true,"iid":"102d8dd5-bfed-47eb-b218-f3ed5e1b0996"}' href="http://www.blindpigbar.com" rel="nofollow noopener" target="_blank">Website</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(212) 209-1573</div><p class="adr"><div class="street-address">233 E 14th St Frnt 1</div><div class="locality">New York, NY 10003</div></p></div><div class="snippet"><figure class="color-2"><svg height="16" viewbox="0 0 22 22" width="16" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#default-avatar"></use></svg></figure><p class="body with-avatar">Great bar food and pleasant bar staff. The drinks were fantastic also.</p></div><div class="listing-ctas"></div></div></div></div></div>,
# ...
#  <div class="result" data-analytics='{"adclick":true,"events":"event7,event6","category":"8004225","impression_id":"fa353a10-6ecd-45b8-9aa1-6c254c396a2f","listing_id":"10889409","item_id":-1,"listing_type":"free","ypid":"10889409","content_provider":"MDM","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-10889409","item_type":"listing","lhc":"8004225","ldir":"NRKNY","rate":4.5,"hasTripAdvisor":false,"mip_claimed_status":"mip_unclaimed","mip_ypid":"10889409","rating":"free","listing_index":27,"tier":999,"poi":27,"rank":27,"act":1,"features":"website,reviews,menu,phone","impression":1,"content_partner_id":"MDM"}' data-impressionid="fa353a10-6ecd-45b8-9aa1-6c254c396a2f" data-ypid="10889409" id="lid-10889409"><div class="srp-listing clickable-area mdm" data-analytics='{"click_id":1600,"category":"8004225","tier":999}' data-bcnt="0"><div class="v-card"><div class="media-thumbnail"><a class="media-thumbnail-wrapper photo" data-analytics='{"click_id":1499,"features":"photo-gallery"}' href="/new-york-ny/mip/frankies-17-spuntino-10889409?lid=10889409#gallery"><img alt="Frankies 17 Spuntino" asset_type="blob_api" class="no-tracks lazy" data-original="https://i3.ypcdn.com/blob/2fb5dba7d86197c0309ea40515773a0832108336_100x100_crop.jpg?546cbad
#  " height="100" src="https://i3.ypcdn.com/blob/2fb5dba7d86197c0309ea40515773a0832108336_100x100_crop.jpg?546cbad
#  " width="100"/><noscript><img alt="Frankies 17 Spuntino" asset_type="blob_api" class="csrp" height="100" src="https://i3.ypcdn.com/blob/2fb5dba7d86197c0309ea40515773a0832108336_100x100_crop.jpg?546cbad
#  " width="100"/></noscript></a></div><div class="info"><h2 class="n">27. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/frankies-17-spuntino-10889409" rel=""><span>Frankies 17 Spuntino</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaurants">Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/italian-restaurants">Italian Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/sandwich-shops">Sandwich Shops</a></div><div class="ratings" data-israteable="true"><a class="rating" data-analytics='{"click_id":22,"listing_features":"ratings"}' href="/new-york-ny/mip/frankies-17-spuntino-10889409#yp-rating"><div class="result-rating four half"><span class="count">(16)</span></div></a></div><div class="badges"><div class="years-in-business"><div class="count"><div class="number">17</div></div><span>YEARS<br/>IN BUSINESS</span></div></div><div class="links"><a class="track-visit-website" data-analytics='{"click_id":6,"act":2,"dku":"http://www.frankiesspuntino.com","FL":"url","target":"website","LOC":"http://www.frankiesspuntino.com","adclick":true,"iid":"fa353a10-6ecd-45b8-9aa1-6c254c396a2f"}' href="http://www.frankiesspuntino.com" rel="nofollow noopener" target="_blank">Website</a><a class="menu" data-analytics='{"click_id":1614,"target":"menus","listing_features":"menu-link"}' href="/listings/10889409/menu?lid=10889409">View Menu</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(212) 253-2303</div><p class="adr"><div class="street-address">17 Clinton St</div><div class="locality">New York, NY 10002</div></p></div><div class="snippet"><figure class="color-2"><svg height="16" viewbox="0 0 22 22" width="16" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#default-avatar"></use></svg></figure><p class="body with-avatar">I've eaten here twice now, and both times had a good experience.  It's a no-nonsense place...good without being pretentious or ""trendy"".  Nice,…</p></div><div class="listing-ctas"></div></div></div></div></div>,
#  <div class="result" data-analytics='{"adclick":true,"events":"event7,event6","category":"8004279","impression_id":"2c6f2c8b-b7b7-4cb4-9b48-59340593439e","listing_id":"12974269","item_id":-1,"listing_type":"free","ypid":"12974269","content_provider":"MDM","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-12974269","item_type":"listing","lhc":"8004279","ldir":"NRKNY","rate":5,"hasTripAdvisor":true,"mip_claimed_status":"mip_unclaimed","mip_ypid":"12974269","rating":"free","listing_index":28,"tier":999,"poi":28,"rank":28,"act":1,"features":"website,reviews,menu,phone,tripadvisor,orderonline-spm","impression":1,"content_partner_id":"MDM"}' data-impressionid="2c6f2c8b-b7b7-4cb4-9b48-59340593439e" data-ypid="12974269" id="lid-12974269"><div class="srp-listing clickable-area mdm" data-analytics='{"click_id":1600,"category":"8004279","tier":999}' data-bcnt="0"><div class="v-card"><div class="media-thumbnail"><a class="media-thumbnail-wrapper default" data-analytics='{"click_id":509}' href="/new-york-ny/mip/pinto-restaurant-12974269"><img alt="Pinto Restaurant" height="100" src="//i4.ypcdn.com/ypu/images/default-thumbnails/thumbnail-1.svg?546cbad" width="100"/></a></div><div class="info"><h2 class="n">28. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/pinto-restaurant-12974269" rel=""><span>Pinto Restaurant</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaurants">Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/thai-restaurants">Thai Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/asian-restaurants">Asian Restaurants</a></div><div class="ratings" data-israteable="true" data-tripadvisor='{"rating":"4.5","count":"57"}'><a class="rating hasExtraRating" data-analytics='{"click_id":22,"listing_features":"ratings"}' href="/new-york-ny/mip/pinto-restaurant-12974269#yp-rating"><div class="result-rating five"><span class="count">(12)</span></div></a></div><div class="badges"><div class="years-in-business"><div class="count"><div class="number">14</div></div><span>YEARS<br/>IN BUSINESS</span></div></div><div class="links"><a class="track-visit-website" data-analytics='{"click_id":6,"act":2,"dku":"http://www.pintonyc.com/#restaurant-section","FL":"url","target":"website","LOC":"http://www.pintonyc.com/#restaurant-section","adclick":true,"iid":"2c6f2c8b-b7b7-4cb4-9b48-59340593439e"}' href="http://www.pintonyc.com/#restaurant-section" rel="nofollow noopener" target="_blank">Website</a><a class="menu" data-analytics='{"click_id":1614,"target":"menus","listing_features":"menu-link"}' href="/listings/12974269/menu?lid=12974269">View Menu</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(212) 366-5455</div><p class="adr"><div class="street-address">118 Christopher St Frnt B</div><div class="locality">New York, NY 10014</div></p></div><div class="snippet"><figure class="color-2"><svg height="16" viewbox="0 0 22 22" width="16" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#default-avatar"></use></svg></figure><p class="body with-avatar">I came here with a group for some pre-birthday party dinner. I had a hard time finding a place in this are that was the food and quality we wanted,…</p></div><div class="listing-ctas"><a class="action order-online" data-analytics='{"adclick":true,"events":"event7,event6","category":"8004279","impression_id":"2c6f2c8b-b7b7-4cb4-9b48-59340593439e","listing_id":"12974269","item_id":-1,"listing_type":"free","ypid":"12974269","content_provider":"MDM","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-12974269","item_type":"SPM","lhc":"8 ...
#  <div class="result" data-analytics='{"adclick":true,"events":"event7,event6","category":"8004210","impression_id":"8c21039f-a485-4bc4-ac97-d5c197420734","listing_id":"4398082","item_id":-1,"listing_type":"free","ypid":"4398082","content_provider":"MDM","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-4398082","item_type":"listing","lhc":"8004210","ldir":"NRKNY","rate":3.5,"hasTripAdvisor":true,"mip_claimed_status":"mip_unclaimed","mip_ypid":"4398082","rating":"free","listing_index":29,"tier":999,"poi":29,"rank":29,"act":1,"features":"reviews,menu,phone,tripadvisor","impression":1,"content_partner_id":"MDM"}' data-impressionid="8c21039f-a485-4bc4-ac97-d5c197420734" data-ypid="4398082" id="lid-4398082"><div class="srp-listing clickable-area mdm" data-analytics='{"click_id":1600,"category":"8004210","tier":999}' data-bcnt="0"><div class="v-card"><div class="media-thumbnail"><a class="media-thumbnail-wrapper default" data-analytics='{"click_id":509}' href="/new-york-ny/mip/mughlai-indian-cuisine-4398082"><img alt="Mughlai Indian Cuisine" height="100" src="//i4.ypcdn.com/ypu/images/default-thumbnails/thumbnail-5.svg?546cbad" width="100"/></a></div><div class="info"><h2 class="n">29. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/mughlai-indian-cuisine-4398082" rel=""><span>Mughlai Indian Cuisine</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaurants">Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/indian-restaurants">Indian Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/middle-eastern-restaurants">Middle Eastern Restaurants</a></div><div class="ratings" data-israteable="true" data-tripadvisor='{"rating":"4.0","count":"62"}'><a class="rating hasExtraRating" data-analytics='{"click_id":22,"listing_features":"ratings"}' href="/new-york-ny/mip/mughlai-indian-cuisine-4398082#yp-rating"><div class="result-rating three half"><span class="count">(26)</span></div></a></div><div class="badges"><div class="years-in-business"><div class="count"><div class="number">32</div></div><span>YEARS<br/>IN BUSINESS</span></div></div><div class="links"><a class="menu" data-analytics='{"click_id":1614,"target":"menus","listing_features":"menu-link"}' href="/listings/4398082/menu?lid=4398082">View Menu</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(212) 724-6363</div><p class="adr"><div class="street-address">320 Columbus Ave</div><div class="locality">New York, NY 10023</div></p></div><div class="snippet"><figure class="color-2"><svg height="16" viewbox="0 0 22 22" width="16" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#default-avatar"></use></svg></figure><p class="body with-avatar">I had been to Mughlai several times over the past 5 years that I have lived on the upper west side, every time for dinner, until one day I decided…</p></div><div class="listing-ctas"></div></div></div></div></div>,
#  <div class="result" data-analytics='{"adclick":true,"events":"event7,event6","category":"8009371","impression_id":"9c964972-4187-4d1f-84cc-f6b36501e4f5","listing_id":"891219","item_id":-1,"listing_type":"free","ypid":"891219","content_provider":"YXT","srid":"L-webyp-bdd87537-0fdd-4ba0-bd78-a77d89302de7-891219","item_type":"listing","lhc":"8009371","ldir":"NRKNY","rate":3.5,"hasTripAdvisor":true,"mip_claimed_status":"mip_unclaimed","mip_ypid":"891219","rating":"free","listing_index":30,"tier":999,"poi":30,"rank":30,"act":1,"features":"website,reviews,menu,phone,tripadvisor","ids":"4817678","impression":1,"content_partner_id":"MDM"}' data-impressionid="9c964972-4187-4d1f-84cc-f6b36501e4f5" data-ypid="891219" id="lid-891219"><div class="srp-listing clickable-area mdm" data-analytics='{"click_id":1600,"category":"8009371","tier":999}' data-bcnt="0"><div class="v-card"><div class="media-thumbnail"><a class="media-thumbnail-wrapper photo" data-analytics='{"click_id":1499,"features":"photo-gallery"}' href="/new-york-ny/mip/planet-hollywood-891219?lid=891219#gallery"><img alt="Planet Hollywood" asset_type="blob_api" class="no-tracks lazy" data-original="https://i3.ypcdn.com/blob/6ff36f7a8693aef7e020d3b1a27621099c282f29_100x100_crop.jpg?546cbad
#  " height="100" src="https://i3.ypcdn.com/blob/6ff36f7a8693aef7e020d3b1a27621099c282f29_100x100_crop.jpg?546cbad
#  " width="100"/><noscript><img alt="Planet Hollywood" asset_type="blob_api" class="csrp" height="100" src="https://i3.ypcdn.com/blob/6ff36f7a8693aef7e020d3b1a27621099c282f29_100x100_crop.jpg?546cbad
#  " width="100"/></noscript></a></div><div class="info"><h2 class="n">30. <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/new-york-ny/mip/planet-hollywood-891219" rel=""><span>Planet Hollywood</span></a></h2><div class="info-section info-primary"><div class="categories"><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/restaurants">Restaurants</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/bars">Bars</a><a data-analytics='{"click_id":1171,"adclick":false,"listing_features":"category","events":""}' href="https://www.yellowpages.com/new-york-ny/bar-grills">Bar &amp; Grills</a></div><div class="ratings" data-israteable="true" data-tripadvisor='{"rating":"3.5","count":"3233"}'><a class="rating hasExtraRating" data-analytics='{"click_id":22,"listing_features":"ratings"}' href="/new-york-ny/mip/planet-hollywood-891219#yp-rating"><div class="result-rating three half"><span class="count">(20)</span></div></a></div><div class="badges"><div class="years-in-business"><div class="count"><div class="number">18</div></div><span>YEARS<br/>IN BUSINESS</span></div></div><div class="links"><a class="track-visit-website" data-analytics='{"click_id":6,"act":2,"dku":"https://locations.planethollywoodintl.com/us/ny/new-york/1540-broadway?y_source=1_NDgxNzY3OC01NTMtbG9jYXRpb24ud2Vic2l0ZQ%3D%3D","FL":"url","target":"website","LOC":"https://locations.planethollywoodintl.com/us/ny/new-york/1540-broadway?y_source=1_NDgxNzY3OC01NTMtbG9jYXRpb24ud2Vic2l0ZQ%3D%3D","adclick":true,"iid":"9c964972-4187-4d1f-84cc-f6b36501e4f5"}' href="https://locations.planethollywoodintl.com/us/ny/new-york/1540-broadway?y_source=1_NDgxNzY3OC01NTMtbG9jYXRpb24ud2Vic2l0ZQ%3D%3D" rel="nofollow noopener" target="_blank">Website</a><a class="menu" data-analytics='{"click_id":1614,"target":"menus","listing_features":"menu-link"}' href="/listings/891219/menu?lid=891219">View Menu</a></div></div><div class="info-section info-secondary"><div class="phones phone primary">(212) 333-7827</div><p class="adr"><div class="street-address">1540 Broadway</div><div class="locality">New York, NY 10036</div></p></div><div class="snippet"><figure class="color-2"><svg height="16" viewbox="0 0 22 22" width="16" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#default-avatar"></use></svg></figure><p class="body with-avatar">I could""nt enjoy myself. It was very sad when they anounced Heath""s death. The window were I was sitting was by the direction they where carring…</p></div><div class="listing-ctas"></div></div></div></div></div>]

# %%
len(result_container)
# Out:
# 30

# %% [markdown]
# ### Concatenate 2 URL Parts to get absolute URL

# %% [markdown]
# #### URL Part 1

# %%
# we combine url part no.1 with url part no.2 in order to get the absolute url

url_part_1 = 'https://www.yellowpages.com/'

# %% [markdown]
# #### Create List for URL Part 2

# %%
url_part_2 = []

# loop through results
for item in result_container:
    # loop through links
    for link in item.find_all('a', {'class': 'business-name'}):
        url_part_2.append(link.get('href'))

# %%
url_part_2
# Out:
# ['/new-york-ny/mip/mr-ks-407372?lid=1001117676060',
#  '/new-york-ny/mip/potjanee-thai-restaurant-of-new-york-475254262?lid=1001874845727',
#  '/new-york-ny/mip/spoonfed-new-york-country-482175847?lid=1000647207573',
#  '/new-york-ny/mip/da-noi-midtown-manhattan-533587405?lid=1001682503857',
#  '/new-york-ny/mip/sevens-turkish-grill-460080517?lid=1000439722148',
#  '/new-york-ny/mip/todaro-brothers-5642814?lid=1001105931107',
#  '/new-york-ny/mip/punch-28771538',
#  '/new-york-ny/mip/alpha-fusion-458844388',
#  '/new-york-ny/mip/babbo-285698',
#  '/new-york-ny/mip/sparks-steak-house-15362553',
#  '/new-york-ny/mip/bianca-6255318',
#  '/new-york-ny/mip/blind-pig-8526127',
#  '/new-york-ny/mip/old-homestead-steakhouse-1275150',
#  '/new-york-ny/mip/casa-mono-462462383',
#  '/new-york-ny/mip/chez-josephine-3030157',
#  '/new-york-ny/mip/esca-3306782',
#  '/new-york-ny/mip/dave-busters-8889637',
#  '/new-york-ny/mip/paul-jimmys-restaurant-2388948',
#  '/new-york-ny/mip/bobby-vans-steakhouse-54th-street-11139387',
#  '/new-york-ny/mip/waldys-pizza-16097243',
#  '/new-york-ny/mip/johnny-rock-10705734',
#  '/new-york-ny/mip/smac-459052000',
#  '/new-york-ny/mip/menchanko-tei-restaurant-2659878',
#  '/new-york-ny/mip/red-house-12325724',
#  '/new-york-ny/mip/lukes-lobster-450845415',
#  '/new-york-ny/mip/gramercy-caf-3465042',
#  '/new-york-ny/mip/frankies-17-spuntino-10889409',
#  '/new-york-ny/mip/pinto-restaurant-12974269',
#  '/new-york-ny/mip/mughlai-indian-cuisine-4398082',
#  '/new-york-ny/mip/planet-hollywood-891219']

# %% [markdown]
# #### Join Url 1 and Url 2

# %%
url_joined = []

for link_2 in url_part_2:
    url_joined.append(urllib.parse.urljoin(url_part_1, link_2))

# %%
url_joined
# Out:
# ['https://www.yellowpages.com/new-york-ny/mip/mr-ks-407372?lid=1001117676060',
#  'https://www.yellowpages.com/new-york-ny/mip/potjanee-thai-restaurant-of-new-york-475254262?lid=1001874845727',
#  'https://www.yellowpages.com/new-york-ny/mip/spoonfed-new-york-country-482175847?lid=1000647207573',
#  'https://www.yellowpages.com/new-york-ny/mip/da-noi-midtown-manhattan-533587405?lid=1001682503857',
#  'https://www.yellowpages.com/new-york-ny/mip/sevens-turkish-grill-460080517?lid=1000439722148',
#  'https://www.yellowpages.com/new-york-ny/mip/todaro-brothers-5642814?lid=1001105931107',
#  'https://www.yellowpages.com/new-york-ny/mip/punch-28771538',
#  'https://www.yellowpages.com/new-york-ny/mip/alpha-fusion-458844388',
#  'https://www.yellowpages.com/new-york-ny/mip/babbo-285698',
#  'https://www.yellowpages.com/new-york-ny/mip/sparks-steak-house-15362553',
#  'https://www.yellowpages.com/new-york-ny/mip/bianca-6255318',
#  'https://www.yellowpages.com/new-york-ny/mip/blind-pig-8526127',
#  'https://www.yellowpages.com/new-york-ny/mip/old-homestead-steakhouse-1275150',
#  'https://www.yellowpages.com/new-york-ny/mip/casa-mono-462462383',
#  'https://www.yellowpages.com/new-york-ny/mip/chez-josephine-3030157',
#  'https://www.yellowpages.com/new-york-ny/mip/esca-3306782',
#  'https://www.yellowpages.com/new-york-ny/mip/dave-busters-8889637',
#  'https://www.yellowpages.com/new-york-ny/mip/paul-jimmys-restaurant-2388948',
#  'https://www.yellowpages.com/new-york-ny/mip/bobby-vans-steakhouse-54th-street-11139387',
#  'https://www.yellowpages.com/new-york-ny/mip/waldys-pizza-16097243',
#  'https://www.yellowpages.com/new-york-ny/mip/johnny-rock-10705734',
#  'https://www.yellowpages.com/new-york-ny/mip/smac-459052000',
#  'https://www.yellowpages.com/new-york-ny/mip/menchanko-tei-restaurant-2659878',
#  'https://www.yellowpages.com/new-york-ny/mip/red-house-12325724',
#  'https://www.yellowpages.com/new-york-ny/mip/lukes-lobster-450845415',
#  'https://www.yellowpages.com/new-york-ny/mip/gramercy-caf-3465042',
#  'https://www.yellowpages.com/new-york-ny/mip/frankies-17-spuntino-10889409',
#  'https://www.yellowpages.com/new-york-ny/mip/pinto-restaurant-12974269',
#  'https://www.yellowpages.com/new-york-ny/mip/mughlai-indian-cuisine-4398082',
#  'https://www.yellowpages.com/new-york-ny/mip/planet-hollywood-891219']

# %% [markdown]
# ### Get Data from First Link

# %%
# Name
# Address
# Phone
# Email
# Website
# General Info

# %% [markdown]
# #### Store first link in variable

# %%
first_link = url_joined[0]

# %% [markdown]
# #### Get Request & Soup Object

# %%
response = requests.get(first_link)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta content="utf-8" name="charset"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width" name="viewport"/><title>Mr. K's 570 Lexington Ave, New York, NY 10022 - YP.com</title><meta content="Get reviews, hours, directions, coupons and more for Mr. K's. Search for other Chinese Restaurants on The Real Yellow Pages®." name="description"/><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam-cell.nr-data.net","errorBeacon":"bam-cell.nr-data.net","licenseKey":"a7bc01046c","applicationID":"7805046,7804101","applicationTime":166.14985,"transactionName":"MgRSZBMFXkMHVhZdWgtOc0USEF9dSVgLRA==","queueTime":0,"ttGuid":"aceb28278477f8","agentToken":null}; (window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:false}};(window.NREUM||(NREUM={})).loader_config={xpid:"XAAAVUVUAAMFVFVU",licenseKey:"a7bc01046c",applicationID:"7805046"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var i,o=t("ee"),a=t(25),s={};try{i=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,i.indexOf("dev")!==-1&&(s.dev=!0),i.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&o.on("internal-error",function(t){r(t.stack)}),s.dev&&o.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{p?p-=1:i(s||new UncaughtException(t,e,n),!0)}catch(f){try{o("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function i(t,e){var n=e?null:c.now();o("err",[t,n])}var o=t("handle"),a=t(26),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError";if(!c.disabled){var p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(9),t(8),"addEventListener"in window&&t(5),c.xhrWrappable&&t(10),d=!0)}s.on("fn-start",function(t,e,n){d&&(p+=1)}),s.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,i(n))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){o("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var i=t("ee"),o=t("handle"),a=t(9),s=t(8),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",g="pushState",y=t("loader");if(!y.disabled){y.features.stn=!0,t(7),"addEventListener"in window&&t(5);var x=NREUM.o.EV;i.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),i.on(w,function(t,e){var n=t[0];n instanceof x&&o("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),this.bstType])}),s.on(m,function(){this.bstStart=y.now()}),s.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),"requestAnimationFrame"])}),i.on(g+p,function(t){this.time=y.now(),this.startPath=location.pathname+location.hash}),i.on(g+h,function(t){o("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){o(d,[window.performance.getEntriesByT ...
# UserLoggedIn   = false;
# source         = "IY";
# Tracking       = {"lwes":{"rid":"webyp-4085e7d1-0b6d-4180-a34e-7295912b549b","ptid":"www.yellowpages.com","aid":"webyp","eaid":"YPU","enc":1,"version":"10844","vrid":"3bd5e6df-de62-4bcb-a6b6-f6df27c24dab","v":120,"referrer":"","ua":"python-requests/2.24.0","uip":"91.8.122.184","url":"https://www.yellowpages.com/new-york-ny/mip/mr-ks-407372?lid=1001117676060","eid":"0990d9e6-300e-4b93-bff9-2f895623d7b3","ypcst_base_url":"https://c.ypcdn.com"},"yext":{"PID":"4Diy12y2qo","TRACK_URL":"https://pl.yext.com/plpixel"},"supermedia":{"SUPERMEDIA_HOST":"api.superpages.com"},"dexmedia":{"SUPERMEDIA_HOST":"api.superpages.com"},"citysearch":{"CITYSEARCH_IMP_TRACKER":"https://api.citygridmedia.com/ads/tracker/imp"},"tripadvisor":{"TRIPADVISOR_HOST":"https://www.tripadvisor.com/img/cdsi/partner/transparent_pixel-32908-3-en_US.gif"},"dex":{"DEX_REDIRECTOR_HOST":"http://www.dexknows.com/rd/index.asp","TRACK_URL":"https://api.superpages.com/xml/search","SRC":"ypintfeed"},"host":"www.yellowpages.com","page_id":120,"pageName":"more_info_details","pageNumber":1,"app_id":"webyp","vrid":"3bd5e6df-de62-4bcb-a6b6-f6df27c24dab","rid":"webyp-4085e7d1-0b6d-4180-a34e-7295912b549b","request_id":"webyp-4085e7d1-0b6d-4180-a34e-7295912b549b","ip":"91.8.122.184","search_terms":"","env":"prod","location":{"geo_term":"Los Angeles, CA","city":"Los Angeles","state":"CA","lat":34.0764,"lng":-118.2626,"slug":"los-angeles-ca","display_geo":"Los Angeles, CA"},"dks":"e3c0cfa8-ac46-42f7-aa7b-d1eb1f6cc05c","user_agent":"python-requests/2.24.0","botData":{"isMobile":false,"isTablet":false,"isiPad":false,"isiPod":false,"isiPhone":false,"isAndroid":false,"isBlackberry":false,"isOpera":false,"isIE":false,"isIECompatibilityMode":false,"isSafari":false,"isFirefox":false,"isWebkit":false,"isChrome":false,"isKonqueror":false,"isOmniWeb":false,"isSeaMonkey":false,"isFlock":false,"isAmaya":false,"isEpiphany":false,"isDesktop":false,"isWindows":false,"isLinux":false,"isLinux
://www.yellowpages.com/new-york-ny/mip/mr-ks-407372" rel="canonical"/><link href="https://www.yellowpages.com/new-york-ny/mip/amp/mr-ks-407372" rel="amphtml"/><link href="https://www.yellowpages.com/new-york-ny/mip/mr-ks-407372?page=2" rel="next"/><link href="//i4.ypcdn.com/ypu/images/favicon.ico?546cbad" rel="icon shortcut"/><link href="//i3.ypcdn.com/ypu/images/apple-touch-icon-precomposed.png?546cbad" rel="apple-touch-icon-precomposed" type="image/x-icon"/><link href="//i3.ypcdn.com/ypu/css/common.min.css?546cbad" rel="stylesheet" type="text/css"/><link href="android-app://com.yellowpages.android.ypmobile/yp/mip/business/407372" rel="alternate"/><link href="ios-app://284806204/ypmobile/mip?listing_id=407372" rel="alternate"/><link href="//i4.ypcdn.com/ypu/css/bpp/index.min.css?546cbad" rel="stylesheet" type="text/css"/><noscript><link href="//i1.ypcdn.com/uitl/web/itl_widget.css?546cbad" rel="stylesheet" type="text/css"/></noscript><script>(function() {
#     function loadDeferredCss() {
#         var lazyStyleElm = document.createElement('link');
#         lazyStyleElm.rel = 'stylesheet';
#         lazyStyleElm.href = '//i1.ypcdn.com/uitl/web/itl_widget.css?546cbad';
#         lazyStyleElm.type = 'text/css';
#         var deferCss = document.getElementsByTagName('link')[0];
#         deferCss.parentNode.insertBefore(lazyStyleElm, deferCss);
#     }
#
#     if (window.addEventListener) {
#         window.addEventListener('load', loadDeferredCss, false);
#     } else if (window.attachEvent) {
#         window.attachEvent('onload', loadDeferredCss);
#     } else {
#         window.onload = loadDeferredCss;
#     }
# })();</script><!--[if IE]><link type='text/css' rel='stylesheet' href="//i3.ypcdn.com/ypu/css/ie.min.css?546cbad"/><![endif]--><script>ValidationJSON = {};
# </script><script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function()
# { (i[r].q=i[r].q||[]).push(arguments)}
# ,i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# var optOut;
# if (document.cookie.indexOf('optOut') !== -1) {
#     optOut = document.cookie.split('optOut=')[1].split(';')[0];
# }
#
# ga('create', 'UA-9709876-1', 'auto');
# ga('require', 'displayfeatures');
# if (optOut) {
#     ga('set', 'allowAdPersonalizationSignals', false);
#     ga('set', 'dimension1', 'true' );
# } else {
#     ga('set', 'allowAdPersonalizationSignals', true);
#     ga('set', 'dimension1', 'false' );
# }
# ga('send', 'pageview');</script><script>!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '886701991493531');
# fbq('track', 'PageView');</script><noscript><img alt="" height="1" src="https://www.facebook.com/tr?id=886701991493531&amp;ev=PageView&amp;noscript=1" width="1"/></noscript><script type="application/ld+json">{"@context":"http://schema.org","@type":"http://schema.org/Restaurant","@id":"/new-york-ny/mip/mr-ks-407372","name":"Mr. K's","address":{"@type":"PostalAddress","addressCountry":"US","streetAddress":"570 Lexington Ave","addressLocality":"New York","addressRegion":"NY","postalCode":"10022"},"aggregateRating":{"@type":"AggregateRating","ratingValue":4,"reviewCount":27},"geo":{"@type":"GeoCoordinates","latitude":40.75686,"longitude":-73.97228},"priceRange":"$$$","telephone":"(212) 583-1668","menu":"/new-york-ny/mip/mr-ks-407372/services?lid=1001117676060","openingHours":["Mo-Fr 11:30-22:00","Sa-Su 12:00-22:00"],"image":{"@type":"ImageObject","url":"https://i4.ypcdn.com/blob/6e9338857a824ad10f4d27d002d80601072ae74b","contentUrl":"https://i4.ypcdn.com/blob/6e9338857a824ad10f4d27d002d80601072ae74b","thumbnailUrl":"https://i4.ypcdn.com/blob/6e9338857a824ad10f4d27d002d80601072ae74b_400x260_crop.jpg"},"review":[{"@type":"Review","itemReviewed":"Mr. K's","author":{"@type":"Person","name":"Margaret E."},"reviewBody":"So delicious!! one of my favorite places in Manhattan, definitely check this place out if you are in this area.","reviewRating":{"@type":"Rating","ratingValue":5},"datePublished":"2018-05-12"},{"@type":"Review","itemReviewed":"Mr. K's","author":{"@type":"Person","name":"Elizabeth F."},"reviewBody":"Mr.K food is my top asain  places that I love going to. Their food is really good!! I recommend taking your friends asap!","reviewRating":{"@type":"Rating","ratingValue":5},"datePublished":"2015-20-12"},{"@type":"Review","itemReviewed":"Mr. K's","author":{"@type":"Person","name":"AshishM84"},"reviewBody":"I can write a long review about how good the food and service is at Mr.K's but that sometime is not needed when i can sum it up in just a few words.\t\tMR.K'S is the best Chinese Restaurant in all of New York.","reviewRating":{"@type":"Rating","ratingValue":5},"datePublished":"2009-17-02"},{"@type":"Review","itemReviewed":"Mr. K's","author":{"@type":"Person","name":"tedelong"},"reviewBody":"After reading some of the negative reviews, I really wanted to see for myself. I was visiting NYC for the 1st time and got tired of same old stuff! Especially the &quot;&quot;I'm better than you&quot;&quot; attitudes or the &quot;&quot;Do you really belong here?&quot;&quot; from the waiters in Manhattan. Being from the Cowboy State, (Wyoming in case you don't know) We can eat Steak and Italian anytime. Anyways, although we were somewhat intimidated at 1st, The waiter seemed to be walking on eggshells so the last thing we wanted to do was to offend the waiter! I Felt it was best to just ASK about the fancy table settings and the such that were being presented. The waiter was thrilled that he was being treated like a person and not a servant. He loosened up right away and was flattered that we didn't want to offend his culture and was more than happy to explain to us what the heck it was all about. The rest of our dining was a true delight. I had the Prawns/Scallops in Garlic sauce and my Wife had the Seafood Fried Rice. Wonton Soup was excellent ! As was the entire meal. Service was Great ! I truly think that by treating the waiter with respect and dignity made the evening even better and we were not the only ones that were pleased with the entire &quot;&quot;event &quot;&quot;. Highly recommended !!!!!! \t\tPS - Regardless of how you treat the waiter, It's definitely a 1st class operation there. Very pleasent time and educational for us I'm not not ashamed to admit. We will certainly go back when we return to NYC in the Spring!!!!!!!!!!!!!!","reviewRating":{"@type":"Rating","ratingValue":5},"datePublished":"2008-16-09"},{"@type":"Review","itemReviewed":"Mr. K's","author":{"@type":"Person","name":"akew"},"reviewBody":"Today was my third vis ...
# googletag.cmd = googletag.cmd || [];</script><script type="text/javascript">googletag.cmd.push(function() {
#     if (document.cookie.indexOf('optOut')!== -1) {
#         googletag.pubads().setPrivacySettings({'restrictDataProcessing': true });
#     }
#     googletag.defineSlot('/53532708/ca-pub-3200418779552017-tag/YP_MIP_300', [300, 250],  'div-gpt-ad-1555711099765-0').addService(googletag.pubads()).setTargeting('us_privacy', '%%PATTERN:pubs_custom_key_for_us_privacy%%');
#     googletag.pubads().enableSingleRequest();
#     googletag.pubads().setTargeting('pubs_custom_key_for_us_privacy', '138315278567');
#     googletag.enableServices();
# });
# </script><meta content="summary" name="twitter:card"/><meta content="@YP" name="twitter:site"/><meta content="Mr. K's 570 Lexington Ave, New York, NY 10022 - YP.com" name="twitter:title"/><meta content="Get reviews, hours, directions, coupons and more for Mr. K's at 570 Lexington Ave, New York, NY 10022. Search for other Chinese Restaurants in New York on The Real Yellow Pages®." name="twitter:description"/><meta content="https://i4.ypcdn.com/blob/6e9338857a824ad10f4d27d002d80601072ae74b_400x260_crop.jpg" name="twitter:image"/></head><body><svg class="hide" height="0" viewbox="0 0 0 0" width="0" xmlns="http://www.w3.org/2000/svg"><symbol id="default-avatar"><path d="M8.5 13v1.624l-5.408 1.92C1.837 16.971 1 18.131 1 19.405V21h20v-1.594c0-1.274-.874-2.434-2.128-2.863L13.5 14.624V13"></path><path d="M16 7.364c0 3.514-2.239 6.363-5 6.363-2.762 0-5-2.849-5-6.363C6 3.85 8.238 1 11 1c2.761 0 5 2.85 5 6.364z"></path></symbol></svg><script>// Begin comScore Tag
# var _comscore = _comscore || [];
# _comscore.push({ c1:2, c2:6035991, c3:"", c4:"", c5:"", c6:"", c15:"" });
# (function() {
# var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
# el.parentNode.insertBefore(s, el);
# })();
# // – End comScore Tag
# </script><noscript><img alt="" height="1" src="http://b.scorecardresearch.com/p?c1=2&amp;c2=6035991&amp;c3=&amp;c4=&amp;c5=&amp;c6=&amp;c15=&amp;cj=1" width="1"/></noscript><img alt="" class="beacon" height="1" src="https://c.ypcdn.com/2/p/webyp?ptid=www.yellowpages.com&amp;rid=webyp-4085e7d1-0b6d-4180-a34e-7295912b549b&amp;vrid=3bd5e6df-de62-4bcb-a6b6-f6df27c24dab" width="1"/><svg class="hide" height="0" viewbox="0 0 0 0" width="0" xmlns="http://www.w3.org/2000/svg"><symbol><path d="M1.143 6.285a5.148 5.148 0 0 1 5.142-5.142 5.148 5.148 0 0 1 5.144 5.142 5.148 5.148 0 0 1-5.144 5.142 5.148 5.148 0 0 1-5.142-5.142zM16 14.857l-4.571-4.571c.783-1.053 1.122-2.564 1.122-3.98 0-3.482-2.81-6.305-6.276-6.305C2.81.001 0 2.824 0 6.307s2.81 6.306 6.275 6.306c1.43 0 2.956-.484 4.01-1.293L14.858 16 16 14.857z" id="magnifying-glass"></path></symbol></svg><svg class="hide" height="0" viewbox="0 0 18 16" width="0" xmlns="http://www.w3.org/2000/svg"><symbol><path d="M15.788 7.11l-1.194-1.197.405-.396 1.194 1.203-.405.39zm-4.902 4.959l-1.238-1.154 4.16-4.153 1.215 1.155-4.137 4.152zm-1.891-.348l1.128 1.051-.77.439-.735-.703.377-.787zm-7.997 3.28V.994H9v3.019h3.001v2.981l-3.993 4.028v2.964h1.997l1.996-1.698V15H.998zM9.985.997l2.033 2.013H9.985V.998zm5.59 3.49a.802.802 0 0 0-1.107-.023l-1.474 1.541V3.004L10.005 0H0v15.98h12.932v-4.53l4.305-4.166c.31-.31.314-.801.006-1.113l-1.668-1.684zM9 6H3V5h6.002L9 6zm0 2H3V7h6.002L9 8zm-2.002 2H3V9h4l-.002 1z" id="pencil-to-page"></path></symbol></svg><header class="global" data-analytics='{"module":"search_docked_bar"}' id="yp-header"><div class="container"><a class="site-logo" data-analytics='{"click_id":1083}' href="/"><img alt="The Real Yellow Pages logo" height="48" id="global-logo" src="//i2.ypcdn.com/ypu/images/svgs/the_real_yp_logo_global.svg?546cbad" width="140"/></a><div aria-expanded="false" id="browse">Browse<div id="browse-menu" style="display: none"><div class="browse-cat" id="auto-services"><div class="category-name"><img alt="Browse auto services" src="//i2.ypcdn.com/ypu/images/svgs/auto-services.svg?546cbad">auto services</img></div><div class="category-links"><a href="https://www.yellowpages.com/los-angeles-ca/auto-body-shops">Auto Body Shops</a><a href="https://www.yellowpages.com/los-angeles-ca/auto-glass-repair">Auto Glass Repair</a><a href="https://www.yellowpages.com/los-angeles-ca/auto-parts">Auto Parts</a><a href="https://www.yellowpages.com
#  Concept Architect: Greg Olving In China, cooking is an ancient art rather than simply a nourishing necessity. Those dishes, which have stood the test of time, provide us with what is known as “the classic Chinese cuisine”. A well-planned meal will vary in texture and color as well as flavor and temperature to achieve overall harmony in the tradition of Ying and Yang. Each of the four main regions of the country has developed its own distinctive culinary style. Peking (North) provides a tender, delicate taste while Shanghai (East) uses light and savory flavors. In contrast are the crispy, unusual blends of Canton (South) and the fiery, spicy seasonings of Hunan and Szechwan (Central and West). To provide New York City, “Capital of the World”, with the best China has to offer, Mr. K’s has meticulously searched for dishes representing the essence of each of these regions. The most gourmet recipes with the best ingredients and subtlest of seasonings have been prepared under the masterful direction of our head chef. Their beautiful presentation on imperial flatware, served in grand style, is an exotic prelude to your delight.</dd><dt class="open-hours">Hours</dt><dd class="open-hours"><div class="open-details"><span class="hour-category">Regular Hours</span><table><tr><th class="day-label">Mon - Fri:</th><td class="day-hours"><time datetime="Mo-Fr 11:30-22:00">11:30 am - 10:00 pm</time></td></tr><tr><th class="day-label">Sat - Sun:</th><td class="day-hours"><time datetime="Sa-Su 12:00-22:00">12:00 pm - 10:00 pm</time></td></tr></table></div></dd><dt class="extra-phones">Extra Phones</dt><dd class="extra-phones"><p><span>Primary Phone: </span><span>(212) 583-1618</span></p><p><span>Fax Number: </span><span>(212) 583-1620</span></p><p><span>Phone: </span><span>(212) 583-1618</span></p><p><span>TollFree: </span><span>(888) 988-2088</span></p></dd><dt>Services/Products</dt><dd>Upscale Chinese Restaurant with Upscale Banquet, Private Dining, Catering, and Private Party Catering</dd><dt>Payment method</dt><dd class="payment">amex, master card, visa, discover</dd><dt>Price Range</dt><dd>$$$</dd><dt>Location</dt><dd class="location-description">Corner of 51st and Lex</dd><dt class="neighborhoods">Neighborhoods</dt><dd class="neighborhoods"><span><a data-analytics='{"click_id":1138}' href="/midtown-manhattan-new-york-ny/chinese-restaurants">Midtown Manhattan</a>, </span><span><a data-analytics='{"click_id":1138}' href="/turtle-bay-new-york-ny/chinese-restaurants">Turtle Bay</a>, </span><span><a data-analytics='{"click_id":1138}' href="/midtown-east-new-york-ny/chinese-restaurants">Midtown East</a>, </span><span><a data-analytics='{"click_id":1138}' href="/midtown-new-york-ny/chinese-restaurants">Midtown</a></span></dd><dt>Associations</dt><dd class="associations">AAA,-Aaa</dd><dt>AKA</dt><dd class="aka"><p>Mr K's</p><p>Mr. K's Restaurant</p><p>Mr K's Restaurant</p></dd><dt class="weblinks">Other Links</dt><dd class="weblinks"><p><a class="other-links" data-analytics='{"adclick":true,"events":"event7,event5","category":"8004222","impression_id":"1b7b88ce-e5d6-44bb-92b8-823e0090913b","listing_id":"1001117676060","item_id":-1,"listing_type":"sub","ypid":"407372","content_provider":"IY","srid":"f08425e0-8f66-4677-b941-78cd9cafb3a4","item_type":"listing","lhc":"8004222","ldir":"NRKNY","rate":4,"hasTripAdvisor":false,"pid":"800000001503987347","geography":"New York, NY","mip_claimed_status":"mip_unclaimed","mip_ypid":"407372","click_id":18}' href="http://www.mrksny.com" rel="nofollow" target="_blank">http://www.mrksny.com</a></p><p><a class="other-links" data-analytics='{"adclick":true,"events":"event7,event5","category":"8004222","impression_id":"1b7b88ce-e5d6-44bb-92b8-823e0090913b","listing_id":"1001117676060","item_id":-1,"listing_type":"sub","ypid":"407372","content_provider":"IY","srid":"f08425e0-8f66-4677-b941-78cd9cafb3a4","item_type":"listing","lhc":"8004222","ldir":"NRKNY","rate":4,"hasTripAdvisor":false,"pid":"800000001503987347","geo ...
#     function loadDeferredScripts() {
#         var js = ["//i1.ypcdn.com/pixy/pixy.js?546cbad"];
#         for (var i = 0; i < js.length; i++) {
#             var el = document.createElement('script');
#             el.src = js[i];
#             document.body.appendChild(el);
#         }
#     }
#     if (window.addEventListener) {
#         window.addEventListener('load', loadDeferredScripts, false);
#     } else if (window.attachEvent) {
#         window.attachEvent('onload', loadDeferredScripts);
#     } else {
#         window.onload = loadDeferredScripts;
#     }
# })();</
# (function(o){var K=o.$LAB,y="UseLocalXHR",z="AlwaysPreserveOrder",u="AllowDuplicates",A="CacheBust",B="BasePath",C=/^[^?#]*\//.exec(location.href)[0],D=/^\w+\:\/\/\/?[^\/]+/.exec(C)[0],i=document.head||document.getElementsByTagName("head"),L=(o.opera&&Object.prototype.toString.call(o.opera)=="[object Opera]")||("MozAppearance"in document.documentElement.style),q=document.createElement("script"),E=typeof q.preload=="boolean",r=E||(q.readyState&&q.readyState=="uninitialized"),F=!r&&q.async===true,M=!r&&!F&&!L;function G(a){return Object.prototype.toString.call(a)=="[object Function]"}function H(a){return Object.prototype.toString.call(a)=="[object Array]"}function N(a,c){var b=/^\w+\:\/\//;if(/^\/\/\/?/.test(a)){a=location.protocol+a}else if(!b.test(a)&&a.charAt(0)!="/"){a=(c||"")+a}return b.test(a)?a:((a.charAt(0)=="/"?D:C)+a)}function s(a,c){for(var b in a){if(a.hasOwnProperty(b)){c[b]=a[b]}}return c}function O(a){var c=false;for(var b=0;b<a.scripts.length;b++){if(a.scripts[b].ready&&a.scripts[b].exec_trigger){c=true;a.scripts[b].exec_trigger();a.scripts[b].exec_trigger=null}}return c}function t(a,c,b,d){a.onload=a.onreadystatechange=function(){if((a.readyState&&a.readyState!="complete"&&a.readyState!="loaded")||c[b])return;a.onload=a.onreadystatechange=null;d()}}function I(a){a.ready=a.finished=true;for(var c=0;c<a.finished_listeners.length;c++){a.finished_listeners[c]()}a.ready_listeners=[];a.finished_listeners=[]}function P(d,f,e,g,h){setTimeout(function(){var a,c=f.real_src,b;if("item"in i){if(!i[0]){setTimeout(arguments.callee,25);return}i=i[0]}a=document.createElement("script");if(f.type)a.type=f.type;if(f.charset)a.charset=f.charset;if(h){if(r){e.elem=a;if(E){a.preload=true;a.onpreload=g}else{a.onreadystatechange=function(){if(a.readyState=="loaded")g()}}a.src=c}else if(h&&c.indexOf(D)==0&&d[y]){b=new XMLHttpRequest();b.onreadystatechange=function(){if(b.readyState==4){b.onreadystatechange=function(){};e.text=b.responseText+"\n//@ sourceURL="+c;g()}};b.open("GET",c);b.send()}else{a.type="text/cache-script";t(a,e,"ready",function(){i.removeChild(a);g()});a.src=c;i.insertBefore(a,i.firstChild)}}else if(F){a.async=false;t(a,e,"finished",g);a.src=c;i.insertBefore(a,i.firstChild)}else{t(a,e,"finished",g);a.src=c;i.insertBefore(a,i.firstChild)}},0)}function J(){var l={},Q=r||M,n=[],p={},m;l[y]=true;l[z]=false;l[u]=false;l[A]=false;l[B]="";function R(a,c,b){var d;function f(){if(d!=null){d=null;I(b)}}if(p[c.src].finished)return;if(!a[u])p[c.src].finished=true;d=b.elem||document.createElement("script");if(c.type)d.type=c.type;if(c.charset)d.charset=c.charset;t(d,b,"finished",f);if(b.elem){b.elem=null}else if(b.text){d.onload=d.onreadystatechange=null;d.text=b.text}else{d.src=c.real_src}i.insertBefore(d,i.firstChild);if(b.text){f()}}function S(c,b,d,f){var e,g,h=function(){b.ready_cb(b,function(){R(c,b,e)})},j=function(){b.finished_cb(b,d)};b.src=N(b.src,c[B]);b.real_src=b.src+(c[A]?((/\?.*$/.test(b.src)?"&_":"?_")+~~(Math.random()*1E9)+"="):"");if(!p[b.src])p[b.src]={items:[],finished:false};g=p[b.src].items;if(c[u]||g.length==0){e=g[g.length]={ready:false,finished:false,ready_listeners:[h],finished_listeners:[j]};P(c,b,e,((f)?function(){e.ready=true;for(var a=0;a<e.ready_listeners.length;a++){e.ready_listeners[a]()}e.ready_listeners=[]}:function(){I(e)}),f)}else{e=g[0];if(e.finished){j()}else{e.finished_listeners.push(j)}}}function v(){var e,g=s(l,{}),h=[],j=0,w=false,k;function T(a,c){a.ready=true;a.exec_trigger=c;x()}function U(a,c){a.ready=a.finished=true;a.exec_trigger=null;for(var b=0;b<c.scripts.length;b++){if(!c.scripts[b].finished)return}c.finished=true;x()}function x(){while(j<h.length){if(G(h[j])){try{h[j++]()}catch(err){}continue}else if(!h[j].finished){if(O(h[j]))continue;break}j++}if(j==h.length){w=false;k=false}}function V(){if(!k||!k.scripts){h.push(k={scripts:[],finished:true})}}e={script:function(){for(var f=0;f<arguments.length;f++){(function(a,c){var b;if(!H(a)){c=[a]}for(var d=0;d<c.length;d++){V();a=c[d];i ...
#     newrelic.setPageViewName('/mip');
# }
# </script><script async="" src="//i1.ypcdn.com/ypu/vendor/shared.bundle.js?546cbad" type="text/javascript"></script><script async="" src="//i2.ypcdn.com/ypu/vendor/jquery-ui-1.10.3.custom.min.js?546cbad" type="text/javascript"></script><script>(function () {
#     function loadDeferredScripts() {
#         var js = ["//i4.ypcdn.com/ypu/js/compiled/bpp.js?546cbad"];
#         for (var i = 0; i < js.length; i++) {
#             var el = document.createElement('script');
#             el.src = js[i];
#             document.body.appendChild(el);
#         }
#     }
#     if (window.addEventListener) {
#         window.addEventListener('load', loadDeferredScripts, false);
#     } else if (window.attachEvent) {
#         window.attachEvent('onload', loadDeferredScripts);
#     } else {
#         window.onload = loadDeferredScripts;
#     }
# })();</script><script>(function () {
#     function loadDeferredScripts() {
#         var js = ["//i3.ypcdn.com/ypu/js/compiled/bpp-reviews.js?546cbad"];
#         for (var i = 0; i < js.length; i++) {
#             var el = document.createElement('script');
#             el.src = js[i];
#             document.body.appendChild(el);
#         }
#     }
#     if (window.addEventListener) {
#         window.addEventListener('load', loadDeferredScripts, false);
#     } else if (window.attachEvent) {
#         window.attachEvent('onload', loadDeferredScripts);
#     } else {
#         window.onload = loadDeferredScripts;
#     }
# })();</script><script>(function () {
#     function loadDeferredScripts() {
#         var js = ["//i3.ypcdn.com/ypu/js/compiled/bpp-media.js?546cbad"];
#         for (var i = 0; i < js.length; i++) {
#             var el = document.createElement('script');
#             el.src = js[i];
#             document.body.appendChild(el);
#         }
#     }
#     if (window.addEventListener) {
#         window.addEventListener('load', loadDeferredScripts, false);
#     } else if (window.attachEvent) {
#         window.attachEvent('onload', loadDeferredScripts);
#     } else {
#         window.onload = loadDeferredScripts;
#     }
# })();</script><img alt="" class="beacon" height="1" src="https://c.ypcdn.com/ta1/3bd5e6df-de62-4bcb-a6b6-f6df27c24dab" width="1"/><script>(function() {
#     function sendNewRelicPerformanceMetrics() {
#         // normalize the browsers
#         const performance = window.performance || window.webkitPerformance || window.msPerformance || window.mozPerformance;
#         const timing = performance.timing;
#         const metrics = {};
#         // IE bug https://gist.github.com/acdha/365f7bc0e10d2e7b7865
#         if (!timing.navigationStart) {
#             return;
#         }
#
#         // Timestamp for the request start
#         metrics.navigationStart = timing.navigationStart;
#         // Time To First Byte
#         metrics.timeToFirstByte = timing.responseStart - timing.navigationStart;
#
#         // Timestamp and duration of First Paint For Chrome
#         if (window.chrome && window.performance) {
#             let performanceEntries = performance.getEntriesByType('paint');
#
#             metrics.timeToFirstPaint = Math.round(performanceEntries[1].startTime);
#             metrics.firstPaint = metrics.timeToFirstPaint + metrics.navigationStart
#         }
#
#         // Timestamp and duration of First Paint For IE
#         else if (typeof timing.msFirstPaint === 'number') {
#             metrics.firstPaint = timing.msFirstPaint;
#             metrics.timeToFirstPaint = timing.msFirstPaint- timing.navigationStart;
#         }
#
#         // Time To Dom Interactive
#         if (timing.domInteractive) {
#             metrics.timeToDomInteractive = timing.domInteractive - timing.navigationStart;
#         }
#
#         if (typeof newrelic == 'object') {
#             newrelic.addPageAction('timings', metrics);
#         }
#     }
#     window.addEventListener('load', sendNewRelicPerformanceMetrics, false);
# })();</script></body>
# <!--
# version: 5.26.30-3389
# built_by: nextgen
# built_on: Thu Jul 22 21:36:56 UTC 2021
# build_host: consumer07-bamboo.prod.st1
# deployed_at: Fri Jul 23 17:40:34 UTC 2021
# deployed_by: root
# scm_rev: 546cbad
# ypu_parent: prod
# ypu_env: prod_ev1
# node_env: production
# hostname: ypu48.ev1
#
# --></html>

# %% [markdown]
# #### Name

# %%
soup.find('h1').get_text()
# Out:
# "Mr. K's"

# %% [markdown]
# #### Address

# %%
soup.find('h2', {'class': 'address'}).get_text()
# Out:
# '570 Lexington AveNew York, NY 10022'

# %% [markdown]
# #### Phone

# %%
soup.find('p', {'class':'phone'}).get_text()
# Out:
# '(212) 583-1668'

# %% [markdown]
# #### Email

# %%
# most important part

# %%
soup.find('a', {'class': 'email-business'}).get('href').split('mailto:')[1]
# Out:
# 'info@movingmaninc.com'

# %% [markdown]
# #### Website

# %%
soup.find('a', {'class': 'website-link'}).get('href')
# Out:
# 'http://www.mrksny.com'

# %% [markdown]
# #### General Info

# %%
soup.find('dd', {'class': 'general-info'}).get_text()
# Out:
# 'We offer exclusive seating to you and your party. Please inquire about our Private rooms on your next visit. You can also specify private room seating with your next reservation to confirm availability. \nOwner: Johnny Kao \n Executive Chef: Chen-Hua Yan\n Management Team: Edward Cheung, John Fong, Henry Lieu\n Date Opened: February 28, 1998\n Concept Architect: Greg Olving In China, cooking is an ancient art rather than simply a nourishing necessity. Those dishes, which have stood the test of time, provide us with what is known as “the classic Chinese cuisine”. A well-planned meal will vary in texture and color as well as flavor and temperature to achieve overall harmony in the tradition of Ying and Yang. Each of the four main regions of the country has developed its own distinctive culinary style. Peking (North) provides a tender, delicate taste while Shanghai (East) uses light and savory flavors. In contrast are the crispy, unusual blends of Canton (South) and the fiery, spicy seasonings of Hunan and Szechwan (Central and West). To provide New York City, “Capital of the World”, with the best China has to offer, Mr. K’s has meticulously searched for dishes representing the essence of each of these regions. The most gourmet recipes with the best ingredients and subtlest of seasonings have been prepared under the masterful direction of our head chef. Their beautiful presentation on imperial flatware, served in grand style, is an exotic prelude to your delight.'

# %% [markdown]
# ### Put all together and loop through all pages

# %%
# empty list - we need it so we can append all results - hand it over to pandas dataframe
results = []

# loop through all joined links
for link in url_joined:
    response = requests.get(link)
    
    # create soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # name
    try:
        name = soup.find('h1').get_text()
    except:
        name = 'n/a'
        
    # address 
    try:
        address = soup.find('h2', {'class': 'address'}).get_text()
    except:
        address = 'n/a'
        
    # phone
    try:
        phone = soup.find('p', {'class':'phone'}).get_text()
    except:
        phone = 'n/a'
        
    # email
    try:
        email = soup.find('a', {'class': 'email-business'}).get('href').split('mailto:')[1]
    except:
        email = 'n/a'
        
    # website
    try:
        website = soup.find('a', {'class': 'website-link'}).get('href')
    except:
        website = 'n/a'
        
    # general info
    try:
        info = soup.find('dd', {'class': 'general-info'}).get_text()
    except:
        info = 'n/a'
        
    
    # create dictionary with results
    output = {'Restaurant Name': name, 'Address': address, 'Phone': phone, 'Email': email, 'Homepage':website,
             'Info':info}
    
    # append results in empty list
    results.append(output)

# %% [markdown]
# ### Create Pandas Dataframe

# 6                                           n/a
# 7                             evazhng@yahoo.com
# 8                      hospitality@babbonyc.com
# 9                   office@sparkssteakhouse.com
# 10                                          n/a
# 11                         info@blindpigbar.com
# 12             OldHomesteadSteakhouse@gmail.com
# 13                         info@casamononyc.com
# 14                 jeanclaude@chezjosephine.com
# 15                         info@mariobatali.com
# 16          sheelagh.wylie@madametussaudsny.com
# 17                       info@paulandjimmys.com
# 18                         Info45@bobbyvans.com
# 19                       support@simplemenu.com
# 20                                          n/a
# 21                           sarita@smacnyc.com
# 22                                          n/a
# 23                                          n/a
# 24                      mobsta@lukeslobster.com
# 25                                          n/a
# 26                  franks@frankiesspuntino.com
# 27                                          n/a
# 28                                          n/a
# 29  general-information@planethollywoodintl.com
#
#                                              Homepage  \
# 0                               http://www.mrksny.com
# 1                                 http://potjanee.net
# 2             http://www.spoonfed.nyc/contact-us.html
# 3          http://danoinyc.com/midtown-manhattan.html
# 4                                                 n/a
# 5                           http://www.todarobros.com
# 6                      http://www.punchrestaurant.com
# 7                              http://www.alpha34.com
# 8                            https://www.babbonyc.com
# 9                     http://www.sparkssteakhouse.com
# 10                           http://www.biancanyc.com
# 11                         http://www.blindpigbar.com
# 12              https://theoldhomesteadsteakhouse.com
# 13                         http://www.casamononyc.com
# 14                       http://www.chezjosephine.com
# 15                            http://www.esca-nyc.com
# 16                      http://www.daveandbusters.com
# 17                       http://www.paulandjimmys.com
# 18                           http://www.bobbyvans.com
# 19                                                n/a
# 20                                                n/a
# 21                             http://www.eatsmac.com
# 22                                                n/a
# 23                       http://www.orderredhouse.com
# 24  http://www.lukeslobster.com/location/nyc-east-...
# 25                     http://www.gramercycafenyc.com
# 26                    http://www.frankiesspuntino.com
# 27        http://www.pintonyc.com/#restaurant-section
# 28                                                n/a
# 29  https://locations.planethollywoodintl.com/us/n...
#
#                                                  Info
# 0   We offer exclusive seating to you and your par...
# 1   If you're looking for authentic Thai food in N...
# 2                                                 n/a
# 3   High quality dining, elegant private parties a...
# 4   Here at Seven's Mediterranean Turkish Grill we...
# 5   NYC's Neighborhood Market since 1917.  Todaro ...
# 6   Punch Restaurant and Bar is located in the Fla...
# 7                                                 n/a
# 8   Babbo Ristorante e Enoteca is an exuberant cel...
# 9   Established in 1966, Sparks Steak House featur...
# 10                                                n/a
# 11                                                n/a
# 12  Classic Gotham Steakhouse located in the ultra...
# 13  Casa Mono and its sister restaurant, Bar Jamón...
# 14  The last of its kind near 42nd Street, Chez Jo...
# 15  ESCA- Italian for "bait," the stuff of temptat...
# 16  You know what Times Square needs? It needs mor...
# 17                                                n/a
# 18  Bobby Van's Steakhouse New York, located at 54...
# 19                                                n/a
# 20  Serving up all-American food and fun, Johnny R...
# 21  S'MAC (short for Sarita's Macaroni & Cheese) i...
# 22                                                n/a
# 23                                                n/a
# 24                                                n/a
# 25                                                n/a
# 26                                                n/a
# 27                                                n/a
# 28                                                n/a
# 29  Big stars in the big apple! Our big and bold r...

# %% [markdown]
# ### Store in Excel

# %%
df.to_excel('result_single_page.xlsx', index=False)
